# %% [markdown]
# ## Time-Series Analysis using CNN-LSTM: Dhaka Tribune
#
# Dataset: Dhaka Tribune 2021 Dataset
#
# Resampling Technique: Every 6 Days
#
# Author: Sumaia Parveen Shupti
#
# Created on: 07/10/2021
#
# Updated on: 07/15/2021

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

from datetime import datetime, timedelta
import warnings
import matplotlib.pyplot as plt
from keras import optimizers
from keras.utils import plot_model
from keras.models import Sequential, Model
from keras.layers.convolutional import Conv1D, MaxPooling1D
from keras.layers import Dense, LSTM, RepeatVector, TimeDistributed, Flatten, Dropout
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
#import chart_studio.plotly as py
import plotly.graph_objs as go
from plotly.offline import init_notebook_mode, iplot
from keras.callbacks import EarlyStopping, ModelCheckpoint

# %matplotlib inline
warnings.filterwarnings("ignore")
init_notebook_mode(connected=True)

# Set seeds to make the experiment more reproducible.
from numpy.random import seed
seed(1)
from tensorflow import random
random.set_seed(1)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ### Load & Preprocess Dataset

# %%
df = pd.read_csv('../input/dhakatribunecomplete/Dhaka Tribune Complete Data.csv')
df['Accident date'] = pd.to_datetime(df['Accident date'])

df = df[['Accident date', 'Deaths']]
df.columns = ['Period', 'Deaths']
df = df.sort_values(by = 'Period')
df = df.reset_index(drop = True).set_index('Period').resample('6D').sum()
df = df.reset_index()
df['Period'] = df['Period'].dt.date
df['Deaths'] = df['Deaths'].fillna(0)
df = df.set_index('Period')
df
# Out:
#             Deaths
# Period
# 2016-06-24     3.0
# 2016-06-30     0.0
# 2016-07-06     0.0
# 2016-07-12     4.0
# 2016-07-18     0.0
# ...            ...
# 2021-05-29     9.0
# 2021-06-04     2.0
# 2021-06-10     8.0
# 2021-06-16    16.0
# 2021-06-22     5.0
#
# [305 rows x 1 columns]

# %% [markdown]
# ### Splitting into Train & Test Sets

# %%
start_ = df.index.max()
end_ = df.index.min()

test_end = df.index.max()
test_start = df.index.max() - timedelta(days = 60)

train_end = test_start - timedelta(days = 1)
train_start = train_end - timedelta(days = 60*4)

print('Dataset Start Date: {}'.format(start_))
print('Dataset End Date: {}'.format(end_))
print (' ')
print('Train Set Start Date: {}'.format(train_start))
print('Train Set End Date: {}'.format(train_end))
print (' ')
print('Test Set Start Date: {}'.format(test_start))
print('Test Set End Date: {}'.format(test_end))
print (' ')
# Out:
# Dataset Start Date: 2021-06-22
# Dataset End Date: 2016-06-24
#
# Train Set Start Date: 2020-08-25
# Train Set End Date: 2021-04-22
#
# Test Set Start Date: 2021-04-23
# Test Set End Date: 2021-06-22

# %%
mask = (df.index > train_start) & (df.index <= train_end)
train = df.loc[mask]

mask = (df.index > test_start) & (df.index <= test_end)
test = df.loc[mask]

# %%
d = pd.concat([train, test])
d = d.reset_index()
d
# Out:
#         Period  Deaths
# 0   2020-08-26     8.0
# 1   2020-09-01     0.0
# 2   2020-09-07    15.0
# 3   2020-09-13     9.0
# 4   2020-09-19     5.0
# 5   2020-09-25     0.0
# 6   2020-10-01     1.0
# 7   2020-10-07     7.0
# 8   2020-10-13     1.0
# 9   2020-10-19     0.0
# 10  2020-10-25     4.0
# 11  2020-10-31     8.0
# 12  2020-11-06     1.0
# 13  2020-11-12     3.0
# 14  2020-11-18    12.0
# 15  2020-11-24     0.0
# 16  2020-11-30     9.0
# 17  2020-12-06    38.0
# 18  2020-12-12     0.0
# 19  2020-12-18     1.0
# 20  2020-12-24     0.0
# 21  2020-12-30    22.0
# 22  2021-01-05     1.0
# 23  2021-01-11     6.0
# 24  2021-01-17     5.0
# 25  2021-01-23     1.0
# 26  2021-01-29    32.0
# 27  2021-02-04     6.0
# 28  2021-02-10    15.0
# 29  2021-02-16    12.0
# 30  2021-02-22    36.0
# 31  2021-02-28    14.0
# 32  2021-03-06     9.0
# 33  2021-03-12     7.0
# 34  2021-03-18    12.0
# 35  2021-03-24    26.0
# 36  2021-03-30     7.0
# 37  2021-04-05     4.0
# 38  2021-04-11    25.0
# 39  2021-04-17     6.0
# 40  2021-04-29    15.0
# 41  2021-05-05    11.0
# 42  2021-05-11    17.0
# 43  2021-05-17    28.0
# 44  2021-05-23     3.0
# 45  2021-05-29     9.0
# 46  2021-06-04     2.0
# 47  2021-06-10     8.0
# 48  2021-06-16    16.0
# 49  2021-06-22     5.0

# %% [markdown]
# ### Transform the data into a time series problem

# %%
def series_to_supervised(data, window=1, lag=1, dropnan=True):
    cols, names = list(), list()
    # Input sequence (t-n, ... t-1)
    for i in range(window, 0, -1):
        cols.append(data.shift(i))
        names += [('%s(t-%d)' % (col, i)) for col in data.columns]
    # Current timestep (t=0)
    cols.append(data)
    names += [('%s(t)' % (col)) for col in data.columns]
    # Target timestep (t=lag)
    cols.append(data.shift(-lag))
    names += [('%s(t+%d)' % (col, lag)) for col in data.columns]
    # Put it all together
    agg = pd.concat(cols, axis=1)
    agg.columns = names
    # Drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg

# %% [markdown]
# ### We will use the present day and the last 3 days data to forecast 1 day's results ahead

# %%
window = 2
lag = 1
series = series_to_supervised(d.drop('Period', axis=1), window=window, lag=lag)
series
# Out:
#     Deaths(t-2)  Deaths(t-1)  Deaths(t)  Deaths(t+1)
# 2           8.0          0.0       15.0          9.0
# 3           0.0         15.0        9.0          5.0
# 4          15.0          9.0        5.0          0.0
# 5           9.0          5.0        0.0          1.0
# 6           5.0          0.0        1.0          7.0
# 7           0.0          1.0        7.0          1.0
# 8           1.0          7.0        1.0          0.0
# 9           7.0          1.0        0.0          4.0
# 10          1.0          0.0        4.0          8.0
# 11          0.0          4.0        8.0          1.0
# 12          4.0          8.0        1.0          3.0
# 13          8.0          1.0        3.0         12.0
# 14          1.0          3.0       12.0          0.0
# 15          3.0         12.0        0.0          9.0
# 16         12.0          0.0        9.0         38.0
# 17          0.0          9.0       38.0          0.0
# 18          9.0         38.0        0.0          1.0
# 19         38.0          0.0        1.0          0.0
# 20          0.0          1.0        0.0         22.0
# 21          1.0          0.0       22.0          1.0
# 22          0.0         22.0        1.0          6.0
# 23         22.0          1.0        6.0          5.0
# 24          1.0          6.0        5.0          1.0
# 25          6.0          5.0        1.0         32.0
# 26          5.0          1.0       32.0          6.0
# 27          1.0         32.0        6.0         15.0
# 28         32.0          6.0       15.0         12.0
# 29          6.0         15.0       12.0         36.0
# 30         15.0         12.0       36.0         14.0
# 31         12.0         36.0       14.0          9.0
# 32         36.0         14.0        9.0          7.0
# 33         14.0          9.0        7.0         12.0
# 34          9.0          7.0       12.0         26.0
# 35          7.0         12.0       26.0          7.0
# 36         12.0         26.0        7.0          4.0
# 37         26.0          7.0        4.0         25.0
# 38          7.0          4.0       25.0          6.0
# 39          4.0         25.0        6.0         15.0
# 40         25.0          6.0       15.0         11.0
# 41          6.0         15.0       11.0         17.0
# 42         15.0         11.0       17.0         28.0
# 43         11.0         17.0       28.0          3.0
# 44         17.0         28.0        3.0          9.0
# 45         28.0          3.0        9.0          2.0
# 46          3.0          9.0        2.0          8.0
# 47          9.0          2.0        8.0         16.0
# 48          2.0          8.0       16.0          5.0

# %%
lag_size = 1

# Label
labels_col = 'Deaths(t+%d)' % lag_size
labels = series[[labels_col]]
series = series.drop(labels_col, axis=1)
series
# Out:
#     Deaths(t-2)  Deaths(t-1)  Deaths(t)
# 2           8.0          0.0       15.0
# 3           0.0         15.0        9.0
# 4          15.0          9.0        5.0
# 5           9.0          5.0        0.0
# 6           5.0          0.0        1.0
# 7           0.0          1.0        7.0
# 8           1.0          7.0        1.0
# 9           7.0          1.0        0.0
# 10          1.0          0.0        4.0
# 11          0.0          4.0        8.0
# 12          4.0          8.0        1.0
# 13          8.0          1.0        3.0
# 14          1.0          3.0       12.0
# 15          3.0         12.0        0.0
# 16         12.0          0.0        9.0
# 17          0.0          9.0       38.0
# 18          9.0         38.0        0.0
# 19         38.0          0.0        1.0
# 20          0.0          1.0        0.0
# 21          1.0          0.0       22.0
# 22          0.0         22.0        1.0
# 23         22.0          1.0        6.0
# 24          1.0          6.0        5.0
# 25          6.0          5.0        1.0
# 26          5.0          1.0       32.0
# 27          1.0         32.0        6.0
# 28         32.0          6.0       15.0
# 29          6.0         15.0       12.0
# 30         15.0         12.0       36.0
# 31         12.0         36.0       14.0
# 32         36.0         14.0        9.0
# 33         14.0          9.0        7.0
# 34          9.0          7.0       12.0
# 35          7.0         12.0       26.0
# 36         12.0         26.0        7.0
# 37         26.0          7.0        4.0
# 38          7.0          4.0       25.0
# 39          4.0         25.0        6.0
# 40         25.0          6.0       15.0
# 41          6.0         15.0       11.0
# 42         15.0         11.0       17.0
# 43         11.0         17.0       28.0
# 44         17.0         28.0        3.0
# 45         28.0          3.0        9.0
# 46          3.0          9.0        2.0
# 47          9.0          2.0        8.0
# 48          2.0          8.0       16.0

# %%
labels
# Out:
#     Deaths(t+1)
# 2           9.0
# 3           5.0
# 4           0.0
# 5           1.0
# 6           7.0
# 7           1.0
# 8           0.0
# 9           4.0
# 10          8.0
# 11          1.0
# 12          3.0
# 13         12.0
# 14          0.0
# 15          9.0
# 16         38.0
# 17          0.0
# 18          1.0
# 19          0.0
# 20         22.0
# 21          1.0
# 22          6.0
# 23          5.0
# 24          1.0
# 25         32.0
# 26          6.0
# 27         15.0
# 28         12.0
# 29         36.0
# 30         14.0
# 31          9.0
# 32          7.0
# 33         12.0
# 34         26.0
# 35          7.0
# 36          4.0
# 37         25.0
# 38          6.0
# 39         15.0
# 40         11.0
# 41         17.0
# 42         28.0
# 43          3.0
# 44          9.0
# 45          2.0
# 46          8.0
# 47         16.0
# 48          5.0

# %%
X_train = series[:len(train)- window]
X_train
# Out:
#     Deaths(t-2)  Deaths(t-1)  Deaths(t)
# 2           8.0          0.0       15.0
# 3           0.0         15.0        9.0
# 4          15.0          9.0        5.0
# 5           9.0          5.0        0.0
# 6           5.0          0.0        1.0
# 7           0.0          1.0        7.0
# 8           1.0          7.0        1.0
# 9           7.0          1.0        0.0
# 10          1.0          0.0        4.0
# 11          0.0          4.0        8.0
# 12          4.0          8.0        1.0
# 13          8.0          1.0        3.0
# 14          1.0          3.0       12.0
# 15          3.0         12.0        0.0
# 16         12.0          0.0        9.0
# 17          0.0          9.0       38.0
# 18          9.0         38.0        0.0
# 19         38.0          0.0        1.0
# 20          0.0          1.0        0.0
# 21          1.0          0.0       22.0
# 22          0.0         22.0        1.0
# 23         22.0          1.0        6.0
# 24          1.0          6.0        5.0
# 25          6.0          5.0        1.0
# 26          5.0          1.0       32.0
# 27          1.0         32.0        6.0
# 28         32.0          6.0       15.0
# 29          6.0         15.0       12.0
# 30         15.0         12.0       36.0
# 31         12.0         36.0       14.0
# 32         36.0         14.0        9.0
# 33         14.0          9.0        7.0
# 34          9.0          7.0       12.0
# 35          7.0         12.0       26.0
# 36         12.0         26.0        7.0
# 37         26.0          7.0        4.0
# 38          7.0          4.0       25.0
# 39          4.0         25.0        6.0

# %%
Y_train = labels[:len(train)- window]
Y_train
# Out:
#     Deaths(t+1)
# 2           9.0
# 3           5.0
# 4           0.0
# 5           1.0
# 6           7.0
# 7           1.0
# 8           0.0
# 9           4.0
# 10          8.0
# 11          1.0
# 12          3.0
# 13         12.0
# 14          0.0
# 15          9.0
# 16         38.0
# 17          0.0
# 18          1.0
# 19          0.0
# 20         22.0
# 21          1.0
# 22          6.0
# 23          5.0
# 24          1.0
# 25         32.0
# 26          6.0
# 27         15.0
# 28         12.0
# 29         36.0
# 30         14.0
# 31          9.0
# 32          7.0
# 33         12.0
# 34         26.0
# 35          7.0
# 36          4.0
# 37         25.0
# 38          6.0
# 39         15.0

# %%
X_valid = series[len(train)- window:]
X_valid
# Out:
#     Deaths(t-2)  Deaths(t-1)  Deaths(t)
# 40         25.0          6.0       15.0
# 41          6.0         15.0       11.0
# 42         15.0         11.0       17.0
# 43         11.0         17.0       28.0
# 44         17.0         28.0        3.0
# 45         28.0          3.0        9.0
# 46          3.0          9.0        2.0
# 47          9.0          2.0        8.0
# 48          2.0          8.0       16.0

# %%
Y_valid = labels[len(train)- window:]
Y_valid
# Out:
#     Deaths(t+1)
# 40         11.0
# 41         17.0
# 42         28.0
# 43          3.0
# 44          9.0
# 45          2.0
# 46          8.0
# 47         16.0
# 48          5.0

# %%
print('Train set shape', X_train.shape)
print('Validation set shape', X_valid.shape)

print('Train labels shape', Y_train.shape)
print('Validation labels shape', Y_valid.shape)
# Out:
# Train set shape (38, 3)
# Validation set shape (9, 3)
# Train labels shape (38, 1)
# Validation labels shape (9, 1)

# %%
X_train_series = X_train.values.reshape((X_train.shape[0], X_train.shape[1], 1))
X_valid_series = X_valid.values.reshape((X_valid.shape[0], X_valid.shape[1], 1))
print('Train set shape', X_train_series.shape)
print('Validation set shape', X_valid_series.shape)
# Out:
# Train set shape (38, 3, 1)
# Validation set shape (9, 3, 1)

# %%
subsequences = 1
timesteps = X_train_series.shape[1]//subsequences
X_train_series_sub = X_train_series.reshape((X_train_series.shape[0], subsequences, timesteps, 1))
X_valid_series_sub = X_valid_series.reshape((X_valid_series.shape[0], subsequences, timesteps, 1))
print('Train set shape', X_train_series_sub.shape)
print('Validation set shape', X_valid_series_sub.shape)
# Out:
# Train set shape (38, 1, 3, 1)
# Validation set shape (9, 1, 3, 1)

# %% [markdown]
# ### Model Development: CNN-LSTM

# %%
epochs = 40
batch = 1
lr = 0.008
adam = optimizers.Adam(lr)
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=70)
mcp = ModelCheckpoint(filepath='weights.h5', monitor='val_loss', verbose=1, save_best_only=True, save_weights_only=True)

# %%
model_cnn_lstm = Sequential()
model_cnn_lstm.add(TimeDistributed(Conv1D(filters=100, kernel_size=1, activation='relu'), input_shape=(None, X_train_series_sub.shape[2], X_train_series_sub.shape[3])))
model_cnn_lstm.add(TimeDistributed(MaxPooling1D(pool_size=1)))
model_cnn_lstm.add(TimeDistributed(Flatten()))
#model_cnn_lstm.add(LSTM(50,activation="relu",return_sequences=True))
#model_cnn_lstm.add(Dropout(0.15))
model_cnn_lstm.add(LSTM(50,activation="relu",return_sequences=True))
model_cnn_lstm.add(LSTM(50,activation="relu"))
model_cnn_lstm.add(Dropout(0.15))
model_cnn_lstm.add(Dense(1))
model_cnn_lstm.compile(loss='mse', optimizer='adam')

# %%
# %%time
cnn_lstm_history = model_cnn_lstm.fit(X_train_series_sub, Y_train, validation_data=(X_valid_series_sub, Y_valid), epochs=epochs, verbose=1, callbacks=[es, mcp])
# Out:
# Epoch 1/40
# 2/2 [==============================] - 3s 959ms/step - loss: 198.0265 - val_loss: 177.4409
#
# Epoch 00001: val_loss improved from inf to 177.44089, saving model to weights.h5
# Epoch 2/40
# 2/2 [==============================] - 0s 120ms/step - loss: 197.6593 - val_loss: 173.9174
#
# Epoch 00002: val_loss improved from 177.44089 to 173.91739, saving model to weights.h5
# Epoch 3/40
# 2/2 [==============================] - 0s 120ms/step - loss: 187.4405 - val_loss: 168.6142
#
# Epoch 00003: val_loss improved from 173.91739 to 168.61420, saving model to weights.h5
# Epoch 4/40
# 2/2 [==============================] - 0s 121ms/step - loss: 180.0539 - val_loss: 160.5398
#
# Epoch 00004: val_loss improved from 168.61420 to 160.53983, saving model to weights.h5
# Epoch 5/40
# 2/2 [==============================] - 0s 126ms/step - loss: 177.0088 - val_loss: 149.1585
#
# Epoch 00005: val_loss improved from 160.53983 to 149.15851, saving model to weights.h5
# Epoch 6/40
# 2/2 [==============================] - 0s 121ms/step - loss: 176.9536 - val_loss: 134.6721
#
# Epoch 00006: val_loss improved from 149.15851 to 134.67215, saving model to weights.h5
# Epoch 7/40
# 2/2 [==============================] - 0s 123ms/step - loss: 167.5506 - val_loss: 117.6712
#
# Epoch 00007: val_loss improved from 134.67215 to 117.67116, saving model to weights.h5
# Epoch 8/40
# 2/2 [==============================] - 0s 123ms/step - loss: 157.8082 - val_loss: 101.5168
#
# Epoch 00008: val_loss improved from 117.67116 to 101.51676, saving model to weights.h5
# Epoch 9/40
# 2/2 [==============================] - 0s 123ms/step - loss: 124.4431 - val_loss: 92.3500
#
# Epoch 00009: val_loss improved from 101.51676 to 92.34999, saving model to weights.h5
# Epoch 10/40
# 2/2 [==============================] - 0s 121ms/step - loss: 145.3533 - val_loss: 95.1018
#
# Epoch 00010: val_loss did not improve from 92.34999
# Epoch 11/40
# 2/2 [==============================] - 0s 117ms/step - loss: 111.8881 - val_loss: 99.0008
#
# Epoch 00011: val_loss did not improve from 92.34999
# Epoch 12/40
# 2/2 [==============================] - 0s 123ms/step - loss: 143.8704 - val_loss: 96.5764
#
# Epoch 00012: val_loss did not improve from 92.34999
# Epoch 13/40
# 2/2 [==============================] - 0s 123ms/step - loss: 141.0317 - val_loss: 88.9912
#
# Epoch 00013: val_loss improved from 92.34999 to 88.99122, saving model to weights.h5
# Epoch 14/40
# 2/2 [==============================] - 0s 120ms/step - loss: 131.0515 - val_loss: 84.7228
#
# Epoch 00014: val_loss improved from 88.99122 to 84.72277, saving model to weights.h5
# Epoch 15/40
# 2/2 [==============================] - 0s 122ms/step - loss: 133.4462 - val_loss: 83.8640
#
# Epoch 00015: val_loss improved from 84.72277 to 83.86399, saving model to weights.h5
# Epoch 16/40
# 2/2 [==============================] - 0s 116ms/step - loss: 136.9882 - val_loss: 85.3463
#
# Epoch 00016: val_loss did not improve from 83.86399
# Epoch 17/40
# 2/2 [==============================] - 0s 120ms/step - loss: 123.0524 - val_loss: 87.2566
#
# Epoch 00017: val_loss did not improve from 83.86399
# Epoch 18/40
# 2/2 [==============================] - 0s 122ms/step - loss: 137.8313 - val_loss: 88.5369
#
# Epoch 00018: val_loss did not improve from 83.86399
# Epoch 19/40
# 2/2 [==============================] - 0s 120ms/step - loss: 127.5428 - val_loss: 88.9392
#
# Epoch 00019: val_loss did not improve from 83.86399
# Epoch 20/40
# 2/2 [==============================] - 0s 127ms/step - loss: 136.9822 - val_loss: 88.3223
#
# Epoch 00020: val_loss did not improve from 83.86399
# Epoch 21/40
# 2/2 [==============================] - 0s 120ms/step - loss: 134.7199 - val_loss: 86.8530
#
# Epoch 00021: val_loss did not improve from 83.86399
# Epoch 22/40
# 2/2 [==============================] - 0s 125ms/step - loss: 121.0628 - val_loss: 84.4811
#
# Epoch 00022: val_loss did not improve from 83.86399
# Epoch 23/40
# 2/2 [==============================] - 0s 122ms/step - loss: 122.4194 - val_loss: 81.8162
#
# Epoch 00023: val_loss improved from 83.86399 to 81.81618, saving model to weights.h5
# Epoch 24/40
# 2/2 [==============================] - 0s 128ms/step - loss: 121.4254 - val_loss: 79.2856
#
# Epoch 00024: val_loss improved from 81.81618 to 79.28561, saving model to weights.h5
# Epoch 25/40
# 2/2 [==============================] - 0s 124ms/step - loss: 130.6856 - val_loss: 77.4457
#
# Epoch 00025: val_loss improved from 79.28561 to 77.44572, saving model to weights.h5
# Epoch 26/40
# 2/2 [==============================] - 0s 120ms/step - loss: 120.4627 - val_loss: 76.5835
#
# Epoch 00026: val_loss improved from 77.44572 to 76.58354, saving model to weights.h5
# Epoch 27/40
# 2/2 [==============================] - 0s 122ms/step - loss: 118.8300 - val_loss: 76.0535
#
# Epoch 00027: val_loss improved from 76.58354 to 76.05354, saving model to weights.h5
# Epoch 28/40
# 2/2 [==============================] - 0s 124ms/step - loss: 118.8252 - val_loss: 75.8383
#
# Epoch 00028: val_loss improved from 76.05354 to 75.83834, saving model to weights.h5
# Epoch 29/40
# 2/2 [==============================] - 0s 122ms/step - loss: 123.6294 - val_loss: 75.8785
#
# Epoch 00029: val_loss did not improve from 75.83834
# Epoch 30/40
# 2/2 [==============================] - 0s 120ms/step - loss: 120.5916 - val_loss: 73.6493
#
# Epoch 00030: val_loss improved from 75.83834 to 73.64934, saving model to weights.h5
# Epoch 31/40
# 2/2 [==============================] - 0s 119ms/step - loss: 112.3025 - val_loss: 70.8536
#
# Epoch 00031: val_loss improved from 73.64934 to 70.85358, saving model to weights.h5
# Epoch 32/40
# 2/2 [==============================] - 0s 125ms/step - loss: 122.0909 - val_loss: 69.1462
#
# Epoch 00032: val_loss improved from 70.85358 to 69.14618, saving model to weights.h5
# Epoch 33/40
# 2/2 [==============================] - 0s 122ms/step - loss: 122.2478 - val_loss: 68.3499
#
# Epoch 00033: val_loss improved from 69.14618 to 68.34988, saving model to weights.h5
# Epoch 34/40
# 2/2 [==============================] - 0s 120ms/step - loss: 118.2516 - val_loss: 68.4620
#
# Epoch 00034: val_loss did not improve from 68.34988
# Epoch 35/40
# 2/2 [==============================] - 0s 121ms/step - loss: 111.8982 - val_loss: 69.2528
#
# Epoch 00035: val_loss did not improve from 68.34988
# Epoch 36/40
# 2/2 [==============================] - 0s 122ms/step - loss: 112.9865 - val_loss: 68.5530
#
# Epoch 00036: val_loss did not improve from 68.34988
# Epoch 37/40
# 2/2 [==============================] - 0s 121ms/step - loss: 112.8700 - val_loss: 65.4418
#
# Epoch 00037: val_loss improved from 68.34988 to 65.44183, saving model to weights.h5
# Epoch 38/40
# 2/2 [==============================] - 0s 119ms/step - loss: 99.4255 - val_loss: 63.5175
#
# Epoch 00038: val_loss improved from 65.44183 to 63.51754, saving model to weights.h5
# Epoch 39/40
# 2/2 [==============================] - 0s 118ms/step - loss: 109.6182 - val_loss: 68.5637
#
# Epoch 00039: val_loss did not improve from 63.51754
# Epoch 40/40
# 2/2 [==============================] - 0s 120ms/step - loss: 106.8141 - val_loss: 78.7537
#
# Epoch 00040: val_loss did not improve from 63.51754
# CPU times: user 8.76 s, sys: 381 ms, total: 9.14 s
# Wall time: 8.69 s

# %%
# %%time
cnn_lstm_valid_pred = model_cnn_lstm.predict(X_valid_series_sub)
# Out:
# CPU times: user 358 ms, sys: 15.8 ms, total: 374 ms
# Wall time: 370 ms

# %%
comparison = test.copy()
comparison = comparison[:len(test)-lag]
comparison['Prediction'] = cnn_lstm_valid_pred
comparison
# Out:
#             Deaths  Prediction
# Period
# 2021-04-29    15.0   18.030252
# 2021-05-05    11.0   14.072212
# 2021-05-11    17.0   18.973494
# 2021-05-17    28.0   22.635250
# 2021-05-23     3.0   11.680267
# 2021-05-29     9.0   12.282712
# 2021-06-04     2.0    5.544176
# 2021-06-10     8.0    8.832713
# 2021-06-16    16.0    8.667019

# %%
# %%time
cnn_lstm_train_pred = model_cnn_lstm.predict(X_train_series_sub)
# Out:
# CPU times: user 39.7 ms, sys: 5.07 ms, total: 44.7 ms
# Wall time: 41.8 ms

# %%
comparison_train = train.copy()
comparison_train = comparison_train[window:]
comparison_train['Prediction'] = cnn_lstm_train_pred
comparison_train
# Out:
#             Deaths  Prediction
# Period
# 2020-09-07    15.0    9.284351
# 2020-09-13     9.0    9.912472
# 2020-09-19     5.0   10.522196
# 2020-09-25     0.0    5.687982
# 2020-10-01     1.0    2.098373
# 2020-10-07     7.0    1.779973
# 2020-10-13     1.0    3.032081
# 2020-10-19     0.0    3.086883
# 2020-10-25     4.0    1.149664
# 2020-10-31     8.0    3.456642
# 2020-11-06     1.0    5.139621
# 2020-11-12     3.0    5.246397
# 2020-11-18    12.0    4.551225
# 2020-11-24     0.0    5.684193
# 2020-11-30     9.0    9.938195
# 2020-12-06    38.0    7.576083
# 2020-12-12     0.0   11.362015
# 2020-12-18     1.0    8.688804
# 2020-12-24     0.0    0.322304
# 2020-12-30    22.0    4.354410
# 2021-01-05     1.0    8.657439
# 2021-01-11     6.0   10.270376
# 2021-01-17     5.0    4.297586
# 2021-01-23     1.0    4.930995
# 2021-01-29    32.0    7.411137
# 2021-02-04     6.0   14.091625
# 2021-02-10    15.0   17.057480
# 2021-02-16    12.0   14.651079
# 2021-02-22    36.0   22.561882
# 2021-02-28    14.0   18.908932
# 2021-03-06     9.0   13.067053
# 2021-03-12     7.0   11.620596
# 2021-03-18    12.0   12.781191
# 2021-03-24    26.0   16.320515
# 2021-03-30     7.0   12.914151
# 2021-04-05     4.0   10.275784
# 2021-04-11    25.0   11.156673
# 2021-04-17     6.0   12.571845

# %% [markdown]
# ### Visualization of Results

# %%
plt.rcParams["figure.figsize"] = [25, 6]

plt.plot(cnn_lstm_history.history['loss'], color = 'lightseagreen')
plt.plot(cnn_lstm_history.history['val_loss'], color = 'black')
plt.title('Loss vs Epoch', fontsize = 16)
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['Training Loss', 'Validation Loss'], loc='best', fontsize = 'large')
plt.show()

# %%
plt.rcParams["figure.figsize"] = [25, 6]

comparison_train.Deaths.plot(linewidth = 2, label = 'Actual', color = 'lightseagreen')
comparison_train.Prediction.plot(linewidth = 1, label = 'Prediction', color = 'black', linestyle = '--')
plt.legend(fontsize = 'large')
plt.ylabel('No of Deaths')
plt.title('Comparison of Actual and Prediction (Training Set): CNN-LSTM', fontsize = 16)
plt.show()

# %%
plt.rcParams["figure.figsize"] = [18, 6]

comparison.Deaths.plot(linewidth = 2, label = 'Actual', color = 'lightseagreen')
comparison.Prediction.plot(linewidth = 1, label = 'Prediction', color = 'black', linestyle = '--')
plt.legend(fontsize = 'large')
plt.ylabel('No of Deaths')
plt.title('Comparison of Actual and Prediction (Test Set): CNN-LSTM', fontsize = 16)
plt.show()

# %% [markdown]
# ### Evaluation Metrics: Training Set

# %%
# Define a function to calculate MAE and RMSE
from sklearn.metrics import mean_squared_log_error, mean_squared_error, mean_absolute_error, mean_absolute_percentage_error
from sklearn.metrics import r2_score

errors = comparison_train['Deaths'] - comparison_train['Prediction']
mse = np.square(errors).mean()
rmse = np.sqrt(mse)
mae = np.abs(errors).mean()
mape = np.abs(errors/comparison_train['Deaths']).mean() * 100
r2 = r2_score(comparison_train['Deaths'], comparison_train['Prediction'])

# %%
print('Mean Absolute Error: {:.4f}'.format(mae))
print('Mean Squared Error: {:.4f}'.format(mse))
print('Root Mean Square Error: {:.4f}'.format(rmse))
print('Mean Absolute Percentage Error: {:.4f}'.format(mape))
print('R2 Score: {:.4f}'.format(r2))
# Out:
# Mean Absolute Error: 6.5426
# Mean Squared Error: 82.2004
# Root Mean Square Error: 9.0664
# Mean Absolute Percentage Error: inf
# R2 Score: 0.1940

# %% [markdown]
# ### Evaluation Metrics: Validation Set

# %%
# Define a function to calculate MAE and RMSE
from sklearn.metrics import mean_squared_log_error, mean_squared_error, mean_absolute_error, mean_absolute_percentage_error
from sklearn.metrics import r2_score

errors = comparison['Deaths'] - comparison['Prediction']
mse = np.square(errors).mean()
rmse = np.sqrt(mse)
mae = np.abs(errors).mean()
mape = np.abs(errors/comparison['Deaths']).mean() * 100
r2 = r2_score(comparison['Deaths'], comparison['Prediction'])

# %%
print('Mean Absolute Error: {:.4f}'.format(mae))
print('Mean Squared Error: {:.4f}'.format(mse))
print('Root Mean Square Error: {:.4f}'.format(rmse))
print('Mean Absolute Percentage Error: {:.4f}'.format(mape))
print('R2 Score: {:.4f}'.format(r2))
# Out:
# Mean Absolute Error: 4.1237
# Mean Squared Error: 22.7163
# Root Mean Square Error: 4.7662
# Mean Absolute Percentage Error: 70.9072
# R2 Score: 0.6014

# %% [markdown]
# ### References
#
# * https://colab.research.google.com/github/phylypo/TimeSeriesPrediction/blob/main/Time_Series_DL_LSTM_CNN.ipynb#scrollTo=LXuSM4llqGag
