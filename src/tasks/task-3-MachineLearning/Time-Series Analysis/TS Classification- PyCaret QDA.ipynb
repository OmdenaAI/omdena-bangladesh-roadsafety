# %% [markdown]
# ## Time-Series Classification using PyCaret QDA: Dhaka Tribune
#
# Dataset: Dhaka Tribune 2021 Dataset
#
# Resampling Technique: Daily
#
# Author: Sumaia Parveen Shupti
#
# Created on: 07/15/2021
#
# Updated on: 07/18/2021

# %% [markdown]
# ### Import Libraries

# %%
#!pip install pycaret

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

from datetime import datetime, timedelta
import warnings
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier

from sklearn.metrics import f1_score,accuracy_score, precision_score, recall_score, roc_curve, roc_auc_score, precision_recall_curve, auc
from sklearn import metrics
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import plot_precision_recall_curve
from sklearn.metrics import average_precision_score, confusion_matrix
import matplotlib.pyplot as plt

# %matplotlib inline
warnings.filterwarnings("ignore")


plt.rcParams['figure.figsize'] = (12, 6)
colors = plt.rcParams['axes.prop_cycle'].by_key()['color']

# %% [markdown]
# ### Load Dataset

# %%
df = pd.read_csv('../input/dhakatribunecomplete/Dhaka Tribune Complete Data.csv')
df['Accident date'] = pd.to_datetime(df['Accident date'])

df = df[['Accident date', 'Deaths']]
df = df.sort_values(by = 'Accident date')
df = df.reset_index(drop = True).set_index('Accident date').resample('1D').sum()
df = df.reset_index()
df['Deaths'] = df['Deaths'].fillna(0)
print(df.shape)
df.head(12)
# Out:
# (1829, 2)
#    Accident date  Deaths
# 0     2016-06-24     3.0
# 1     2016-06-25     0.0
# 2     2016-06-26     0.0
# 3     2016-06-27     0.0
# 4     2016-06-28     0.0
# 5     2016-06-29     0.0
# 6     2016-06-30     0.0
# 7     2016-07-01     0.0
# 8     2016-07-02     0.0
# 9     2016-07-03     0.0
# 10    2016-07-04     0.0
# 11    2016-07-05     0.0

# %% [markdown]
# ### Feature Enginnering

# %%
df['Accident date'] = pd.to_datetime(df['Accident date'])
df['Year'] = df['Accident date'].dt.year
df['Month'] = df['Accident date'].dt.month
df['Day'] = df['Accident date'].dt.day
df['DayofWeek'] = df['Accident date'].dt.weekday
df['Weekend_(y/n)'] = ((df['Accident date'].dt.dayofweek) // 5 == 1).astype(float)
df['DayofYear'] = df['Accident date'].dt.dayofyear
# Convert the date into a number (of days since some point)
fromDate = min(df['Accident date'])
df['DateInt'] = (df['Accident date'] - fromDate).astype(np.int64)/100000000000
df.head()
# Out:
#   Accident date  Deaths  Year  Month  Day  DayofWeek  Weekend_(y/n)  \
# 0    2016-06-24     3.0  2016      6   24          4            0.0
# 1    2016-06-25     0.0  2016      6   25          5            1.0
# 2    2016-06-26     0.0  2016      6   26          6            1.0
# 3    2016-06-27     0.0  2016      6   27          0            0.0
# 4    2016-06-28     0.0  2016      6   28          1            0.0
#
#    DayofYear  DateInt
# 0        176      0.0
# 1        177    864.0
# 2        178   1728.0
# 3        179   2592.0
# 4        180   3456.0

# %% [markdown]
# ### Binary Classification maybe?

# %%
# create a new column and use np.select to assign values to it using our lists as arguments
df['deathYorN'] = np.select([df['Deaths'] > 0], [1])

# display updated DataFrame
df.head(12)
# Out:
#    Accident date  Deaths  Year  Month  Day  DayofWeek  Weekend_(y/n)  \
# 0     2016-06-24     3.0  2016      6   24          4            0.0
# 1     2016-06-25     0.0  2016      6   25          5            1.0
# 2     2016-06-26     0.0  2016      6   26          6            1.0
# 3     2016-06-27     0.0  2016      6   27          0            0.0
# 4     2016-06-28     0.0  2016      6   28          1            0.0
# 5     2016-06-29     0.0  2016      6   29          2            0.0
# 6     2016-06-30     0.0  2016      6   30          3            0.0
# 7     2016-07-01     0.0  2016      7    1          4            0.0
# 8     2016-07-02     0.0  2016      7    2          5            1.0
# 9     2016-07-03     0.0  2016      7    3          6            1.0
# 10    2016-07-04     0.0  2016      7    4          0            0.0
# 11    2016-07-05     0.0  2016      7    5          1            0.0
#
#     DayofYear  DateInt  deathYorN
# 0         176      0.0          1
# 1         177    864.0          0
# 2         178   1728.0          0
# 3         179   2592.0          0
# 4         180   3456.0          0
# 5         181   4320.0          0
# 6         182   5184.0          0
# 7         183   6048.0          0
# 8         184   6912.0          0
# 9         185   7776.0          0
# 10        186   8640.0          0
# 11        187   9504.0          0

# %%
df.dtypes
# Out:
# Accident date    datetime64[ns]
# Deaths                  float64
# Year                      int64
# Month                     int64
# Day                       int64
# DayofWeek                 int64
# Weekend_(y/n)           float64
# DayofYear                 int64
# DateInt                 float64
# deathYorN                 int64
# dtype: object

# %% [markdown]
# ### Feature Corelation

# %%
import seaborn as sns

correlation = df.corr()

mask = np.zeros_like(correlation, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

f, ax = plt.subplots(figsize=(10, 10))

cmap = sns.diverging_palette(180, 20, as_cmap=True)
sns.heatmap(correlation, mask=mask, cmap=cmap, vmax=1, vmin =-1, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5}, annot=True)

plt.show()

# %% [markdown]
# ### Train Test Split

# %%
start_ = df['Accident date'].max()
end_ = df['Accident date'].min()

test_end = df['Accident date'].max()
test_start = df['Accident date'].max() - timedelta(days = 90)

train_end = test_start - timedelta(days = 1)
train_start = train_end - timedelta(days = 90*8)

print('Dataset Start Date: {}'.format(start_))
print('Dataset End Date: {}'.format(end_))
print (' ')
print('Train Set Start Date: {}'.format(train_start))
print('Train Set End Date: {}'.format(train_end))
print (' ')
print('Test Set Start Date: {}'.format(test_start))
print('Test Set End Date: {}'.format(test_end))
print (' ')
# Out:
# Dataset Start Date: 2021-06-26 00:00:00
# Dataset End Date: 2016-06-24 00:00:00
#
# Train Set Start Date: 2019-04-07 00:00:00
# Train Set End Date: 2021-03-27 00:00:00
#
# Test Set Start Date: 2021-03-28 00:00:00
# Test Set End Date: 2021-06-26 00:00:00

# %%
mask = (df['Accident date'] > train_start) & (df['Accident date'] <= train_end)
train = df.loc[mask]
train = train.drop('Accident date', 1)
train = train.drop('Deaths', 1)

mask = (df['Accident date'] > test_start) & (df['Accident date'] <= test_end)
test = df.loc[mask]
test = test.drop('Accident date', 1)
test = test.drop('Deaths', 1)

# %%
train.tail()
# Out:
#       Year  Month  Day  DayofWeek  Weekend_(y/n)  DayofYear    DateInt  \
# 1733  2021      3   23          1            0.0         82  1497312.0
# 1734  2021      3   24          2            0.0         83  1498176.0
# 1735  2021      3   25          3            0.0         84  1499040.0
# 1736  2021      3   26          4            0.0         85  1499904.0
# 1737  2021      3   27          5            1.0         86  1500768.0
#
#       deathYorN
# 1733          0
# 1734          0
# 1735          0
# 1736          1
# 1737          0

# %%
test.head()
# Out:
#       Year  Month  Day  DayofWeek  Weekend_(y/n)  DayofYear    DateInt  \
# 1739  2021      3   29          0            0.0         88  1502496.0
# 1740  2021      3   30          1            0.0         89  1503360.0
# 1741  2021      3   31          2            0.0         90  1504224.0
# 1742  2021      4    1          3            0.0         91  1505088.0
# 1743  2021      4    2          4            0.0         92  1505952.0
#
#       deathYorN
# 1739          0
# 1740          0
# 1741          1
# 1742          0
# 1743          0

# %%
# Train-Test Split
X_train = train.drop('deathYorN', axis = 1) 
y_train = train[['deathYorN']]

X_test = test.drop('deathYorN', axis = 1) 
y_test = test[['deathYorN']]

# %% [markdown]
# ### Creating Synthetic Samples

# %%
# import SMOTE 
from imblearn.over_sampling import SMOTE
sm = SMOTE(random_state = 25, sampling_strategy='auto')   # again we are eqalizing both the classes

# fit the sampling
X_train, y_train = sm.fit_resample(X_train, y_train)
np.unique(y_train, return_counts=True)     # Y_train is numpy array, so unique() functions returns the count of all the unique elements in the array

from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %% [markdown]
# ### Count of Classes

# %%
sns.countplot(y_train.deathYorN, palette = "Set2")
# Out:
# <AxesSubplot:xlabel='deathYorN', ylabel='count'>

# %% [markdown]
# ### PyCaret Implementation

# %%
from pycaret.classification import *
exp_clf101 = setup(data = train, target = 'deathYorN', session_id=123)
# Out:
# <style  type="text/css" >
# #T_1e49f_row44_col1{
#             background-color:  lightgreen;
#         }</style><table id="T_1e49f_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1e49f_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_1e49f_row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_1e49f_row0_col1" class="data row0 col1" >123</td>
#             </tr>
#             <tr>
#                         <th id="T_1e49f_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_1e49f_row1_col0" class="data row1 col0" >Target</td>
#                         <td id="T_1e49f_row1_col1" class="data row1 col1" >deathYorN</td>
#             </tr>
#             <tr>
#                         <th id="T_1e49f_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_1e49f_row2_col0" class="data row2 col0" >Target Type</td>
#                         <td id="T_1e49f_row2_col1" class="data row2 col1" >Binary</td>
#             </tr>
#             <tr>
#                         <th id="T_1e49f_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_1e49f_row3_col0" class="data row3 col0" >Label Encoded</td>
#                         <td id="T_1e49f_row3_col1" class="data row3 col1" >0: 0, 1: 1</td>
#             </tr>
#             <tr>
#                         <th id="T_1e49f_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_1e49f_row4_col0" class="data row4 col0" >Original Data</td>
#                         <td id="T_1e49f_row4_col1" class="data row4 col1" >(720, 8)</td>
#             </tr>
#             <tr>
#                         <th id="T_1e49f_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_1e49f_row5_col0" class="data row5 col0" >Missing Values</td>
#                         <td id="T_1e49f_row5_col1" class="data row5 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_1e49f_level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_1e49f_row6_col0" class="data row6 col0" >Numeric Features</td>
#                         <td id="T_1e49f_row6_col1" class="data row6 col1" >3</td>
#             </tr>
#             <tr>
#                         <th id="T_1e49f_level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_1e49f_row7_col0" class="data row7 col0" >Categorical Features</td>
#                         <td id="T_1e49f_row7_col1" class="data row7 col1" >4</td>
#             </tr>
#             <tr>
#                         <th id="T_1e49f_level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_1e49f_row8_col0" class="data row8 col0" >Ordinal Features</td>
#                         <td id="T_1e49f_row8_col1" class="data row8 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_1e49f_level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_1e49f_row9_col0" class="data row9 col0" >High Cardinality Features</td>
#                         <td id="T_1e49f_row9_col1" class="data row9 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_1e49f_level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_1e49f_row10_col0" class="data row10 col0" >High Cardinality Method</td>
#                         <td id="T_1e49f_row10_col1" class="data row10 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_1e49f_level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_1e49f_row11_col0" class="data row11 col0" >Transformed Train Set</td>
#                         <td id="T_1e49f_row11_col1" class="data row11 col1" >(503, 26)</td>
#             </tr>
#             <tr>
#                         <th id="T_1e49f_level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_1e49f_row12_col0" class="data row12 col0" >Transformed Test Set</td>
#                         <td id="T_1e49f_row12_col1" class="data row12 col1" >(217, 26)</td>
#             </tr>
#             <tr>
#                         <th id="T_1e49f_level0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_1e49f_row13_col0" class="data row13 col0" >Shuffle Train-Test</td>
#                         <td id="T_1e49f_row13_col1" class="data row13 col1" >True</td>
#             </tr>
#             <tr>
#                         <th id="T_1e49f_level0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_1e49f_row14_col0" class="data row14 col0" >Stratify Train-Test</td>
#                         <td id="T_1e49f_row14_col1" class="data row14 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_1e49f_level0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_1e49f_row15_col0" class="data row15 col0" >Fold Generator</td>
#                         <td id="T_1e49f_row15_col1" class="data row15 col1" >StratifiedKFold</td>
#             </tr>
#             <tr>
#                         <th id="T_1e49f_level0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_1e49f_row16_col0" class="data row16 col0" >Fold Number</td>
#                         <td id="T_1e49f_row16_col1" class="data row16 col1" >10</td>
#             </tr>
#             <tr>
#                         <th id="T_1e49f_level0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_1e49f_row17_col0" class="data row17 col0" >CPU Jobs</td>
#                         <td id="T_1e49f_row17_col1" class="data row17 col1" >-1</td>
#             </tr>
#             <tr>
#                         <th id="T_1e49f_level0_row18" class="row_heading level0 row18" >18</th>
#                         <td id="T_1e49f_row18_col0" class="data row18 col0" >Use GPU</td>
#                         <td id="T_1e49f_row18_col1" class="data row18 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_1e49f_level0_row19" class="row_heading level0 row19" >19</th>
#                         <td id="T_1e49f_row19_col0" class="data row19 col0" >Log Experiment</td>
#                         <td id="T_1e49f_row19_col1" class="data row19 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_1e49f_level0_row20" class="row_heading level0 row20" >20</th>
#                         <td id="T_1e49f_row20_col0" class="data row20 col0" >Experiment Name</td>
#                         <td id="T_1e49f_row20_col1" class="data row20 col1" >clf-default-name</td>
#             </tr>
#             <tr>
#                         <th id="T_1e49f_level0_row21" class="row_heading level0 row21" >21</th>
#                         <td id="T_1e49f_row21_col0" class="data row21 col0" >USI</td>
#                         <td id="T_1e49f_row21_col1" class="data row21 col1" >960c</td>
#             </tr>
#             <tr>
#                         <th id="T_1e49f_level0_row22" class="row_heading level0 row22" >22</th>
#                         <td id="T_1e49f_row22_col0" class="data row22 col0" >Imputation Type</td>
#                         <td id="T_1e49f_row22_col1" class="data row22 col1" >simple</td>
#             </tr>
#             <tr>
#                         <th id="T_1e49f_level0_row23" class="row_heading level0 row23" >23</th>
#                         <td id="T_1e49f_row23_col0" class="data row23 col0" >Iterative Imputation Iteration</td>
#                         <td id="T_1e49f_row23_col1" class="data row23 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_1e49f_level0_row24" class="row_heading level0 row24" >24</

# %% [markdown]
# ### Comparing the model for Best Recall Score

# %%
# %%time
best = compare_models(sort = 'Recall')
# Out:
# <style  type="text/css" >
#     #T_68c72_ th {
#           text-align: left;
#     }#T_68c72_row0_col0,#T_68c72_row0_col1,#T_68c72_row0_col2,#T_68c72_row0_col4,#T_68c72_row0_col6,#T_68c72_row0_col7,#T_68c72_row1_col0,#T_68c72_row1_col1,#T_68c72_row1_col2,#T_68c72_row1_col3,#T_68c72_row1_col4,#T_68c72_row1_col5,#T_68c72_row1_col6,#T_68c72_row1_col7,#T_68c72_row2_col0,#T_68c72_row2_col1,#T_68c72_row2_col2,#T_68c72_row2_col3,#T_68c72_row2_col4,#T_68c72_row2_col5,#T_68c72_row2_col6,#T_68c72_row2_col7,#T_68c72_row3_col0,#T_68c72_row3_col1,#T_68c72_row3_col2,#T_68c72_row3_col3,#T_68c72_row3_col4,#T_68c72_row3_col5,#T_68c72_row3_col6,#T_68c72_row3_col7,#T_68c72_row4_col0,#T_68c72_row4_col1,#T_68c72_row4_col2,#T_68c72_row4_col3,#T_68c72_row4_col4,#T_68c72_row4_col5,#T_68c72_row4_col6,#T_68c72_row4_col7,#T_68c72_row5_col0,#T_68c72_row5_col1,#T_68c72_row5_col2,#T_68c72_row5_col3,#T_68c72_row5_col4,#T_68c72_row5_col5,#T_68c72_row5_col6,#T_68c72_row5_col7,#T_68c72_row6_col0,#T_68c72_row6_col1,#T_68c72_row6_col2,#T_68c72_row6_col3,#T_68c72_row6_col4,#T_68c72_row6_col5,#T_68c72_row6_col6,#T_68c72_row6_col7,#T_68c72_row7_col0,#T_68c72_row7_col1,#T_68c72_row7_col2,#T_68c72_row7_col3,#T_68c72_row7_col4,#T_68c72_row7_col5,#T_68c72_row7_col6,#T_68c72_row7_col7,#T_68c72_row8_col0,#T_68c72_row8_col1,#T_68c72_row8_col2,#T_68c72_row8_col3,#T_68c72_row8_col4,#T_68c72_row8_col5,#T_68c72_row8_col6,#T_68c72_row8_col7,#T_68c72_row9_col0,#T_68c72_row9_col1,#T_68c72_row9_col2,#T_68c72_row9_col3,#T_68c72_row9_col4,#T_68c72_row9_col5,#T_68c72_row9_col6,#T_68c72_row9_col7,#T_68c72_row10_col0,#T_68c72_row10_col1,#T_68c72_row10_col2,#T_68c72_row10_col3,#T_68c72_row10_col4,#T_68c72_row10_col5,#T_68c72_row10_col6,#T_68c72_row10_col7,#T_68c72_row11_col0,#T_68c72_row11_col1,#T_68c72_row11_col2,#T_68c72_row11_col3,#T_68c72_row11_col4,#T_68c72_row11_col5,#T_68c72_row11_col7,#T_68c72_row12_col0,#T_68c72_row12_col1,#T_68c72_row12_col2,#T_68c72_row12_col3,#T_68c72_row12_col4,#T_68c72_row12_col5,#T_68c72_row12_col6,#T_68c72_row12_col7,#T_68c72_row13_col0,#T_68c72_row13_col3,#T_68c72_row13_col5,#T_68c72_row13_col6,#T_68c72_row14_col0,#T_68c72_row14_col1,#T_68c72_row14_col2,#T_68c72_row14_col3,#T_68c72_row14_col4,#T_68c72_row14_col5,#T_68c72_row14_col6,#T_68c72_row14_col7{
#             text-align:  left;
#             text-align:  left;
#         }#T_68c72_row0_col3,#T_68c72_row0_col5,#T_68c72_row11_col6,#T_68c72_row13_col1,#T_68c72_row13_col2,#T_68c72_row13_col4,#T_68c72_row13_col7{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }#T_68c72_row0_col8,#T_68c72_row1_col8,#T_68c72_row2_col8,#T_68c72_row3_col8,#T_68c72_row4_col8,#T_68c72_row5_col8,#T_68c72_row6_col8,#T_68c72_row7_col8,#T_68c72_row8_col8,#T_68c72_row9_col8,#T_68c72_row10_col8,#T_68c72_row11_col8,#T_68c72_row12_col8,#T_68c72_row14_col8{
#             text-align:  left;
#             text-align:  left;
#             background-color:  lightgrey;
#         }#T_68c72_row13_col8{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#             background-color:  lightgrey;
#         }</style><table id="T_68c72_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >Accuracy</th>        <th class="col_heading level0 col2" >AUC</th>        <th class="col_heading level0 col3" >Recall</th>        <th class="col_heading level0 col4" >Prec.</th>        <th class="col_heading level0 col5" >F1</th>        <th class="col_heading level0 col6" >Kappa</th>        <th class="col_heading level0 col7" >MCC</th>        <th class="col_heading level0 col8" >TT (Sec)</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_68c72_level0_row0" class="row_heading level0 row0" >qda</th>
#                         <td id="T_68c72_row0_col0" class="data row0 col0" >Quadratic Discriminant Analysis</td>
#                         <td id="T_68c72_row0_col1" class="data row0 col1" >0.5346</td>
#                         <td id="T_68c72_row0_col2" class="data row0 col2" >0.5359</td>
#                         <td id="T_68c72_row0_col3" class="data row0 col3" >0.5405</td>
#                         <td id="T_68c72_row0_col4" class="data row0 col4" >0.3810</td>
#                         <td id="T_68c72_row0_col5" class="data row0 col5" >0.4369</td>
#                         <td id="T_68c72_row0_col6" class="data row0 col6" >0.0625</td>
#                         <td id="T_68c72_row0_col7" class="data row0 col7" >0.0683</td>
#                         <td id="T_68c72_row0_col8" class="data row0 col8" >0.0120</td>
#             </tr>
#             <tr>
#                         <th id="T_68c72_level0_row1" class="row_heading level0 row1" >svm</th>
#                         <td id="T_68c72_row1_col0" class="data row1 col0" >SVM - Linear Kernel</td>
#                         <td id="T_68c72_row1_col1" class="data row1 col1" >0.4953</td>
#                         <td id="T_68c72_row1_col2" class="data row1 col2" >0.0000</td>
#                         <td id="T_68c72_row1_col3" class="data row1 col3" >0.5000</td>
#                         <td id="T_68c72_row1_col4" class="data row1 col4" >0.1746</td>
#                         <td id="T_68c72_row1_col5" class="data row1 col5" >0.2588</td>
#                         <td id="T_68c72_row1_col6" class="data row1 col6" >0.0000</td>
#                         <td id="T_68c72_row1_col7" class="data row1 col7" >0.0000</td>
#                         <td id="T_68c72_row1_col8" class="data row1 col8" >0.0130</td>
#             </tr>
#             <tr>
#                         <th id="T_68c72_level0_row2" class="row_heading level0 row2" >dt</th>
#                         <td id="T_68c72_row2_col0" class="data row2 col0" >Decision Tree Classifier</td>
#                         <td id="T_68c72_row2_col1" class="data row2 col1" >0.5485</td>
#                         <td id="T_68c72_row2_col2" class="data row2 col2" >0.5161</td>
#                         <td id="T_68c72_row2_col3" class="data row2 col3" >0.4046</td>
#                         <td id="T_68c72_row2_col4" class="data row2 col4" >0.3830</td>
#                         <td id="T_68c72_row2_col5" class="data row2 col5" >0.3865</td>
#                         <td id="T_68c72_row2_col6" class="data row2 col6" >0.0348</td>
#                         <td id="T_68c72_row2_col7" class="data row2 col7" >0.0355</td>
#                         <td id="T_68c72_row2_col8" class="data row2 col8" >0.0120</td>
#             </tr>
#             <tr>
#                         <th id="T_68c72_level0_row3" class="row_heading level0 row3" >et</th>
#                         <td id="T_68c72_row3_col0" class="data row3 col0" >Extra Trees Classifier</td>
#                         <td id="T_68c72_row3_col1" class="data row3 col1" >0.5687</td>
#                         <td id="T_68c72_row3_col2" class="data row3 col2" >0.5492</td>
#                         <td id="T_68c72_row3_col3" class="data row3 col3" >0.3484</td>
#                         <td id="T_68c72_row3_col4" class="data row3 col4" >0.3892</td>
#                         <td id="T_68c72_row3_col5" class="data row3 col5" >0.3632</td>
#                         <td id="T_68c72_row3_col6" class="data row3 col6" >0.0412</td>
#                         <td id="T_68c72_row3_col7" class="data row3 col7" >0.0425</td>
#                         <td id="T_68c72_row3_col8" class="data row3 col8" >0.2900</td>
#             </tr>
#             <tr>
#                         <th id="T_68c72_level0_row4" class="row_heading level0 row4" >lda</th>
#                         <td id="T_68c72_row4_col0" class="data row4 col0" >Linear Discriminant Analysis</td>
#                         <td id="T_68c72_row4_col1" class="data row4 col1" >0.6362</td>
#                         <td id="T_68c72_row4_col2" class="data row4 col2" >0.6401</td>
#                         <td id="T_68c72_row4_col3" class="data row4 col3" >0.3314</td>
#                         <td id="T_68c72_row4_col4"
# CPU times: user 6.49 s, sys: 228 ms, total: 6.72 s
# Wall time: 2min 30s

# %%
qda = create_model('qda')
# Out:
# <style  type="text/css" >
# #T_e5b3d_row10_col0,#T_e5b3d_row10_col1,#T_e5b3d_row10_col2,#T_e5b3d_row10_col3,#T_e5b3d_row10_col4,#T_e5b3d_row10_col5,#T_e5b3d_row10_col6{
#             background:  yellow;
#         }</style><table id="T_e5b3d_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e5b3d_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_e5b3d_row0_col0" class="data row0 col0" >0.5490</td>
#                         <td id="T_e5b3d_row0_col1" class="data row0 col1" >0.4874</td>
#                         <td id="T_e5b3d_row0_col2" class="data row0 col2" >0.2778</td>
#                         <td id="T_e5b3d_row0_col3" class="data row0 col3" >0.3333</td>
#                         <td id="T_e5b3d_row0_col4" class="data row0 col4" >0.3030</td>
#                         <td id="T_e5b3d_row0_col5" class="data row0 col5" >-0.0262</td>
#                         <td id="T_e5b3d_row0_col6" class="data row0 col6" >-0.0265</td>
#             </tr>
#             <tr>
#                         <th id="T_e5b3d_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_e5b3d_row1_col0" class="data row1 col0" >0.5686</td>
#                         <td id="T_e5b3d_row1_col1" class="data row1 col1" >0.5278</td>
#                         <td id="T_e5b3d_row1_col2" class="data row1 col2" >0.3889</td>
#                         <td id="T_e5b3d_row1_col3" class="data row1 col3" >0.3889</td>
#                         <td id="T_e5b3d_row1_col4" class="data row1 col4" >0.3889</td>
#                         <td id="T_e5b3d_row1_col5" class="data row1 col5" >0.0556</td>
#                         <td id="T_e5b3d_row1_col6" class="data row1 col6" >0.0556</td>
#             </tr>
#             <tr>
#                         <th id="T_e5b3d_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_e5b3d_row2_col0" class="data row2 col0" >0.5882</td>
#                         <td id="T_e5b3d_row2_col1" class="data row2 col1" >0.5934</td>
#                         <td id="T_e5b3d_row2_col2" class="data row2 col2" >0.6111</td>
#                         <td id="T_e5b3d_row2_col3" class="data row2 col3" >0.4400</td>
#                         <td id="T_e5b3d_row2_col4" class="data row2 col4" >0.5116</td>
#                         <td id="T_e5b3d_row2_col5" class="data row2 col5" >0.1717</td>
#                         <td id="T_e5b3d_row2_col6" class="data row2 col6" >0.1786</td>
#             </tr>
#             <tr>
#                         <th id="T_e5b3d_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_e5b3d_row3_col0" class="data row3 col0" >0.6000</td>
#                         <td id="T_e5b3d_row3_col1" class="data row3 col1" >0.6114</td>
#                         <td id="T_e5b3d_row3_col2" class="data row3 col2" >0.6471</td>
#                         <td id="T_e5b3d_row3_col3" class="data row3 col3" >0.4400</td>
#                         <td id="T_e5b3d_row3_col4" class="data row3 col4" >0.5238</td>
#                         <td id="T_e5b3d_row3_col5" class="data row3 col5" >0.2000</td>
#                         <td id="T_e5b3d_row3_col6" class="data row3 col6" >0.2111</td>
#             </tr>
#             <tr>
#                         <th id="T_e5b3d_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_e5b3d_row4_col0" class="data row4 col0" >0.5400</td>
#                         <td id="T_e5b3d_row4_col1" class="data row4 col1" >0.5660</td>
#                         <td id="T_e5b3d_row4_col2" class="data row4 col2" >0.6471</td>
#                         <td id="T_e5b3d_row4_col3" class="data row4 col3" >0.3929</td>
#                         <td id="T_e5b3d_row4_col4" class="data row4 col4" >0.4889</td>
#                         <td id="T_e5b3d_row4_col5" class="data row4 col5" >0.1140</td>
#                         <td id="T_e5b3d_row4_col6" class="data row4 col6" >0.1259</td>
#             </tr>
#             <tr>
#                         <th id="T_e5b3d_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_e5b3d_row5_col0" class="data row5 col0" >0.5400</td>
#                         <td id="T_e5b3d_row5_col1" class="data row5 col1" >0.4948</td>
#                         <td id="T_e5b3d_row5_col2" class="data row5 col2" >0.3333</td>
#                         <td id="T_e5b3d_row5_col3" class="data row5 col3" >0.3529</td>
#                         <td id="T_e5b3d_row5_col4" class="data row5 col4" >0.3429</td>
#                         <td id="T_e5b3d_row5_col5" class="data row5 col5" >-0.0105</td>
#                         <td id="T_e5b3d_row5_col6" class="data row5 col6" >-0.0106</td>
#             </tr>
#             <tr>
#                         <th id="T_e5b3d_level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_e5b3d_row6_col0" class="data row6 col0" >0.6400</td>
#                         <td id="T_e5b3d_row6_col1" class="data row6 col1" >0.6580</td>
#                         <td id="T_e5b3d_row6_col2" class="data row6 col2" >0.7222</td>
#                         <td id="T_e5b3d_row6_col3" class="data row6 col3" >0.5000</td>
#                         <td id="T_e5b3d_row6_col4" class="data row6 col4" >0.5909</td>
#                         <td id="T_e5b3d_row6_col5" class="data row6 col5" >0.2880</td>
#                         <td id="T_e5b3d_row6_col6" class="data row6 col6" >0.3036</td>
#             </tr>
#             <tr>
#                         <th id="T_e5b3d_level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_e5b3d_row7_col0" class="data row7 col0" >0.4400</td>
#                         <td id="T_e5b3d_row7_col1" class="data row7 col1" >0.5260</td>
#                         <td id="T_e5b3d_row7_col2" class="data row7 col2" >0.8333</td>
#                         <td id="T_e5b3d_row7_col3" class="data row7 col3" >0.3750</td>
#                         <td id="T_e5b3d_row7_col4" class="data row7 col4" >0.5172</td>
#                         <td id="T_e5b3d_row7_col5" class="data row7 col5" >0.0411</td>
#                         <td id="T_e5b3d_row7_col6" class="data row7 col6" >0.0625</td>
#             </tr>
#             <tr>
#                         <th id="T_e5b3d_level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_e5b3d_row8_col0" class="data row8 col0" >0.4200</td>
#                         <td id="T_e5b3d_row8_col1" class="data row8 col1" >0.4861</td>
#                         <td id="T_e5b3d_row8_col2" class="data row8 col2" >0.7222</td>
#                         <td id="T_e5b3d_row8_col3" class="data row8 col3" >0.3514</td>
#                         <td id="T_e5b3d_row8_col4" class="data row8 col4" >0.4727</td>
#                         <td id="T_e5b3d_row8_col5" class="data row8 col5" >-0.0226</td>
#                         <td id="T_e5b3d_row8_col6" class="data row8 col6" >-0.0304</td>
#             </tr>
#             <tr>
#                         <th id="T_e5b3d_level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_e5b3d_row9_col0" class="data row9 col0" >0.4600</td>
#                         <td id="T_e5b3d_row9_col1" class="data row9 col1" >0.4080</td>
#                         <td id="T_e5b3d_row9_col2" class="data row9 col2" >0.2222</td>
#                         <td id="T_e5b3d_row9_col3" class="data row9 col3" >0.2353</td>
#                         <td id="T_e5b3d_row9_col4" class="data row9 col4" >0.2286</td>
#                         <td id="T_e5b3d_row9_col5" class="data row9 col5" >-0.1863</td>

# %%
tuned_qda = tune_model(qda, optimize = 'Recall')
# Out:
# <style  type="text/css" >
# #T_646c5_row10_col0,#T_646c5_row10_col1,#T_646c5_row10_col2,#T_646c5_row10_col3,#T_646c5_row10_col4,#T_646c5_row10_col5,#T_646c5_row10_col6{
#             background:  yellow;
#         }</style><table id="T_646c5_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_646c5_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_646c5_row0_col0" class="data row0 col0" >0.5490</td>
#                         <td id="T_646c5_row0_col1" class="data row0 col1" >0.6406</td>
#                         <td id="T_646c5_row0_col2" class="data row0 col2" >0.7222</td>
#                         <td id="T_646c5_row0_col3" class="data row0 col3" >0.4194</td>
#                         <td id="T_646c5_row0_col4" class="data row0 col4" >0.5306</td>
#                         <td id="T_646c5_row0_col5" class="data row0 col5" >0.1518</td>
#                         <td id="T_646c5_row0_col6" class="data row0 col6" >0.1730</td>
#             </tr>
#             <tr>
#                         <th id="T_646c5_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_646c5_row1_col0" class="data row1 col0" >0.5098</td>
#                         <td id="T_646c5_row1_col1" class="data row1 col1" >0.7003</td>
#                         <td id="T_646c5_row1_col2" class="data row1 col2" >0.8333</td>
#                         <td id="T_646c5_row1_col3" class="data row1 col3" >0.4054</td>
#                         <td id="T_646c5_row1_col4" class="data row1 col4" >0.5455</td>
#                         <td id="T_646c5_row1_col5" class="data row1 col5" >0.1344</td>
#                         <td id="T_646c5_row1_col6" class="data row1 col6" >0.1785</td>
#             </tr>
#             <tr>
#                         <th id="T_646c5_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_646c5_row2_col0" class="data row2 col0" >0.5490</td>
#                         <td id="T_646c5_row2_col1" class="data row2 col1" >0.5522</td>
#                         <td id="T_646c5_row2_col2" class="data row2 col2" >0.6111</td>
#                         <td id="T_646c5_row2_col3" class="data row2 col3" >0.4074</td>
#                         <td id="T_646c5_row2_col4" class="data row2 col4" >0.4889</td>
#                         <td id="T_646c5_row2_col5" class="data row2 col5" >0.1134</td>
#                         <td id="T_646c5_row2_col6" class="data row2 col6" >0.1209</td>
#             </tr>
#             <tr>
#                         <th id="T_646c5_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_646c5_row3_col0" class="data row3 col0" >0.6400</td>
#                         <td id="T_646c5_row3_col1" class="data row3 col1" >0.6301</td>
#                         <td id="T_646c5_row3_col2" class="data row3 col2" >0.5294</td>
#                         <td id="T_646c5_row3_col3" class="data row3 col3" >0.4737</td>
#                         <td id="T_646c5_row3_col4" class="data row3 col4" >0.5000</td>
#                         <td id="T_646c5_row3_col5" class="data row3 col5" >0.2201</td>
#                         <td id="T_646c5_row3_col6" class="data row3 col6" >0.2209</td>
#             </tr>
#             <tr>
#                         <th id="T_646c5_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_646c5_row4_col0" class="data row4 col0" >0.4000</td>
#                         <td id="T_646c5_row4_col1" class="data row4 col1" >0.4216</td>
#                         <td id="T_646c5_row4_col2" class="data row4 col2" >0.5294</td>
#                         <td id="T_646c5_row4_col3" class="data row4 col3" >0.2903</td>
#                         <td id="T_646c5_row4_col4" class="data row4 col4" >0.3750</td>
#                         <td id="T_646c5_row4_col5" class="data row4 col5" >-0.1144</td>
#                         <td id="T_646c5_row4_col6" class="data row4 col6" >-0.1340</td>
#             </tr>
#             <tr>
#                         <th id="T_646c5_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_646c5_row5_col0" class="data row5 col0" >0.5400</td>
#                         <td id="T_646c5_row5_col1" class="data row5 col1" >0.6267</td>
#                         <td id="T_646c5_row5_col2" class="data row5 col2" >0.5000</td>
#                         <td id="T_646c5_row5_col3" class="data row5 col3" >0.3913</td>
#                         <td id="T_646c5_row5_col4" class="data row5 col4" >0.4390</td>
#                         <td id="T_646c5_row5_col5" class="data row5 col5" >0.0589</td>
#                         <td id="T_646c5_row5_col6" class="data row5 col6" >0.0602</td>
#             </tr>
#             <tr>
#                         <th id="T_646c5_level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_646c5_row6_col0" class="data row6 col0" >0.6800</td>
#                         <td id="T_646c5_row6_col1" class="data row6 col1" >0.7743</td>
#                         <td id="T_646c5_row6_col2" class="data row6 col2" >0.8333</td>
#                         <td id="T_646c5_row6_col3" class="data row6 col3" >0.5357</td>
#                         <td id="T_646c5_row6_col4" class="data row6 col4" >0.6522</td>
#                         <td id="T_646c5_row6_col5" class="data row6 col5" >0.3808</td>
#                         <td id="T_646c5_row6_col6" class="data row6 col6" >0.4130</td>
#             </tr>
#             <tr>
#                         <th id="T_646c5_level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_646c5_row7_col0" class="data row7 col0" >0.5400</td>
#                         <td id="T_646c5_row7_col1" class="data row7 col1" >0.5781</td>
#                         <td id="T_646c5_row7_col2" class="data row7 col2" >0.5556</td>
#                         <td id="T_646c5_row7_col3" class="data row7 col3" >0.4000</td>
#                         <td id="T_646c5_row7_col4" class="data row7 col4" >0.4651</td>
#                         <td id="T_646c5_row7_col5" class="data row7 col5" >0.0800</td>
#                         <td id="T_646c5_row7_col6" class="data row7 col6" >0.0833</td>
#             </tr>
#             <tr>
#                         <th id="T_646c5_level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_646c5_row8_col0" class="data row8 col0" >0.5000</td>
#                         <td id="T_646c5_row8_col1" class="data row8 col1" >0.6571</td>
#                         <td id="T_646c5_row8_col2" class="data row8 col2" >0.5556</td>
#                         <td id="T_646c5_row8_col3" class="data row8 col3" >0.3704</td>
#                         <td id="T_646c5_row8_col4" class="data row8 col4" >0.4444</td>
#                         <td id="T_646c5_row8_col5" class="data row8 col5" >0.0219</td>
#                         <td id="T_646c5_row8_col6" class="data row8 col6" >0.0234</td>
#             </tr>
#             <tr>
#                         <th id="T_646c5_level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_646c5_row9_col0" class="data row9 col0" >0.6200</td>
#                         <td id="T_646c5_row9_col1" class="data row9 col1" >0.7083</td>
#                         <td id="T_646c5_row9_col2" class="data row9 col2" >0.7778</td>
#                         <td id="T_646c5_row9_col3" class="data row9 col3" >0.4828</td>
#                         <td id="T_646c5_row9_col4" class="data row9 col4" >0.5957</td>
#                         <td id="T_646c5_row9_col5" class="data row9 col5" >0.2726</td>
#                         <td i

# %% [markdown]
# ### Confusion Matrix for the Training Set

# %%
plot_model(tuned_qda, plot = 'confusion_matrix')

# %%
plot_model(tuned_qda, plot = 'auc')

# %%
plot_model(tuned_qda, plot = 'pr')

# %%
predict_model(tuned_qda);
# Out:
# <style  type="text/css" >
# </style><table id="T_25e53_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >Accuracy</th>        <th class="col_heading level0 col2" >AUC</th>        <th class="col_heading level0 col3" >Recall</th>        <th class="col_heading level0 col4" >Prec.</th>        <th class="col_heading level0 col5" >F1</th>        <th class="col_heading level0 col6" >Kappa</th>        <th class="col_heading level0 col7" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_25e53_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_25e53_row0_col0" class="data row0 col0" >Quadratic Discriminant Analysis</td>
#                         <td id="T_25e53_row0_col1" class="data row0 col1" >0.5806</td>
#                         <td id="T_25e53_row0_col2" class="data row0 col2" >0.6403</td>
#                         <td id="T_25e53_row0_col3" class="data row0 col3" >0.7386</td>
#                         <td id="T_25e53_row0_col4" class="data row0 col4" >0.4887</td>
#                         <td id="T_25e53_row0_col5" class="data row0 col5" >0.5882</td>
#                         <td id="T_25e53_row0_col6" class="data row0 col6" >0.1956</td>
#                         <td id="T_25e53_row0_col7" class="data row0 col7" >0.2132</td>
#             </tr>
#     </tbody></table>

# %%
print(tuned_qda)
# Out:
# QuadraticDiscriminantAnalysis(priors=None, reg_param=0.98,
#                               store_covariance=False, tol=0.0001)

# %% [markdown]
# ### **Prediction on Unseen Data**

# %%
unseen_predictions = predict_model(qda, data=test)
unseen_predictions["Date"] = df['Accident date'][1739:]
unseen_predictions = unseen_predictions.set_index('Date')
unseen_predictions
# Out:
#             Year  Month  Day  DayofWeek  Weekend_(y/n)  DayofYear    DateInt  \
# Date
# 2021-03-29  2021      3   29          0            0.0         88  1502496.0
# 2021-03-30  2021      3   30          1            0.0         89  1503360.0
# 2021-03-31  2021      3   31          2            0.0         90  1504224.0
# 2021-04-01  2021      4    1          3            0.0         91  1505088.0
# 2021-04-02  2021      4    2          4            0.0         92  1505952.0
# ...          ...    ...  ...        ...            ...        ...        ...
# 2021-06-22  2021      6   22          1            0.0        173  1575936.0
# 2021-06-23  2021      6   23          2            0.0        174  1576800.0
# 2021-06-24  2021      6   24          3            0.0        175  1577664.0
# 2021-06-25  2021      6   25          4            0.0        176  1578528.0
# 2021-06-26  2021      6   26          5            1.0        177  1579392.0
#
#             deathYorN  Label  Score
# Date
# 2021-03-29          0      0    1.0
# 2021-03-30          0      1    1.0
# 2021-03-31          1      1    1.0
# 2021-04-01          0      0    1.0
# 2021-04-02          0      0    1.0
# ...               ...    ...    ...
# 2021-06-22          0      1    1.0
# 2021-06-23          1      0    1.0
# 2021-06-24          0      0    1.0
# 2021-06-25          0      0    1.0
# 2021-06-26          1      1    1.0
#
# [90 rows x 10 columns]

# %% [markdown]
# ### Viz of Actual vs Prediction

# %%
actuals = unseen_predictions.deathYorN
prediction = unseen_predictions.Label

# %%
actual_plt = actuals.replace(0, 0.1)
pred_plt = prediction.replace(0, 0.1)

plt.rcParams["figure.figsize"] = [18, 6]

actual_plt.plot(kind = 'bar', linewidth = 1, label = 'Prediction', color = 'black', linestyle = '--', alpha = 0.5)
pred_plt.plot(kind = 'bar', linewidth = 1, label = 'Actual', color = 'lightseagreen')
plt.ylabel('No of Deaths')
plt.title('Comparison of Actual and Prediction (Test Set): QDA Classifier', fontsize = 16)
plt.legend(bbox_to_anchor=(1.04,1), loc="upper left")
plt.show()

# %% [markdown]
# ### Unseen Data: Confusion Matrix

# %%
data = confusion_matrix(actuals, prediction)
df_cm = pd.DataFrame(data, columns=np.unique(y_test), index = np.unique(y_test))
df_cm.index.name = 'Actual'
df_cm.columns.name = 'Predicted'
plt.figure(figsize = (6, 4))
sns.heatmap(df_cm, cmap="Blues", annot=True,annot_kws={"size": 12})# font size
plt.show()
        
tn, fp, fn, tp = confusion_matrix(actuals, prediction).ravel()
print ("TP: {}, FP: {}, TN: {}, FN: {}".format(tp, fp, tn, fn))
# Out:
# TP: 16, FP: 21, TN: 40, FN: 13

# %% [markdown]
# ### Recall, Precision & F1 Score

# %%
def macro_weighted_prec_rec(y_test, y_hat):
    
    acc_test = metrics.accuracy_score(y_test, y_hat)
    print ("Accuracy Score of Test Set:", acc_test)
    
    print('.')
    
    rec_ = metrics.recall_score(y_test, y_hat)
    print ("Recall Score:", rec_)

    
    rec_mac = metrics.recall_score(y_test, y_hat, average = 'macro')
    print ("Macro Average of Recall Score:", rec_mac)

    rec_wei = metrics.recall_score(y_test, y_hat, average = 'weighted')
    print ("Weighted Average of Recall Score:", rec_wei)
    
    print ('.')
    
    prec_mac = metrics.precision_score(y_test, y_hat, average = 'macro')
    print ("Macro Average of Precision Score:", prec_mac)

    prec_wei = metrics.precision_score(y_test, y_hat, average = 'weighted')
    print ("Weighted Average of Precision Score:", prec_wei)
    
    print ('.')

    f1_mac = metrics.f1_score(y_test, y_hat, average = 'macro')
    print ("Macro Average of F1 Score:", f1_mac)

    f1_wei = metrics.f1_score(y_test, y_hat, average = 'weighted')
    print ("Weighted Average of F1 Score:", f1_wei)

# %%
macro_weighted_prec_rec(actuals, prediction)
# Out:
# Accuracy Score of Test Set: 0.6222222222222222
# .
# Recall Score: 0.5517241379310345
# Macro Average of Recall Score: 0.6037309214245337
# Weighted Average of Recall Score: 0.6222222222222222
# .
# Macro Average of Precision Score: 0.593574706782254
# Weighted Average of Precision Score: 0.6508697376621906
# .
# Macro Average of F1 Score: 0.5933014354066986
# Weighted Average of F1 Score: 0.6318624844940633

# %% [markdown]
# ### Distribution Plot of the Unseen Data

# %%
 ax2 = sns.distplot(actuals, hist=False, color='lightseagreen', label = 'Actual')
sns.distplot(prediction, hist=False, ax=ax2, color='black', label = 'Prediction')
plt.title('Actual vs Predicted Values (Test Set)')
plt.xlabel('Killed or not')
plt.ylabel('Proportion of Results')
plt.legend()
plt.show()

# %% [markdown]
# ### References
#
# *  [True vs. False and Positive vs. Negative](https://developers.google.com/machine-learning/crash-course/classification/true-false-positive-negative)
# *  [Accuracy](https://developers.google.com/machine-learning/crash-course/classification/accuracy)
# *  [Precision and Recall](https://developers.google.com/machine-learning/crash-course/classification/precision-and-recall)
# *  [ROC-AUC](https://developers.google.com/machine-learning/crash-course/classification/roc-and-auc)
# *  [Relationship between Precision-Recall and ROC Curves](https://www.biostat.wisc.edu/~page/rocpr.pdf)
#
# * https://colab.research.google.com/drive/1GqQ3XAIzg4krBbnOpKyeRqT0qBQhdwYL#scrollTo=nwaZk6oTEQsi
