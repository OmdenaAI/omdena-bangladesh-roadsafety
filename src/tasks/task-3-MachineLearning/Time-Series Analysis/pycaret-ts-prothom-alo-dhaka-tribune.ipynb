# %% [markdown]
# # Time-Series Analysis using PyCaret: Prothom Alo & Dhaka Tribune
#
# ## Highlights
#
# * PyCaret Time-Series Problem
#
# ### Dataset: Prothom Alo + Dhaka Tribune 2021 Dataset.
#
# * Training Period: 2021-04-23 to 2021-06-18
# * Test/Validation Period: 2021-06-19 to 2021-06-26
#
# Author: Sumaia Parveen Shupti
#
# Created on: 07/10/2021
#
# Updated on: 07/10/2021

# %% [markdown]
# ## Import Libraries

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import datetime

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

from datetime import datetime, timedelta
import warnings
import matplotlib.pyplot as plt

from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

import plotly.graph_objs as go
from plotly.offline import init_notebook_mode, iplot

# %matplotlib inline
warnings.filterwarnings("ignore")
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.2.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ## Install PyCaret

# %%
#!pip install pycaret-ts-alpha

# %% [markdown]
# ## Load & Clean Prothom Alo 2021 Dataset

# %%
df1 = pd.read_csv('../input/prothom-alo-20192021/prothom_alo_2021.csv')
df1 = df1[['date_of_incident', 'time_of_incident', 'published-time',
       'incident_type', 'location', 'death_count', 'injury_count',
       'type_of_vehicle1', 'type_of_vehicle2']]

df1.loc[1, 'time_of_incident'] = '20:00'
df1["time_of_incident"] = pd.to_datetime(df1["time_of_incident"], format='%H:%M').dt.time

df1['date_of_incident'] = pd.to_datetime(df1['date_of_incident'])
df1 = df1.reset_index(drop = True).set_index('date_of_incident').resample('1D').sum().reset_index()
df_2021_PA = df1[:177]
df_2021_PA
# Out:
#     date_of_incident  death_count  injury_count
# 0         2021-01-01          4.0           1.0
# 1         2021-01-02          0.0           0.0
# 2         2021-01-03          7.0           0.0
# 3         2021-01-04          0.0           0.0
# 4         2021-01-05          0.0           0.0
# ..               ...          ...           ...
# 172       2021-06-22          1.0           3.0
# 173       2021-06-23          3.0           0.0
# 174       2021-06-24          2.0           0.0
# 175       2021-06-25          0.0           2.0
# 176       2021-06-26          2.0           2.0
#
# [177 rows x 3 columns]

# %% [markdown]
# ## Load & Clean Dhaka Tribune 2021 Dataset

# %%
df1 = pd.read_csv('../input/dhakatribunecomplete/Dhaka Tribune Complete Data.csv')
df1['Accident date'] = pd.to_datetime(df1['Accident date'])
df1 = df1[['Accident date', 'Deaths']]
df1.columns = ['Period', 'Deaths']
df1 = df1.sort_values(by = 'Period')
df1 = df1.reset_index(drop = True).set_index('Period').resample('1D').sum().reset_index()
df_2021_DT = df1[1652:].reset_index(drop = True)
df_2021_DT
# Out:
#         Period  Deaths
# 0   2021-01-01    11.0
# 1   2021-01-02     0.0
# 2   2021-01-03     7.0
# 3   2021-01-04     0.0
# 4   2021-01-05     0.0
# ..         ...     ...
# 172 2021-06-22     0.0
# 173 2021-06-23     3.0
# 174 2021-06-24     0.0
# 175 2021-06-25     0.0
# 176 2021-06-26     2.0
#
# [177 rows x 2 columns]

# %% [markdown]
# ### Creating new death count column ==> AVG(Prothom Alo, Dhaka Tribune)

# %%
df = df_2021_DT.copy()
df['death_PA'] = df_2021_PA.death_count
df.columns = ['Period', 'death_DT', 'death_PA']
df['death_count'] = (df['death_DT']+df['death_PA'])/2
df_2021 = df.copy()
df_2021.head()
# Out:
#       Period  death_DT  death_PA  death_count
# 0 2021-01-01      11.0       4.0          7.5
# 1 2021-01-02       0.0       0.0          0.0
# 2 2021-01-03       7.0       7.0          7.0
# 3 2021-01-04       0.0       0.0          0.0
# 4 2021-01-05       0.0       0.0          0.0

# %% [markdown]
# ## Feature Engineering

# %%
df_2021['Date'] = df_2021['Period'].dt.date
df_2021['Year'] = df_2021['Period'].dt.year
df_2021['Month'] = df_2021['Period'].dt.month
df_2021['Day'] = df_2021['Period'].dt.day
df_2021['Day_name'] = df_2021['Period'].dt.day_name()
df_2021['DayofWeek'] = df_2021['Period'].dt.weekday
df_2021['Weekend_(y/n)'] = ((df_2021['Period'].dt.dayofweek) // 5 == 1).astype(float)
df_2021['DayofYear'] = df_2021['Period'].dt.dayofyear
# Convert the date into a number (of days since some point)
fromDate = min(df_2021['Period'])
df_2021['DateInt'] = (df_2021['Period'] - fromDate).astype(np.int64)/100000000000
df_2021.head()
# Out:
#       Period  death_DT  death_PA  death_count        Date  Year  Month  Day  \
# 0 2021-01-01      11.0       4.0          7.5  2021-01-01  2021      1    1
# 1 2021-01-02       0.0       0.0          0.0  2021-01-02  2021      1    2
# 2 2021-01-03       7.0       7.0          7.0  2021-01-03  2021      1    3
# 3 2021-01-04       0.0       0.0          0.0  2021-01-04  2021      1    4
# 4 2021-01-05       0.0       0.0          0.0  2021-01-05  2021      1    5
#
#    Day_name  DayofWeek  Weekend_(y/n)  DayofYear  DateInt
# 0    Friday          4            0.0          1      0.0
# 1  Saturday          5            1.0          2    864.0
# 2    Sunday          6            1.0          3   1728.0
# 3    Monday          0            0.0          4   2592.0
# 4   Tuesday          1            0.0          5   3456.0

# %% [markdown]
# Taking the below columns for the Regression and Time-Series Problem.

# %%
df_2021 = df_2021[[ 'Date', 'Year', 'Month', 'Day', 'DayofWeek', 'Weekend_(y/n)', 'DayofYear', 'DateInt', 'death_count']]
df_2021.head()
# Out:
#          Date  Year  Month  Day  DayofWeek  Weekend_(y/n)  DayofYear  DateInt  \
# 0  2021-01-01  2021      1    1          4            0.0          1      0.0
# 1  2021-01-02  2021      1    2          5            1.0          2    864.0
# 2  2021-01-03  2021      1    3          6            1.0          3   1728.0
# 3  2021-01-04  2021      1    4          0            0.0          4   2592.0
# 4  2021-01-05  2021      1    5          1            0.0          5   3456.0
#
#    death_count
# 0          7.5
# 1          0.0
# 2          7.0
# 3          0.0
# 4          0.0

# %% [markdown]
# ## Train Test Split
#
# * Test/Validation data = 7 days data
# * Training data =  8 weeks data

# %%
start_ = df_2021.Date.max()
end_ = df_2021.Date.min()

test_end = df_2021.Date.max()
test_start = df_2021.Date.max() - timedelta(days = 7)

train_end = test_start - timedelta(days = 1)
train_start = train_end - timedelta(days = 56)

print('Dataset Start Date: {}'.format(start_))
print('Dataset End Date: {}'.format(end_))
print (' ')
print('Train Set Start Date: {}'.format(train_start))
print('Train Set End Date: {}'.format(train_end))
print (' ')
print('Test Set Start Date: {}'.format(test_start))
print('Test Set End Date: {}'.format(test_end))
print (' ')
# Out:
# Dataset Start Date: 2021-06-26
# Dataset End Date: 2021-01-01
#
# Train Set Start Date: 2021-04-23
# Train Set End Date: 2021-06-18
#
# Test Set Start Date: 2021-06-19
# Test Set End Date: 2021-06-26

# %%
mask = (df_2021.Date >= train_start) & (df_2021.Date <= train_end)
train = df_2021.loc[mask]
train = train.drop('Date', 1)

mask = (df_2021.Date >= test_start) & (df_2021.Date <= test_end)
test = df_2021.loc[mask]
test = test.drop('Date', 1)

# %%
train.tail()
# Out:
#      Year  Month  Day  DayofWeek  Weekend_(y/n)  DayofYear   DateInt  \
# 164  2021      6   14          0            0.0        165  141696.0
# 165  2021      6   15          1            0.0        166  142560.0
# 166  2021      6   16          2            0.0        167  143424.0
# 167  2021      6   17          3            0.0        168  144288.0
# 168  2021      6   18          4            0.0        169  145152.0
#
#      death_count
# 164          0.0
# 165          0.0
# 166          3.0
# 167          0.0
# 168          9.0

# %%
test.head()
# Out:
#      Year  Month  Day  DayofWeek  Weekend_(y/n)  DayofYear   DateInt  \
# 169  2021      6   19          5            1.0        170  146016.0
# 170  2021      6   20          6            1.0        171  146880.0
# 171  2021      6   21          0            0.0        172  147744.0
# 172  2021      6   22          1            0.0        173  148608.0
# 173  2021      6   23          2            0.0        174  149472.0
#
#      death_count
# 169          8.5
# 170          1.0
# 171          0.0
# 172          0.5
# 173          3.0

# %% [markdown]
# ## PyCaret Time Series Analysis

# %% [markdown]
# ### Import libraries

# %%
from pprint import pprint
from pycaret.datasets import get_data
from pycaret.internal.pycaret_experiment import TimeSeriesExperiment

from sktime.utils.plotting import plot_series
# Out:
# <style type='text/css'>
# .datatable table.frame { margin-bottom: 0; }
# .datatable table.frame thead { border-bottom: none; }
# .datatable table.frame tr.coltypes td {  color: #FFFFFF;  line-height: 6px;  padding: 0 0.5em;}
# .datatable .bool    { background: #DDDD99; }
# .datatable .object  { background: #565656; }
# .datatable .int     { background: #5D9E5D; }
# .datatable .float   { background: #4040CC; }
# .datatable .str     { background: #CC4040; }
# .datatable .time    { background: #40CC40; }
# .datatable .row_index {  background: var(--jp-border-color3);  border-right: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  font-size: 9px;}
# .datatable .frame tbody td { text-align: left; }
# .datatable .frame tr.coltypes .row_index {  background: var(--jp-border-color0);}
# .datatable th:nth-child(2) { padding-left: 12px; }
# .datatable .hellipsis {  color: var(--jp-cell-editor-border-color);}
# .datatable .vellipsis {  background: var(--jp-layout-color0);  color: var(--jp-cell-editor-border-color);}
# .datatable .na {  color: var(--jp-cell-editor-border-color);  font-size: 80%;}
# .datatable .sp {  opacity: 0.25;}
# .datatable .footer { font-size: 9px; }
# .datatable .frame_dimensions {  background: var(--jp-border-color3);  border-top: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  display: inline-block;  opacity: 0.6;  padding: 1px 10px 1px 5px;}
# </style>

# %% [markdown]
# ### Loading Dataset

# %%
df_2021['Date'] = pd.to_datetime(df_2021['Date'])
df = df_2021.set_index('Date')
y = df.death_count
y
# Out:
# Date
# 2021-01-01     7.5
# 2021-01-02     0.0
# 2021-01-03     7.0
# 2021-01-04     0.0
# 2021-01-05     0.0
# 2021-01-06     0.5
# 2021-01-07     0.0
# 2021-01-08     0.0
# 2021-01-09     0.0
# 2021-01-10     0.0
# 2021-01-11     0.0
# 2021-01-12     0.0
# 2021-01-13     3.0
# 2021-01-14     0.0
# 2021-01-15     0.0
# 2021-01-16     0.0
# 2021-01-17     0.0
# 2021-01-18     1.0
# 2021-01-19     0.5
# 2021-01-20     0.5
# 2021-01-21     3.5
# 2021-01-22     0.0
# 2021-01-23     0.5
# 2021-01-24     0.0
# 2021-01-25     1.0
# 2021-01-26     0.0
# 2021-01-27     0.0
# 2021-01-28     0.5
# 2021-01-29     0.0
# 2021-01-30     0.0
# 2021-01-31     2.0
# 2021-02-01     0.5
# 2021-02-02     0.0
# 2021-02-03    17.0
# 2021-02-04     0.0
# 2021-02-05     1.5
# 2021-02-06     1.5
# 2021-02-07     0.0
# 2021-02-08     1.0
# 2021-02-09     0.5
# 2021-02-10    12.0
# 2021-02-11     1.5
# 2021-02-12     1.0
# 2021-02-13     0.0
# 2021-02-14     1.0
# 2021-02-15     0.5
# 2021-02-16     0.0
# 2021-02-17     0.0
# 2021-02-18     0.5
# 2021-02-19     2.5
# 2021-02-20     3.0
# 2021-02-21     3.0
# 2021-02-22     4.5
# 2021-02-23     4.0
# 2021-02-24     0.0
# 2021-02-25     6.0
# 2021-02-26    12.0
# 2021-02-27     1.0
# 2021-02-28     0.0
# 2021-03-01     0.0
# 2021-03-02     6.5
# 2021-03-03     1.5
# 2021-03-04     0.0
# 2021-03-05     0.5
# 2021-03-06     3.0
# 2021-03-07     2.0
# 2021-03-08     0.0
# 2021-03-09     0.0
# 2021-03-10     0.5
# 2021-03-11     1.0
# 2021-03-12     1.5
# 2021-03-13     2.0
# 2021-03-14     0.5
# 2021-03-15     1.0
# 2021-03-16     0.5
# 2021-03-17     0.0
# 2021-03-18     0.0
# 2021-03-19     1.5
# 2021-03-20     5.0
# 2021-03-21     8.0
# 2021-03-22     2.0
# 2021-03-23     0.0
# 2021-03-24     0.0
# 2021-03-25     2.0
# 2021-03-26    17.5
# 2021-03-27     0.0
# 2021-03-28     5.0
# 2021-03-29     0.0
# 2021-03-30     2.0
# 2021-03-31     5.0
# 2021-04-01     0.0
# 2021-04-02     1.0
# 2021-04-03     0.5
# 2021-04-04     2.0
# 2021-04-05     1.0
# 2021-04-06     0.0
# 2021-04-07     2.0
# 2021-04-08     0.0
# 2021-04-09     0.0
# 2021-04-10     0.0
# 2021-04-11     0.0
# 2021-04-12     0.5
# 2021-04-13     1.5
# 2021-04-14    11.0
# 2021-04-15     0.0
# 2021-04-16     0.0
# 2021-04-17     1.0
# 2021-04-18     1.5
# 2021-04-19     1.5
# 2021-04-20     1.5
# 2021-04-21     0.0
# 2021-04-22     0.0
# 2021-04-23     0.0
# 2021-04-24     1.0
# 2021-04-25     0.0
# 2021-04-26     0.5
# 2021-04-27     0.0
# 2021-04-28     1.5
# 2021-04-29     0.5
# 2021-04-30     2.0
# 2021-05-01     5.0
# 2021-05-02     3.0
# 2021-05-03     4.0
# 2021-05-04     1.0
# 2021-05-05     0.0
# 2021-05-06     2.0
# 2021-05-07     0.0
# 2021-05-08     2.0
# 2021-05-09     0.5
# 2021-05-10     3.0
# 2021-05-11     0.0
# 2021-05-12     6.0
# 2021-05-13     0.0
# 2021-05-14     0.0
# 2021-05-15     5.0
# 2021-05-16     1.0
# 2021-05-17     2.0
# 2021-05-18     1.5
# 2021-05-19     8.0
# 2021-05-20     1.5
# 2021-05-21     5.0
# 2021-05-22     0.5
# 2021-05-23     0.0
# 2021-05-24     0.0
# 2021-05-25     0.0
# 2021-05-26     1.5
# 2021-05-27     0.0
# 2021-05-28     1.5
# 2021-05-29     0.0
# 2021-05-30     0.0
# 2021-05-31     0.0
# 2021-06-01     0.0
# 2021-06-02     0.0
# 2021-06-03     8.0
# 2021-06-04     2.0
# 2021-06-05     1.0
# 2021-06-06     0.0
# 2021-06-07     0.0
# 2021-06-08     0.0
# 2021-06-09     1.0
# 2021-06-10     0.0
# 2021-06-11     0.5
# 2021-06-12     0.0
# 2021-06-13     4.0
# 2021-06-14     0.0
# 2021-06-15     0.0
# 2021-06-16     3.0
# 2021-06-17     0.0
# 2021-06-18     9.0
# 2021-06-19     8.5
# 2021-06-20     1.0
# 2021-06-21     0.0
# 2021-06-22     0.5
# 2021-06-23     3.0
# 2021-06-24     1.0
# 2021-06-25     0.0
# 2021-06-26     2.0
# Name: death_count, dtype: float64

# %%
plt.figure(figsize=(18, 6))
y.plot(color = 'lightseagreen', linestyle = '--')
plt.title('Date vs Death Count')
plt.ylabel('Death Count')
plt.show()

# %% [markdown]
# ### Setup PyCaret Time Series Experiment

# %%
exp = TimeSeriesExperiment()
exp.setup(data=y, fh=7, fold=3, session_id=42)
# Out:
# <style  type="text/css" >
# </style><table id="T_76577_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_76577_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_76577_row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_76577_row0_col1" class="data row0 col1" >42</td>
#             </tr>
#             <tr>
#                         <th id="T_76577_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_76577_row1_col0" class="data row1 col0" >Original Data</td>
#                         <td id="T_76577_row1_col1" class="data row1 col1" >(177, 1)</td>
#             </tr>
#             <tr>
#                         <th id="T_76577_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_76577_row2_col0" class="data row2 col0" >Missing Values</td>
#                         <td id="T_76577_row2_col1" class="data row2 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_76577_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_76577_row3_col0" class="data row3 col0" >Transformed Train Set</td>
#                         <td id="T_76577_row3_col1" class="data row3 col1" >(170,)</td>
#             </tr>
#             <tr>
#                         <th id="T_76577_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_76577_row4_col0" class="data row4 col0" >Transformed Test Set</td>
#                         <td id="T_76577_row4_col1" class="data row4 col1" >(7,)</td>
#             </tr>
#             <tr>
#                         <th id="T_76577_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_76577_row5_col0" class="data row5 col0" >Fold Generator</td>
#                         <td id="T_76577_row5_col1" class="data row5 col1" >ExpandingWindowSplitter</td>
#             </tr>
#             <tr>
#                         <th id="T_76577_level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_76577_row6_col0" class="data row6 col0" >Fold Number</td>
#                         <td id="T_76577_row6_col1" class="data row6 col1" >3</td>
#             </tr>
#             <tr>
#                         <th id="T_76577_level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_76577_row7_col0" class="data row7 col0" >CPU Jobs</td>
#                         <td id="T_76577_row7_col1" class="data row7 col1" >-1</td>
#             </tr>
#             <tr>
#                         <th id="T_76577_level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_76577_row8_col0" class="data row8 col0" >Use GPU</td>
#                         <td id="T_76577_row8_col1" class="data row8 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_76577_level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_76577_row9_col0" class="data row9 col0" >Log Experiment</td>
#                         <td id="T_76577_row9_col1" class="data row9 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_76577_level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_76577_row10_col0" class="data row10 col0" >Experiment Name</td>
#                         <td id="T_76577_row10_col1" class="data row10 col1" >ts-default-name</td>
#             </tr>
#             <tr>
#                         <th id="T_76577_level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_76577_row11_col0" class="data row11 col0" >USI</td>
#                         <td id="T_76577_row11_col1" class="data row11 col1" >fbbb</td>
#             </tr>
#             <tr>
#                         <th id="T_76577_level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_76577_row12_col0" class="data row12 col0" >Imputation Type</td>
#                         <td id="T_76577_row12_col1" class="data row12 col1" >simple</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ### List of Available Models

# %%
exp.models()
# Out:
#                                                               Name  \
# ID
# naive                                             Naive Forecaster
# snaive                                   Seasonal Naive Forecaster
# polytrend                              Polynomial Trend Forecaster
# arima                                                        ARIMA
# auto_arima                                              Auto ARIMA
# exp_smooth                                   Exponential Smoothing
# ets                                                            ETS
# theta                                             Theta Forecaster
# tbats                                                        TBATS
# bats                                                          BATS
# prophet                                                    Prophet
# lr_cds_dt               Linear w/ Cond. Deseasonalize & Detrending
# en_cds_dt          Elastic Net w/ Cond. Deseasonalize & Detrending
# ridge_cds_dt             Ridge w/ Cond. Deseasonalize & Detrending
# lasso_cds_dt             Lasso w/ Cond. Deseasonalize & Detrending
# lar_cds_dt       Least Angular Regressor w/ Cond. Deseasonalize...
# llar_cds_dt      Lasso Least Angular Regressor w/ Cond. Deseaso...
# br_cds_dt        Bayesian Ridge w/ Cond. Deseasonalize & Detren...
# huber_cds_dt             Huber w/ Cond. Deseasonalize & Detrending
# par_cds_dt       Passive Aggressive w/ Cond. Deseasonalize & De...
# omp_cds_dt       Orthogonal Matching Pursuit w/ Cond. Deseasona...
# knn_cds_dt         K Neighbors w/ Cond. Deseasonalize & Detrending
# dt_cds_dt        Decision Tree w/ Cond. Deseasonalize & Detrending
# rf_cds_dt        Random Forest w/ Cond. Deseasonalize & Detrending
# et_cds_dt          Extra Trees w/ Cond. Deseasonalize & Detrending
# gbr_cds_dt       Gradient Boosting w/ Cond. Deseasonalize & Det...
# ada_cds_dt            AdaBoost w/ Cond. Deseasonalize & Detrending
# xgboost_cds_dt   Extreme Gradient Boosting w/ Cond. Deseasonali...
# lightgbm_cds_dt  Light Gradient Boosting w/ Cond. Deseasonalize...
# catboost_cds_dt  CatBoost Regressor w/ Cond. Deseasonalize & De...
#
#                                                          Reference  Turbo
# ID
# naive                     sktime.forecasting.naive.NaiveForecaster   True
# snaive                    sktime.forecasting.naive.NaiveForecaster   True
# polytrend        sktime.forecasting.trend.PolynomialTrendForeca...   True
# arima                               sktime.forecasting.arima.ARIMA   True
# auto_arima                      sktime.forecasting.arima.AutoARIMA   True
# exp_smooth       sktime.forecasting.exp_smoothing.ExponentialSm...   True
# ets                                 sktime.forecasting.ets.AutoETS   True
# theta                     sktime.forecasting.theta.ThetaForecaster   True
# tbats                               sktime.forecasting.tbats.TBATS  False
# bats                                  sktime.forecasting.bats.BATS  False
# prophet          pycaret.containers.models.time_series.ProphetP...  False
# lr_cds_dt          pycaret.containers.models.time_series.BaseCdsDt   True
# en_cds_dt          pycaret.containers.models.time_series.BaseCdsDt   True
# ridge_cds_dt       pycaret.containers.models.time_series.BaseCdsDt   True
# lasso_cds_dt       pycaret.containers.models.time_series.BaseCdsDt   True
# lar_cds_dt         pycaret.containers.models.time_series.BaseCdsDt   True
# llar_cds_dt        pycaret.containers.models.time_series.BaseCdsDt   True
# br_cds_dt          pycaret.containers.models.time_series.BaseCdsDt   True
# huber_cds_dt       pycaret.containers.models.time_series.BaseCdsDt   True
# par_cds_dt         pycaret.containers.models.time_series.BaseCdsDt   True
# omp_cds_dt         pycaret.containers.models.time_series.BaseCdsDt   True
# knn_cds_dt         pycaret.containers.models.time_series.BaseCdsDt   True
# dt_cds_dt          pycaret.containers.models.time_series.BaseCdsDt   True
# rf_cds_dt          pycaret.containers.models.time_series.BaseCdsDt   True
# et_cds_dt          pycaret.containers.models.time_series.BaseCdsDt   True
# gbr_cds_dt         pycaret.containers.models.time_series.BaseCdsDt   True
# ada_cds_dt         pycaret.containers.models.time_series.BaseCdsDt   True
# xgboost_cds_dt     pycaret.containers.models.time_series.BaseCdsDt   True
# lightgbm_cds_dt    pycaret.containers.models.time_series.BaseCdsDt   True
# catboost_cds_dt    pycaret.containers.models.time_series.BaseCdsDt   True

# %% [markdown]
# ### Compare Different Models

# %%
# %%time
best_baseline_models = exp.compare_models(n_select=3, sort='mape')
# Out:
# <style  type="text/css" >
#     #T_df3cd_ th {
#           text-align: left;
#     }#T_df3cd_row0_col0,#T_df3cd_row0_col2,#T_df3cd_row0_col4,#T_df3cd_row0_col5,#T_df3cd_row1_col0,#T_df3cd_row1_col2,#T_df3cd_row1_col4,#T_df3cd_row1_col5,#T_df3cd_row2_col0,#T_df3cd_row2_col1,#T_df3cd_row2_col2,#T_df3cd_row2_col3,#T_df3cd_row2_col4,#T_df3cd_row2_col5,#T_df3cd_row3_col0,#T_df3cd_row3_col1,#T_df3cd_row3_col2,#T_df3cd_row3_col3,#T_df3cd_row3_col4,#T_df3cd_row3_col5,#T_df3cd_row4_col0,#T_df3cd_row4_col1,#T_df3cd_row4_col2,#T_df3cd_row4_col3,#T_df3cd_row4_col4,#T_df3cd_row4_col5,#T_df3cd_row5_col0,#T_df3cd_row5_col1,#T_df3cd_row5_col2,#T_df3cd_row5_col3,#T_df3cd_row5_col4,#T_df3cd_row5_col5,#T_df3cd_row6_col0,#T_df3cd_row6_col1,#T_df3cd_row6_col2,#T_df3cd_row6_col3,#T_df3cd_row6_col4,#T_df3cd_row6_col5,#T_df3cd_row7_col0,#T_df3cd_row7_col1,#T_df3cd_row7_col2,#T_df3cd_row7_col3,#T_df3cd_row7_col4,#T_df3cd_row7_col5,#T_df3cd_row8_col0,#T_df3cd_row8_col1,#T_df3cd_row8_col2,#T_df3cd_row8_col3,#T_df3cd_row8_col4,#T_df3cd_row8_col5,#T_df3cd_row9_col0,#T_df3cd_row9_col1,#T_df3cd_row9_col2,#T_df3cd_row9_col3,#T_df3cd_row9_col4,#T_df3cd_row9_col5,#T_df3cd_row10_col0,#T_df3cd_row10_col1,#T_df3cd_row10_col2,#T_df3cd_row10_col3,#T_df3cd_row10_col4,#T_df3cd_row10_col5,#T_df3cd_row11_col0,#T_df3cd_row11_col1,#T_df3cd_row11_col2,#T_df3cd_row11_col3,#T_df3cd_row11_col4,#T_df3cd_row11_col5,#T_df3cd_row12_col0,#T_df3cd_row12_col1,#T_df3cd_row12_col2,#T_df3cd_row12_col3,#T_df3cd_row12_col4,#T_df3cd_row12_col5,#T_df3cd_row13_col0,#T_df3cd_row13_col1,#T_df3cd_row13_col2,#T_df3cd_row13_col3,#T_df3cd_row13_col4,#T_df3cd_row13_col5,#T_df3cd_row14_col0,#T_df3cd_row14_col1,#T_df3cd_row14_col3,#T_df3cd_row15_col0,#T_df3cd_row15_col1,#T_df3cd_row15_col2,#T_df3cd_row15_col3,#T_df3cd_row15_col4,#T_df3cd_row15_col5,#T_df3cd_row16_col0,#T_df3cd_row16_col1,#T_df3cd_row16_col2,#T_df3cd_row16_col3,#T_df3cd_row16_col4,#T_df3cd_row16_col5,#T_df3cd_row17_col0,#T_df3cd_row17_col1,#T_df3cd_row17_col2,#T_df3cd_row17_col3,#T_df3cd_row17_col4,#T_df3cd_row17_col5,#T_df3cd_row18_col0,#T_df3cd_row18_col1,#T_df3cd_row18_col2,#T_df3cd_row18_col3,#T_df3cd_row18_col4,#T_df3cd_row18_col5,#T_df3cd_row19_col0,#T_df3cd_row19_col1,#T_df3cd_row19_col2,#T_df3cd_row19_col3,#T_df3cd_row19_col4,#T_df3cd_row19_col5,#T_df3cd_row20_col0,#T_df3cd_row20_col1,#T_df3cd_row20_col2,#T_df3cd_row20_col3,#T_df3cd_row20_col4,#T_df3cd_row20_col5,#T_df3cd_row21_col0,#T_df3cd_row21_col1,#T_df3cd_row21_col2,#T_df3cd_row21_col3,#T_df3cd_row21_col4,#T_df3cd_row21_col5,#T_df3cd_row22_col0,#T_df3cd_row22_col1,#T_df3cd_row22_col2,#T_df3cd_row22_col3,#T_df3cd_row22_col4,#T_df3cd_row22_col5,#T_df3cd_row23_col0,#T_df3cd_row23_col1,#T_df3cd_row23_col2,#T_df3cd_row23_col3,#T_df3cd_row23_col4,#T_df3cd_row23_col5,#T_df3cd_row24_col0,#T_df3cd_row24_col1,#T_df3cd_row24_col2,#T_df3cd_row24_col3,#T_df3cd_row24_col4,#T_df3cd_row24_col5,#T_df3cd_row25_col0,#T_df3cd_row25_col1,#T_df3cd_row25_col2,#T_df3cd_row25_col3,#T_df3cd_row25_col4,#T_df3cd_row25_col5,#T_df3cd_row26_col0,#T_df3cd_row26_col1,#T_df3cd_row26_col2,#T_df3cd_row26_col3,#T_df3cd_row26_col4,#T_df3cd_row26_col5{
#             text-align:  left;
#             text-align:  left;
#         }#T_df3cd_row0_col1,#T_df3cd_row0_col3,#T_df3cd_row1_col1,#T_df3cd_row1_col3,#T_df3cd_row14_col2,#T_df3cd_row14_col4,#T_df3cd_row14_col5{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }#T_df3cd_row0_col6,#T_df3cd_row2_col6,#T_df3cd_row3_col6,#T_df3cd_row4_col6,#T_df3cd_row5_col6,#T_df3cd_row6_col6,#T_df3cd_row7_col6,#T_df3cd_row8_col6,#T_df3cd_row9_col6,#T_df3cd_row11_col6,#T_df3cd_row12_col6,#T_df3cd_row13_col6,#T_df3cd_row14_col6,#T_df3cd_row15_col6,#T_df3cd_row16_col6,#T_df3cd_row17_col6,#T_df3cd_row18_col6,#T_df3cd_row19_col6,#T_df3cd_row20_col6,#T_df3cd_row21_col6,#T_df3cd_row22_col6,#T_df3cd_row23_col6,#T_df3cd_row24_col6,#T_df3cd_row25_col6,#T_df3cd_row26_col6{
#             text-align:  left;
#             text-align:  left;
#             background-color:  lightgrey;
#         }#T_df3cd_row1_col6,#T_df3cd_row10_col6{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#             background-color:  lightgrey;
#         }</style><table id="T_df3cd_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >MAE</th>        <th class="col_heading level0 col2" >RMSE</th>        <th class="col_heading level0 col3" >MAPE</th>        <th class="col_heading level0 col4" >SMAPE</th>        <th class="col_heading level0 col5" >R2</th>        <th class="col_heading level0 col6" >TT (Sec)</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_df3cd_level0_row0" class="row_heading level0 row0" >naive</th>
#                         <td id="T_df3cd_row0_col0" class="data row0 col0" >Naive Forecaster</td>
#                         <td id="T_df3cd_row0_col1" class="data row0 col1" >1.9524</td>
#                         <td id="T_df3cd_row0_col2" class="data row0 col2" >12.0238</td>
#                         <td id="T_df3cd_row0_col3" class="data row0 col3" >1072285625564404.1250</td>
#                         <td id="T_df3cd_row0_col4" class="data row0 col4" >1.8413</td>
#                         <td id="T_df3cd_row0_col5" class="data row0 col5" >-1.9717</td>
#                         <td id="T_df3cd_row0_col6" class="data row0 col6" >0.7600</td>
#             </tr>
#             <tr>
#                         <th id="T_df3cd_level0_row1" class="row_heading level0 row1" >snaive</th>
#                         <td id="T_df3cd_row1_col0" class="data row1 col0" >Seasonal Naive Forecaster</td>
#                         <td id="T_df3cd_row1_col1" class="data row1 col1" >1.9524</td>
#                         <td id="T_df3cd_row1_col2" class="data row1 col2" >12.0238</td>
#                         <td id="T_df3cd_row1_col3" class="data row1 col3" >1072285625564404.1250</td>
#                         <td id="T_df3cd_row1_col4" class="data row1 col4" >1.8413</td>
#                         <td id="T_df3cd_row1_col5" class="data row1 col5" >-1.9717</td>
#                         <td id="T_df3cd_row1_col6" class="data row1 col6" >0.0100</td>
#             </tr>
#             <tr>
#                         <th id="T_df3cd_level0_row2" class="row_heading level0 row2" >huber_cds_dt</th>
#                         <td id="T_df3cd_row2_col0" class="data row2 col0" >Huber w/ Cond. Deseasonalize & Detrending</td>
#                         <td id="T_df3cd_row2_col1" class="data row2 col1" >1.9733</td>
#                         <td id="T_df3cd_row2_col2" class="data row2 col2" >10.2091</td>
#                         <td id="T_df3cd_row2_col3" class="data row2 col3" >2192186647808089.0000</td>
#                         <td id="T_df3cd_row2_col4" class="data row2 col4" >1.6062</td>
#                         <td id="T_df3cd_row2_col5" class="data row2 col5" >-1.8253</td>
#                         <td id="T_df3cd_row2_col6" class="data row2 col6" >0.0333</td>
#             </tr>
#             <tr>
#                         <th id="T_df3cd_level0_row3" class="row_heading level0 row3" >omp_cds_dt</th>
#                         <td id="T_df3cd_row3_col0" class="data row3 col0" >Orthogonal Matching Pursuit w/ Cond. Deseasonalize & Detrending</td>
#                         <td id="T_df3cd_row3_col1" class="data row3 col1" >2.2684</td>
#                         <td id="T_df3cd_row3_col2" class="data row3 col2" >9.2864</td>
#                         <td id="T_df3cd_row3_col3" class="data row3 col3" >4201261479278450.5000</td>
#                         <td id="T_df3cd_row3_col4" class="data row3 col4" >1.5277</td>
#                         <td id="T_df3cd_row3_col5" class="data row3 col5" >-6.6445</td>
#                         <td id="T_df3cd_row3_col6" class="data row3 col6" >0.0267</td>
#             </tr>
#             <tr>
#                         <th id="T_df3cd_level0_row4" class="row_heading level0 row4" >
# CPU times: user 12.8 s, sys: 477 ms, total: 13.3 s
# Wall time: 52.5 s

# %% [markdown]
# ## Reference
#
# * https://nbviewer.jupyter.org/github/pycaret/sktime-dev-days-2021/blob/main/sktime_dev_days_101.ipynb
