# %% [markdown]
# ### Data Cleaning & Interactive Folium Maps for Final Phases: Dhaka Tribune

# %%
#!pip install -U spacy
#!python -m spacy download en
#!pip install geopy

# %%
# for manipulating dataframes
import pandas as pd
import numpy as np
# for natural language processing: named entity recognition
import spacy
from collections import Counter
import en_core_web_sm
nlp = en_core_web_sm.load()
# for visualizations
# %matplotlib inline

from geopy.geocoders import Nominatim
geolocator = Nominatim(user_agent="jjj")

# %%
df = pd.read_csv("../input/dhakatribunecomplete/Dhaka Tribune Complete Data.csv")
df['Accident date']= pd.to_datetime(df['Accident date'])
df
# Out:
#      Unnamed: 0 Newspaper Name Accident date  \
# 0             0  Dhaka Tribune    2021-06-26
# 1             1  Dhaka Tribune    2021-06-23
# 2             2  Dhaka Tribune    2021-06-19
# 3             3  Dhaka Tribune    2021-06-19
# 4             4  Dhaka Tribune    2021-06-19
# ..          ...            ...           ...
# 771         836  Dhaka Tribune    2016-08-04
# 772         837  Dhaka Tribune    2016-07-16
# 773         838  Dhaka Tribune    2016-07-15
# 774         839  Dhaka Tribune    2016-06-25
# 775         840  Dhaka Tribune    2016-06-24
#
#                                                 Header  \
# 0          Two labourers killed in Dhaka road accident
# 1             Three killed in Muktagacha road accident
# 2    Truck-pickup van collision leaves 3 dead in Na...
# 3    Couple, infant grandson killed in Bogra bus-au...
# 4              Policeman killed in Dhaka road accident
# ..                                                 ...
# 771  Two motorcyclists killed in Manikganj road acc...
# 772                Four die in Manikganj road accident
# 773             BNP leader hurt in Dinajpur road crash
# 774   Foreigners among 25 injured in Ctg road accident
# 775                  3 killed in Gazipur road accident
#
#                                      News title  Deaths  Injured
# 0                  2 killed in Dhaka road crash     2.0        2
# 1            Three killed in Muktagacha road...     3.0        0
# 2        Truck-pickup van collision leaves 3...     3.0        0
# 3                      Bogra road crash kills 3     3.0        0
# 4                Cop killed in Dhaka road crash     1.0        0
# ..                                          ...     ...      ...
# 771    Two motorcyclists killed in Manikganj...     2.0        0
# 772                  Four die in Manikganj road     4.0        0
# 773         BNP leader hurt in Dinajpur road...     0.0        1
# 774  Foreigners among 25 injured in Ctg road...     0.0       25
# 775           3 killed in Gazipur road accident     3.0        0
#
# [776 rows x 7 columns]

# %%
# %%time

col_value = []

for i in range(len(df)):
    tokens = nlp(''.join(str(df['Header'][i])))
    
    location_list = []
    for ent in tokens.ents:
        if ent.label_ == 'GPE':
            location_list.append(ent.text)
    
    
    location_counts = Counter(location_list).most_common(10)
    col_value.append(''.join(filter(str.isalpha, str(location_counts))))
    
df['Location_appox'] = col_value
# Out:
# CPU times: user 4.92 s, sys: 6.93 ms, total: 4.92 s
# Wall time: 4.92 s

# %%
df['Location_appox'] = col_value

# %% [markdown]
# ### Text Cleaning

# %%
df['Location_appox'] = df['Location_appox'].replace( '', np.nan)
df['Location_appox'] = df['Location_appox'].replace( 'RangpurFeni', 'Rangpur')
df['Location_appox'] = df['Location_appox'].replace( 'Ctg', 'Chittagong')
df['Location_appox'] = df['Location_appox'].replace( 'Cox', "Cox's Bazar")
df['Location_appox'] = df['Location_appox'].replace( 'JessoreDinajpurNilphamari', "Jessore")
df['Location_appox'] = df['Location_appox'].replace( 'ComillaKhulna', "Cumilla")
df['Location_appox'] = df['Location_appox'].replace( 'DhakaGabtoli', "Dhaka")
df['Location_appox'] = df['Location_appox'].replace( 'BograJhenaidah', "Bogra")
df['Location_appox'] = df['Location_appox'].replace( 'ElderlyDhaka', "Dhaka")

X = ['Elderly', 'Ahona', 'Rasel', 'Wasa', 'Bangladesh', 'India', 'Utah', "California", "Macedonia", "Nepal", 'SaudiArabia', "NewYork", "Uganda", "Oman", "Egypt", "Canada", "Mozambique",\
    'BangladeshUSA', 'Australia']

df.loc[df.Location_appox.isin(X), 'Location_appox'] = np.NaN

# %%
df.isnull().sum()
# Out:
# Unnamed: 0          0
# Newspaper Name      0
# Accident date       0
# Header              0
# News title          0
# Deaths             14
# Injured             0
# Location_appox    488
# dtype: int64

# %%
a = list(df.Location_appox.unique())

coordinates = []

def loc_errors(a):
    list_of_error_loc = []
    for loc in a:
        try:
            location = geolocator.geocode(str(loc + ", Bangladesh"))
            lat_long = (location.latitude, location.longitude)
            coordinates.append(list(lat_long))
        except Exception:
            list_of_error_loc.append(loc)
            continue
    return list_of_error_loc

# %time list_of_error_loc = loc_errors(a)
list_of_error_loc
# Out:
# CPU times: user 122 ms, sys: 10.2 ms, total: 132 ms
# Wall time: 25.3 s
# [nan]

# %%
df = df[['Accident date', 'Header', 'Location_appox']]
df = df.dropna()

# %%
df.Location_appox = df['Location_appox'] + ', Bangladesh'
df = df.reset_index(drop = True)
df
# Out:
#     Accident date                                             Header  \
# 0      2021-06-26        Two labourers killed in Dhaka road accident
# 1      2021-06-19  Truck-pickup van collision leaves 3 dead in Na...
# 2      2021-06-19            Policeman killed in Dhaka road accident
# 3      2021-06-18           3 killed in bus-car collision in Comilla
# 4      2021-06-16          6 die in road accidents in Dhaka, Gazipur
# ..            ...                                                ...
# 283    2016-08-15                    Road accident kills 1 in Natore
# 284    2016-08-04  Two motorcyclists killed in Manikganj road acc...
# 285    2016-07-16                Four die in Manikganj road accident
# 286    2016-07-15             BNP leader hurt in Dinajpur road crash
# 287    2016-06-24                  3 killed in Gazipur road accident
#
#             Location_appox
# 0        Dhaka, Bangladesh
# 1    Narsingdi, Bangladesh
# 2        Dhaka, Bangladesh
# 3      Comilla, Bangladesh
# 4        Dhaka, Bangladesh
# ..                     ...
# 283     Natore, Bangladesh
# 284  Manikganj, Bangladesh
# 285  Manikganj, Bangladesh
# 286   Dinajpur, Bangladesh
# 287    Gazipur, Bangladesh
#
# [288 rows x 3 columns]

# %% [markdown]
# ### Using GeoPy to retrive coordinates of the locations

# %%
# %%time

loc_bengali = []
lat = []
lon = []

for i in range(len(df)):
    location = geolocator.geocode(df.Location_appox.values[i])
    print(df.Location_appox.values[i])
    loc_bengali.append(location.address)
    lat.append(location.latitude)
    lon.append(location.longitude)
# Out:
# Dhaka, Bangladesh
# Narsingdi, Bangladesh
# Dhaka, Bangladesh
# Comilla, Bangladesh
# Dhaka, Bangladesh
# Brahmanbaria, Bangladesh
# Gulshan, Bangladesh
# Chittagong, Bangladesh
# Rajshahi, Bangladesh
# Dhaka, Bangladesh
# Comilla, Bangladesh
# Comilla, Bangladesh
# Dhaka, Bangladesh
# Brahmanbaria, Bangladesh
# Chittagong, Bangladesh
# Narsingdi, Bangladesh
# Bogra, Bangladesh
# Chittagong, Bangladesh
# Bogra, Bangladesh
# Dhaka, Bangladesh
# Munshiganj, Bangladesh
# Chittagong, Bangladesh
# Kaliakoir, Bangladesh
# Chittagong, Bangladesh
# Chittagong, Bangladesh
# Jessore, Bangladesh
# Dhaka, Bangladesh
# Narsingdi, Bangladesh
# Narayanganj, Bangladesh
# Narayanganj, Bangladesh
# Chittagong, Bangladesh
# Kushtia, Bangladesh
# Comilla, Bangladesh
# Tejgaon, Bangladesh
# Dhaka, Bangladesh
# Chittagong, Bangladesh
# Narsingdi, Bangladesh
# Magura, Bangladesh
# Faridpur, Bangladesh
# Dhaka, Bangladesh
# Narayanganj, Bangladesh
# Dhaka, Bangladesh
# Chittagong, Bangladesh
# Mirpur, Bangladesh
# Gazipur, Bangladesh
# Brahmanbaria, Bangladesh
# Kushtia, Bangladesh
# Narayanganj, Bangladesh
# Khulna, Bangladesh
# Comilla, Bangladesh
# Narayanganj, Bangladesh
# Munshiganj, Bangladesh
# Brahmanbaria, Bangladesh
# Chittagong, Bangladesh
# Munshiganj, Bangladesh
# Dinajpur, Bangladesh
# Dhaka, Bangladesh
# Rangpur, Bangladesh
# Gazipur, Bangladesh
# Natore, Bangladesh
# Manikganj, Bangladesh
# Manikganj, Bangladesh
# Dinajpur, Bangladesh
# Gazipur, Bangladesh
# CPU times: user 1.09 s, sys: 139 ms, total: 1.23 s
# Wall time: 2min 23s

# %%
df['location'] = loc_bengali
df['Latitude'] = lat
df['Longitude'] = lon

# %%
df
# Out:
#     Accident date                                             Header  \
# 0      2021-06-26        Two labourers killed in Dhaka road accident
# 1      2021-06-19  Truck-pickup van collision leaves 3 dead in Na...
# 2      2021-06-19            Policeman killed in Dhaka road accident
# 3      2021-06-18           3 killed in bus-car collision in Comilla
# 4      2021-06-16          6 die in road accidents in Dhaka, Gazipur
# ..            ...                                                ...
# 283    2016-08-15                    Road accident kills 1 in Natore
# 284    2016-08-04  Two motorcyclists killed in Manikganj road acc...
# 285    2016-07-16                Four die in Manikganj road accident
# 286    2016-07-15             BNP leader hurt in Dinajpur road crash
# 287    2016-06-24                  3 killed in Gazipur road accident
#
#             Location_appox                                           location  \
# 0        Dhaka, Bangladesh  ঢাকা, Chanpara Bazar, ঢাকা জেলা, ঢাকা বিভাগ, 1...
# 1    Narsingdi, Bangladesh  নরসিংদী, নরসিংদী জেলা, ঢাকা বিভাগ, 1602, বাংলাদেশ
# 2        Dhaka, Bangladesh  ঢাকা, Chanpara Bazar, ঢাকা জেলা, ঢাকা বিভাগ, 1...
# 3      Comilla, Bangladesh  কুমিল্লা, কুমিল্লা জেলা, চট্টগ্রাম বিভাগ, 3500...
# 4        Dhaka, Bangladesh  ঢাকা, Chanpara Bazar, ঢাকা জেলা, ঢাকা বিভাগ, 1...
# ..                     ...                                                ...
# 283     Natore, Bangladesh  chakrampur,Natore,Bangladesh, N/A, N502, নাটোর...
# 284  Manikganj, Bangladesh               মানিকগঞ্জ জেলা, ঢাকা বিভাগ, বাংলাদেশ
# 285  Manikganj, Bangladesh               মানিকগঞ্জ জেলা, ঢাকা বিভাগ, বাংলাদেশ
# 286   Dinajpur, Bangladesh            দিনাজপুর, দিনাজপুর জেলা, 5216, বাংলাদেশ
# 287    Gazipur, Bangladesh  গাজীপুর, গাজীপুর জেলা, ঢাকা বিভাগ, 1701, বাংলাদেশ
#
#       Latitude  Longitude
# 0    23.810651  90.412647
# 1    23.915645  90.698196
# 2    23.810651  90.412647
# 3    23.461061  91.180875
# 4    23.810651  90.412647
# ..         ...        ...
# 283  24.411130  88.997356
# 284  23.871163  89.998783
# 285  23.871163  89.998783
# 286  25.626071  88.634623
# 287  23.998080  90.422985
#
# [288 rows x 6 columns]

# %%
df.to_csv('Dhaka_Tribune.csv', index = False)

# %%
df_new = df.copy()

# %%
import folium
from folium.plugins import *
from folium import plugins

# %%
df_new = df_new.dropna()
df_new = df_new[(df_new['Latitude'] != 0) & (df_new['Longitude'] != 0)]

def map():


    # Create a map centered on Vancouver
    map_bd = folium.Map(location= [23.6850, 90.3563], tiles="cartodbpositron", zoom_start = 7)

    # Create a list with lat and long values and add the list to a heat map, then show map
    heat_data = [[row['Latitude'],row['Longitude']] for index, row in df_new.iterrows()]
    HeatMap(heat_data).add_to(map_bd)

    # instantiate a feature group for the incidents in the dataframe
    incidents = folium.map.FeatureGroup()

    # loop through the 100 crimes and add each to the incidents feature group
    for lat, lng, in zip(df_new.Latitude, df_new.Longitude):
        incidents.add_child(
            folium.CircleMarker(
                [lat, lng],
                radius=5, # define how big you want the circle markers to be
                color='darkred',
                fill=True,
                fill_color='red',
                fill_opacity=0.6
            )
        )
    
    #map_van.add_child(incidents)
    folium.TileLayer('cartodbdark_matter').add_to(map_bd)

    # instantiate a mark cluster object for the incidents in the dataframe
    incident = plugins.MarkerCluster().add_to(map_bd)

    # loop through the dataframe and add each data point to the mark cluster
    for lat, lng, label, in zip(df_new.Latitude, df_new.Longitude, df_new.Location_appox):
        folium.Marker(
            location=[lat, lng],
            icon=None,
            popup=label,
        ).add_to(incident)

    # add incidents to map
    map_bd.add_child(incident)
    return map_bd

map()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_1cf08f2825b3473e88df39efdee9dec1%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium%40master/folium/templates/leaflet_heat.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css%22/%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20 ...

# %%
df_new["Weight"] = df_new['Accident date'].astype(str)
df_new["Weight"] = df_new["Weight"].str[5:7]
df_new["Weight"] = df_new["Weight"].astype(float)

import datetime 
df_new['year'] = pd.DatetimeIndex(df_new['Accident date']).year
df_new['month'] = pd.DatetimeIndex(df_new['Accident date']).month

lista_tempo = [] 

for x in df_new['month']: 
    monthinteger = x 
    lista_tempo.append(datetime.date(1900, monthinteger, 1).strftime('%B')) 
    
df_new['months_in_full'] = lista_tempo 
df_new['month_year'] = [d.split('-')[1] + " " + d.split('-')[0] for d in df_new['Accident date'].astype(str)]

df_new
# Out:
#     Accident date                                             Header  \
# 0      2021-06-26        Two labourers killed in Dhaka road accident
# 1      2021-06-19  Truck-pickup van collision leaves 3 dead in Na...
# 2      2021-06-19            Policeman killed in Dhaka road accident
# 3      2021-06-18           3 killed in bus-car collision in Comilla
# 4      2021-06-16          6 die in road accidents in Dhaka, Gazipur
# ..            ...                                                ...
# 283    2016-08-15                    Road accident kills 1 in Natore
# 284    2016-08-04  Two motorcyclists killed in Manikganj road acc...
# 285    2016-07-16                Four die in Manikganj road accident
# 286    2016-07-15             BNP leader hurt in Dinajpur road crash
# 287    2016-06-24                  3 killed in Gazipur road accident
#
#             Location_appox                                           location  \
# 0        Dhaka, Bangladesh  ঢাকা, Chanpara Bazar, ঢাকা জেলা, ঢাকা বিভাগ, 1...
# 1    Narsingdi, Bangladesh  নরসিংদী, নরসিংদী জেলা, ঢাকা বিভাগ, 1602, বাংলাদেশ
# 2        Dhaka, Bangladesh  ঢাকা, Chanpara Bazar, ঢাকা জেলা, ঢাকা বিভাগ, 1...
# 3      Comilla, Bangladesh  কুমিল্লা, কুমিল্লা জেলা, চট্টগ্রাম বিভাগ, 3500...
# 4        Dhaka, Bangladesh  ঢাকা, Chanpara Bazar, ঢাকা জেলা, ঢাকা বিভাগ, 1...
# ..                     ...                                                ...
# 283     Natore, Bangladesh  chakrampur,Natore,Bangladesh, N/A, N502, নাটোর...
# 284  Manikganj, Bangladesh               মানিকগঞ্জ জেলা, ঢাকা বিভাগ, বাংলাদেশ
# 285  Manikganj, Bangladesh               মানিকগঞ্জ জেলা, ঢাকা বিভাগ, বাংলাদেশ
# 286   Dinajpur, Bangladesh            দিনাজপুর, দিনাজপুর জেলা, 5216, বাংলাদেশ
# 287    Gazipur, Bangladesh  গাজীপুর, গাজীপুর জেলা, ঢাকা বিভাগ, 1701, বাংলাদেশ
#
#       Latitude  Longitude  Weight  year  month months_in_full month_year
# 0    23.810651  90.412647     6.0  2021      6           June    06 2021
# 1    23.915645  90.698196     6.0  2021      6           June    06 2021
# 2    23.810651  90.412647     6.0  2021      6           June    06 2021
# 3    23.461061  91.180875     6.0  2021      6           June    06 2021
# 4    23.810651  90.412647     6.0  2021      6           June    06 2021
# ..         ...        ...     ...   ...    ...            ...        ...
# 283  24.411130  88.997356     8.0  2016      8         August    08 2016
# 284  23.871163  89.998783     8.0  2016      8         August    08 2016
# 285  23.871163  89.998783     7.0  2016      7           July    07 2016
# 286  25.626071  88.634623     7.0  2016      7           July    07 2016
# 287  23.998080  90.422985     6.0  2016      6           June    06 2016
#
# [288 rows x 11 columns]

# %%
import folium
from folium.plugins import *
from folium import plugins

# %%
df_new['indexx'] = df_new['months_in_full'] + '/' + df_new['year'].astype(str)
lista_index = df_new['indexx'].unique().tolist()

weight_list = []

df_new['conta'] = 1 
for x in df_new['month_year'].sort_values().unique(): 
    weight_list.append(df_new.loc[df_new['month_year'] == x, 
                                        ['Latitude',"Longitude",'conta']].groupby(['Latitude','Longitude']).sum().reset_index().values.tolist()) 
    
base_map = folium.Map(location=[23.6850, 90.3563],tiles="stamen toner",zoom_start = 6) 

#create the heatmap from our List 
HeatMapWithTime(weight_list, radius=20,index= lista_index, gradient={0.1: 'blue',0.5: 'green', 0.5: 'yellow', 0.95: 'orange', 1: 'red'}, \
                                                                     
                        auto_play =True, min_opacity=0.5, max_opacity=1, use_local_extrema=True).add_to(base_map) 
                                                                
                                                                     
base_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_94efbac9588c42e19d3407a16683ff28%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/iso8601-js-period%400.2.1/iso8601.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet-timedimension%401.1.1/dist/leaflet.timedimension.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/pa7_hm.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/pa7_leaflet_hm.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet-timedimension%401. ...

# %% [markdown]
# ### References
#
# * https://medium.com/nerd-for-tech/time-lapse-heat-maps-with-folium-1847f53ec956
