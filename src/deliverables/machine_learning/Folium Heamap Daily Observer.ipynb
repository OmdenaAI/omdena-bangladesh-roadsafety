# %% [markdown]
# ### Data Cleaning & Interactive Folium Maps for Final Phases: Daily Observer

# %%
#!pip install -U spacy
#!python -m spacy download en
#!pip install geopy

# %%
# for manipulating dataframes
import pandas as pd
import numpy as np
# for natural language processing: named entity recognition
import spacy
from collections import Counter
import en_core_web_sm
nlp = en_core_web_sm.load()
# for visualizations
# %matplotlib inline

from geopy.geocoders import Nominatim
geolocator = Nominatim(user_agent="jjj")

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('../input/dhakatribunecomplete/TheDailyObserver-cleaned-final.csv')
df = df[['links', 'Year', 'date']]

# %%
df_new = pd.read_csv('../input/dhakatribunecomplete/TheDailyObserver.csv')
df_new
# Out:
#                                              links  \
# 0    https://www.observerbd.com/news.php?id=319689
# 1    https://www.observerbd.com/news.php?id=319655
# 2    https://www.observerbd.com/news.php?id=319338
# 3    https://www.observerbd.com/news.php?id=319194
# 4    https://www.observerbd.com/news.php?id=319024
# ..                                             ...
# 804  https://www.observerbd.com/news.php?id=176806
# 805  https://www.observerbd.com/news.php?id=176637
# 806  https://www.observerbd.com/news.php?id=176524
# 807  https://www.observerbd.com/news.php?id=176389
# 808  https://www.observerbd.com/news.php?id=176070
#
#                                                 titles  \
# 0    Mother Killed, police official injured in Mada...
# 1               Three killed in Satkhira bike accident
# 2       2 killed, 5 injured in Cumilla road accident\n
# 3    Four killed in Jashore accident on way to buy ...
# 4               Two killed in Mymensingh road accident
# ..                                                 ...
# 804               Mother-son killed in road accident\n
# 805                    Sirajganj road accident kills 3
# 806                    Teacher killed in road accident
# 807        3 of a family die in Faridpur road accident
# 808               \n\n2 bikers killed in road accident
#
#                                                   News
# 0    Mother Killed, police official injured in Mada...
# 1    Three killed in Satkhira bike accidentThree me...
# 2    Two were killed and five others were severely ...
# 3    Four killed in Jashore accident on way to buy ...
# 4    Two killed in Mymensingh road accident Two peo...
# ..                                                 ...
# 804  A woman and her son were killed while her daug...
# 805  Sirajganj road accident kills 3Three people we...
# 806  Teacher killed in road accident A retired teac...
# 807  3 of a family die in Faridpur road accidentThr...
# 808  2 bikers killed in road accidentTwo motorcycle...
#
# [809 rows x 3 columns]

# %%
df1 = df.merge(df_new, how='left', on ='links')
df1
# Out:
#                                               links  Year    date  \
# 0     https://www.observerbd.com/news.php?id=319689  2021  30-Jun
# 1     https://www.observerbd.com/news.php?id=319655  2021  30-Jun
# 2     https://www.observerbd.com/news.php?id=319338  2021  28-Jun
# 3     https://www.observerbd.com/news.php?id=319194  2021  27-Jun
# 4     https://www.observerbd.com/news.php?id=319024  2021  26-Jun
# ...                                             ...   ...     ...
# 1382  https://www.observerbd.com/news.php?id=176806  2019  06-Jan
# 1383  https://www.observerbd.com/news.php?id=176637  2019  05-Jan
# 1384  https://www.observerbd.com/news.php?id=176524  2019  04-Jan
# 1385  https://www.observerbd.com/news.php?id=176389  2019  03-Jan
# 1386  https://www.observerbd.com/news.php?id=176070  2019  01-Jan
#
#                                                  titles  \
# 0     Mother Killed, police official injured in Mada...
# 1                Three killed in Satkhira bike accident
# 2        2 killed, 5 injured in Cumilla road accident\n
# 3     Four killed in Jashore accident on way to buy ...
# 4                Two killed in Mymensingh road accident
# ...                                                 ...
# 1382               Mother-son killed in road accident\n
# 1383                    Sirajganj road accident kills 3
# 1384                    Teacher killed in road accident
# 1385        3 of a family die in Faridpur road accident
# 1386               \n\n2 bikers killed in road accident
#
#                                                    News
# 0     Mother Killed, police official injured in Mada...
# 1     Three killed in Satkhira bike accidentThree me...
# 2     Two were killed and five others were severely ...
# 3     Four killed in Jashore accident on way to buy ...
# 4     Two killed in Mymensingh road accident Two peo...
# ...                                                 ...
# 1382  A woman and her son were killed while her daug...
# 1383  Sirajganj road accident kills 3Three people we...
# 1384  Teacher killed in road accident A retired teac...
# 1385  3 of a family die in Faridpur road accidentThr...
# 1386  2 bikers killed in road accidentTwo motorcycle...
#
# [1387 rows x 5 columns]

# %% [markdown]
# ### Employing spaCy to retrive the GPEs

# %%
# %%time

col_value = []

for i in range(len(df1)):
    tokens = nlp(''.join(str(df1['News'][i])))
    
    location_list = []
    for ent in tokens.ents:
        if ent.label_ == 'GPE':
            location_list.append(ent.text)
    
    
    location_counts = Counter(location_list).most_common(1)
    col_value.append(''.join(filter(str.isalpha, str(location_counts))))
# Out:
# CPU times: user 55.4 s, sys: 84.5 ms, total: 55.4 s
# Wall time: 55.5 s

# %%
df1['Location_appox'] = col_value

# %%
# dropping duplicate values
df1 = df1.drop_duplicates(keep=False)
df1
# Out:
#                                               links  Year    date  \
# 0     https://www.observerbd.com/news.php?id=319689  2021  30-Jun
# 1     https://www.observerbd.com/news.php?id=319655  2021  30-Jun
# 2     https://www.observerbd.com/news.php?id=319338  2021  28-Jun
# 3     https://www.observerbd.com/news.php?id=319194  2021  27-Jun
# 4     https://www.observerbd.com/news.php?id=319024  2021  26-Jun
# ...                                             ...   ...     ...
# 1382  https://www.observerbd.com/news.php?id=176806  2019  06-Jan
# 1383  https://www.observerbd.com/news.php?id=176637  2019  05-Jan
# 1384  https://www.observerbd.com/news.php?id=176524  2019  04-Jan
# 1385  https://www.observerbd.com/news.php?id=176389  2019  03-Jan
# 1386  https://www.observerbd.com/news.php?id=176070  2019  01-Jan
#
#                                                  titles  \
# 0     Mother Killed, police official injured in Mada...
# 1                Three killed in Satkhira bike accident
# 2        2 killed, 5 injured in Cumilla road accident\n
# 3     Four killed in Jashore accident on way to buy ...
# 4                Two killed in Mymensingh road accident
# ...                                                 ...
# 1382               Mother-son killed in road accident\n
# 1383                    Sirajganj road accident kills 3
# 1384                    Teacher killed in road accident
# 1385        3 of a family die in Faridpur road accident
# 1386               \n\n2 bikers killed in road accident
#
#                                                    News Location_appox
# 0     Mother Killed, police official injured in Mada...
# 1     Three killed in Satkhira bike accidentThree me...
# 2     Two were killed and five others were severely ...       Chandina
# 3     Four killed in Jashore accident on way to buy ...        Jashore
# 4     Two killed in Mymensingh road accident Two peo...      Jangaldia
# ...                                                 ...            ...
# 1382  A woman and her son were killed while her daug...     Godaikandi
# 1383  Sirajganj road accident kills 3Three people we...
# 1384  Teacher killed in road accident A retired teac...          Kasba
# 1385  3 of a family die in Faridpur road accidentThr...       Boalmari
# 1386  2 bikers killed in road accidentTwo motorcycle...         Lalpur
#
# [652 rows x 6 columns]

# %% [markdown]
# ### Crazy cleaning starts here

# %%
df1['Location_appox'] = df1['Location_appox'].replace( '', np.nan)
df1['Location_appox'] = df1['Location_appox'].replace( 'DhakaAricha', 'Dhaka')
df1['Location_appox'] = df1['Location_appox'].replace( 'HaziparaPatrolPump', 'Dhaka')
df1['Location_appox'] = df1['Location_appox'].replace( 'Kamarkhand', 'Sirajganj')
df1['Location_appox'] = df1['Location_appox'].replace( 'Chhagalnaiya', 'Feni')
df1['Location_appox'] = df1['Location_appox'].replace( 'Lohaghara', 'Chittagong')
df1['Location_appox'] = df1['Location_appox'].replace( 'Boilgaon', 'Chittagong')
df1['Location_appox'] = df1['Location_appox'].replace( 'Banshkhali Upazila', 'Chittagong')
df1['Location_appox'] = df1['Location_appox'].replace( 'Nodigram', 'Nandigram')
df1['Location_appox'] = df1['Location_appox'].replace( 'Nondigram', 'Nandigram')
df1['Location_appox'] = df1['Location_appox'].replace( 'PabnaaccidentA', 'Pabna')

df1['Location_appox'] = df1['Location_appox'].replace( 'Jalashivillage', 'Panchagarh')
df1['Location_appox'] = df1['Location_appox'].replace( 'Katalivillage', 'Panchagarh')
df1['Location_appox'] = df1['Location_appox'].replace( 'Joyrampur', 'Dhaka')
df1['Location_appox'] = df1['Location_appox'].replace( 'Phulbarimunicipality', 'Dinajpur')
df1['Location_appox'] = df1['Location_appox'].replace( 'JhalakatiDistrict', 'Jhalakati')
df1['Location_appox'] = df1['Location_appox'].replace( 'Sylhetcity', 'Sylhet')
df1['Location_appox'] = df1['Location_appox'].replace( 'Sylhetcity', 'Sylhet')
df1['Location_appox'] = df1['Location_appox'].replace( 'KolaroaJashore', 'Jashore')
df1['Location_appox'] = df1['Location_appox'].replace( 'PatharghataUpazila', 'Barguna')
df1['Location_appox'] = df1['Location_appox'].replace( 'Kaloroa', 'Satkhira')
df1['Location_appox'] = df1['Location_appox'].replace( 'Joypuhat', 'Joypurhat')
df1['Location_appox'] = df1['Location_appox'].replace( 'Naogao', 'Naogaon')
df1['Location_appox'] = df1['Location_appox'].replace( 'EastHajirpara', 'Dhaka')
df1['Location_appox'] = df1['Location_appox'].replace( 'Hazirparavillage', 'Chittagong')
df1['Location_appox'] = df1['Location_appox'].replace( 'AfajiaBazar', 'Hatiya Island')
df1['Location_appox'] = df1['Location_appox'].replace( 'Kurigrams', 'Kurigram')
df1['Location_appox'] = df1['Location_appox'].replace( 'Bbaria', 'Brahmanbaria')
df1['Location_appox'] = df1['Location_appox'].replace( 'Awravillage', 'Joypurhat')
df1['Location_appox'] = df1['Location_appox'].replace( 'Lakkatura', 'Sylhet')
df1['Location_appox'] = df1['Location_appox'].replace( 'DaganbhuiyanBazar', 'Chittagong')
df1['Location_appox'] = df1['Location_appox'].replace( 'FaridpuraccidentTwo', 'Faridpur')
df1['Location_appox'] = df1['Location_appox'].replace( 'DaganbhuiyanBazar', 'Chittagong')
df1['Location_appox'] = df1['Location_appox'].replace( 'DaganbhuiyanBazar', 'Chittagong')
df1['Location_appox'] = df1['Location_appox'].replace( 'Chechniakandi', 'Gopalganj')
df1['Location_appox'] = df1['Location_appox'].replace( 'Charfesson', 'Barisal')
df1['Location_appox'] = df1['Location_appox'].replace( 'Horirampur', 'Harirampur')
df1['Location_appox'] = df1['Location_appox'].replace( 'Mymensinghs', 'Mymensingh')
df1['Location_appox'] = df1['Location_appox'].replace( 'Rusulpura', 'Tangail')
df1['Location_appox'] = df1['Location_appox'].replace( 'Rajshahiparavillage', 'Rajshahi')
df1['Location_appox'] = df1['Location_appox'].replace( 'Binaivillage', 'Joypurhat')
df1['Location_appox'] = df1['Location_appox'].replace( 'JashoreBenapole', 'Jashore')
df1['Location_appox'] = df1['Location_appox'].replace( 'Sheanpara', 'Patiya Upazila')
df1['Location_appox'] = df1['Location_appox'].replace( 'ChoughoriBazar', 'Sylhet')
df1['Location_appox'] = df1['Location_appox'].replace( 'GararonVillage', 'Gazipur')
df1['Location_appox'] = df1['Location_appox'].replace( 'Subarnachar', 'Noakhali')
df1['Location_appox'] = df1['Location_appox'].replace( 'Ctg', 'Chittagong')
df1['Location_appox'] = df1['Location_appox'].replace( 'MasrutNakhenda', 'Kurigram')
df1['Location_appox'] = df1['Location_appox'].replace( 'PaschimRampur', 'Sylhet')
df1['Location_appox'] = df1['Location_appox'].replace( 'Fulgazi', 'Feni')
df1['Location_appox'] = df1['Location_appox'].replace( 'UllaparaVillage', 'Sirajganj')
df1['Location_appox'] = df1['Location_appox'].replace( 'Supariparavillage', 'Thakurgaon')
df1['Location_appox'] = df1['Location_appox'].replace( 'AlamBazar', 'Chittagong')
df1['Location_appox'] = df1['Location_appox'].replace( 'Pashchimdasra', 'Manikganj')
df1['Location_appox'] = df1['Location_appox'].replace( 'Borashura', 'Gopalganj')
df1['Location_appox'] = df1['Location_appox'].replace( 'Korbaniaghona', 'Chittagong')
df1['Location_appox'] = df1['Location_appox'].replace( 'Dhakacity', 'Dhaka')
df1['Location_appox'] = df1['Location_appox'].replace( 'Patkelghata', 'Khulna')
df1['Location_appox'] = df1['Location_appox'].replace( 'Bakhorerkandi', 'Madaripur')
df1['Location_appox'] = df1['Location_appox'].replace( 'MollikBariBazar', 'Mymensingh')
df1['Location_appox'] = df1['Location_appox'].replace( 'Baniarchhara', "Cox's Bazar")
df1['Location_appox'] = df1['Location_appox'].replace( 'HajirhatTalpatti', 'Chittagong')
df1['Location_appox'] = df1['Location_appox'].replace( 'Kanaitola', 'Jhenaidah')
df1['Location_appox'] = df1['Location_appox'].replace( 'Cox', "Cox's Bazar")
df1['Location_appox'] = df1['Location_appox'].replace( 'KuakataBeach', 'Patuakhali')
df1['Location_appox'] = df1['Location_appox'].replace( 'MathbariaUpazila', 'Mathbaria Upazila')
df1['Location_appox'] = df1['Location_appox'].replace( 'Palashpur', 'Khagrachari')
df1['Location_appox'] = df1['Location_appox'].replace( 'Simultala', 'Dhaka')
df1['Location_appox'] = df1['Location_appox'].replace( 'Nabogram', 'Dhaka')
df1['Location_appox'] = df1['Location_appox'].replace( 'Kamarkhanda', 'Sirajganj')
df1['Location_appox'] = df1['Location_appox'].replace( 'Tetultoly', 'Mymensingh')
df1['Location_appox'] = df1['Location_appox'].replace( 'Hirapurvillage', 'Lakshmipur')

df1['Location_appox'] = df1['Location_appox'].replace( 'BhandariaUpazila', 'Pirojpur')
df1['Location_appox'] = df1['Location_appox'].replace( 'SreepurUpazila', 'Gazipur')
df1['Location_appox'] = df1['Location_appox'].replace( 'NoaparaVillage', 'Noapara')
df1['Location_appox'] = df1['Location_appox'].replace( 'BaroharishpurBypass', 'Bheramara')
df1['Location_appox'] = df1['Location_appox'].replace( 'DemraTrafficZone', 'Dhaka')
df1['Location_appox'] = df1['Location_appox'].replace( 'Kapastala', 'Dhaka')

df1['Location_appox'] = df1['Location_appox'].replace( 'Kakdanga', 'Khulna')
df1['Location_appox'] = df1['Location_appox'].replace( 'Godaikandi', 'Netrokona')
df1['Location_appox'] = df1['Location_appox'].replace( 'Nirwarispur', 'Noakhali')
df1['Location_appox'] = df1['Location_appox'].replace( 'Dholiapara', 'Dhaka')
df1['Location_appox'] = df1['Location_appox'].replace( 'NaudaparaAmchattar', 'Noapara')
df1['Location_appox'] = df1['Location_appox'].replace( 'Paolanpur', 'Narshingdi')

df1['Location_appox'] = df1['Location_appox'].replace( 'Sapahar', 'Rajshahi')
df1['Location_appox'] = df1['Location_appox'].replace( 'Louhajang', 'Munshiganj')
df1['Location_appox'] = df1['Location_appox'].replace( 'BelkuchiUpazila', 'Sirajganj')
df1['Location_appox'] = df1['Location_appox'].replace( 'Soidabad', 'Saidabad')
df1['Location_appox'] = df1['Location_appox'].replace( 'Orakandi', 'Faridpur')
df1['Location_appox'] = df1['Location_appox'].replace( 'Moksudpur', 'Gopalganj')
df1['Location_appox'] = df1['Location_appox'].replace( 'Tilchara', 'Gopalganj')

df1['Location_appox'] = df1['Location_appox'].replace( 'Uzirpur', 'Barisal')
df1['Location_appox'] = df1['Location_appox'].replace( 'Boraigram', 'Natore')
df1['Location_appox'] = df1['Location_appox'].replace( 'Sayedabad', 'Dhaka')
df1['Location_appox'] = df1['Location_appox'].replace( 'Geor', 'Ghior')
df1['Location_appox'] = df1['Location_appox'].replace( 'Chattagram', 'Chittagong')
df1['Location_appox'] = df1['Location_appox'].replace( 'Chouddagram', 'Cumilla')
df1['Location_appox'] = df1['Location_appox'].replace( 'Gadaikandi', 'Netrokona')

df1['Location_appox'] = df1['Location_appox'].replace( 'Tentulia', 'Panchagarh')
df1['Location_appox'] = df1['Location_appox'].replace( 'Laxmipur', 'Lakshmipur')
df1['Location_appox'] = df1['Location_appox'].replace( 'Jaintapur', 'Sylhet')
df1['Location_appox'] = df1['Location_appox'].replace( 'Rangunia', 'Chittagong')
df1['Location_appox'] = df1['Location_appox'].replace( 'Kotalipara', 'Gopalganj')
df1['Location_appox'] = df1['Location_appox'].replace( 'Jhenidah', 'Jhenaidah')
df1['Location_appox'] = df1['Location_appox'].replace( 'Gadaikandi', 'Netrokona')

df1['Location_appox'] = df1['Location_appox'].replace( 'Jhalakati', 'Jhalokati')
df1['Location_appox'] = df1['Location_appox'].replace( 'Jhenidah', 'Jhenaidah')
df1['Location_appox'] = df1['Location_appox'].replace( 'Gadaikandi', 'Netrokona')
df1['Location_appox'] = df1['Location_appox'].replace( 'Baraigram', 'Natore')

df1['Location_appox'] = df1['Location_appox'].replace( 'southPalashpurofBarishalcity', 'Barishal')
df1['Location_appox'] = df1['Location_appox'].replace( 'ShajahanpurUpazila', 'Bogra')
df1['Location_appox'] = df1['Location_appox'].replace( 'GomastapurUpazila', 'Nawabganj')
df1['Location_appox'] = df1['Location_appox'].replace( 'Gabindaganj', 'Gaibandha')

df1['Location_appox'] = df1['Location_appox'].replace( 'FakirhatUpazila', 'Bagerhat')
df1['Location_appox'] = df1['Location_appox'].replace( 'Rousonbagh', 'Panchagarh')
df1['Location_appox'] = df1['Location_appox'].replace( 'BrahmanbariasNabinagar', 'Brahmanbaria')
df1['Location_appox'] = df1['Location_appox'].replace( 'Ramgar', 'Khagrachari')

df1['Location_appox'] = df1['Location_appox'].replace( 'Kashiadanga', 'Rajshahi')
df1['Location_appox'] = df1['Location_appox'].replace( 'Gomostapur', 'Nawabganj')
df1['Location_appox'] = df1['Location_appox'].replace( 'Khanjanamara', 'Rangpur')
df1['Location_appox'] = df1['Location_appox'].replace( 'Khejurtola', 'Chuadanga')

df1['Location_appox'] = df1['Location_appox'].replace( 'PakshiUnion', 'Pabna')
df1['Location_appox'] = df1['Location_appox'].replace( 'LamaMunicipality', 'Lama')
df1['Location_appox'] = df1['Location_appox'].replace( 'Rasulpurvillage', 'Tangail')
df1['Location_appox'] = df1['Location_appox'].replace( 'Manikchhari', 'Chittagong')

df1['Location_appox'] = df1['Location_appox'].replace( 'ChattogramCity', 'Chittagong')
df1['Location_appox'] = df1['Location_appox'].replace( 'NoakhaliDistrict', 'Noakhali')
df1['Location_appox'] = df1['Location_appox'].replace( 'KhulnaCityCorporation', 'Khulna')
df1['Location_appox'] = df1['Location_appox'].replace( 'NatoreDistrict', 'Natore')

df1['Location_appox'] = df1['Location_appox'].replace( 'CumillaCity', 'Cumilla')
df1['Location_appox'] = df1['Location_appox'].replace( 'NoakhaliDistrict', 'Noakhali')
df1['Location_appox'] = df1['Location_appox'].replace( 'BashundharaResidentialArea', 'Dhaka')
df1['Location_appox'] = df1['Location_appox'].replace( 'KhulnaMawa', 'Khulna')

df1['Location_appox'] = df1['Location_appox'].replace( 'Godagai', 'Rajshahi')
df1['Location_appox'] = df1['Location_appox'].replace( 'Kalignaj', 'Gazipur')
df1['Location_appox'] = df1['Location_appox'].replace( 'Vektamari', 'Bagerhat')
df1['Location_appox'] = df1['Location_appox'].replace( 'AkkelpurMunicipality', 'Joypurhat')
df1['Location_appox'] = df1['Location_appox'].replace( 'Baufal', 'Patuakhali')
df1['Location_appox'] = df1['Location_appox'].replace( 'BonparaMunicipality', 'Natore')
df1['Location_appox'] = df1['Location_appox'].replace( 'Piljanga', 'Bhola')
df1['Location_appox'] = df1['Location_appox'].replace( 'ShibcharUpazila', 'Dhaka')
df1['Location_appox'] = df1['Location_appox'].replace( 'Kamalnagar', 'Chittagong')
df1['Location_appox'] = df1['Location_appox'].replace( 'Saddarparavillage', 'Gaibandha')
df1['Location_appox'] = df1['Location_appox'].replace( 'MohadevpurUpazila', 'Rajshahi')
df1['Location_appox'] = df1['Location_appox'].replace( 'Madariganj', 'Jamalpur')
df1['Location_appox'] = df1['Location_appox'].replace( 'Shahipara', 'Rangpur')
df1['Location_appox'] = df1['Location_appox'].replace( 'Kalikapurvillage', 'Satkhira')
df1['Location_appox'] = df1['Location_appox'].replace( 'Jafarpurvillage', 'Jashore')
df1['Location_appox'] = df1['Location_appox'].replace( 'Nagardia', 'Faridpur')
df1['Location_appox'] = df1['Location_appox'].replace( 'ChawkgopalVillage', 'Sylhet')
df1['Location_appox'] = df1['Location_appox'].replace( 'Lemua', 'Barguna')
df1['Location_appox'] = df1['Location_appox'].replace( 'Noakati', 'Khulna')
df1['Location_appox'] = df1['Location_appox'].replace( 'Pirgachha', 'Rangpur')
df1['Location_appox'] = df1['Location_appox'].replace( 'Ujanpara', 'Rajshahi')
df1['Location_appox'] = df1['Location_appox'].replace( 'Telijana', 'Sirajganj')
df1['Location_appox'] = df1['Location_appox'].replace( 'Bukailvillage', 'Faridpur')
df1['Location_appox'] = df1['Location_appox'].replace( 'Bhobanipurvillage', 'Meherpur')
df1['Location_appox'] = df1['Location_appox'].replace( 'BegumganjUpazila', 'Noakhali')
df1['Location_appox'] = df1['Location_appox'].replace( 'Kellaposhi', 'Bogura')
df1['Location_appox'] = df1['Location_appox'].replace( 'JangalbariVillage', 'Kishoreganj')
df1['Location_appox'] = df1['Location_appox'].replace( 'ShailkupaUpazila', 'Jhenaidah')
df1['Location_appox'] = df1['Location_appox'].replace( 'Alalpur', 'Dhaka')
df1['Location_appox'] = df1['Location_appox'].replace( 'Hrila', 'Teknaf')
df1['Location_appox'] = df1['Location_appox'].replace( 'Ullahpara', 'Sirajganj')
df1['Location_appox'] = df1['Location_appox'].replace( 'BarishalSher', 'Barisal')
df1['Location_appox'] = df1['Location_appox'].replace( 'Bhennapara', 'Gopalganj')
df1['Location_appox'] = df1['Location_appox'].replace( 'KasbaUpazila', 'Brahmanbaria')
df1['Location_appox'] = df1['Location_appox'].replace( 'Gosainagar', 'Manikganj')
df1['Location_appox'] = df1['Location_appox'].replace( 'UlipurUpazila', 'Rangpur')
df1['Location_appox'] = df1['Location_appox'].replace( 'Aiirkhamar', 'Lalmonirhat')
df1['Location_appox'] = df1['Location_appox'].replace( 'SapaharUpazila', 'Naogaon')
df1['Location_appox'] = df1['Location_appox'].replace( 'Karnopur', 'Gazipur')
df1['Location_appox'] = df1['Location_appox'].replace( 'Narayangaj', 'Narayanganj')
df1['Location_appox'] = df1['Location_appox'].replace( 'Gopalaganj', 'Gopalganj')


X = ['MofizulKarigor', 'BariMajlis', 'Peru', 'minibus', 'Signboard', 'AnwerHossain', 'Jangaldia', 'KundaisVillage', "Nazma", 'Jugantar', "Canada", 'Sonmandi', "Bangladesh", "Oman", "I0"\
    'Banganadhu', 'Banganadhu', "Anik", "Bokcharavillage", "Hanif","India", "Kabul", "Cuba", "Farakkabandhunion", "Md", "IO", "Jannatullah", "MansurAkon", "Votvoti", "Yeasin", "Ghana",\
    "Nuzrul", "Madrasha", "Pasadena", "Jasmin", "Jakir", "Mridha", "Abdur", "SaudiArabia", "Tharhaat", "SI", "Borhanuddin", "AbulHossain", 'Bolivia', "Mujahid", \
    "Akhtar", "AbdurRazzaq", "Rafiqul", 'Tazreen', "Liton", "Jeddah", "Iran", "Rasel", "ObilerBazar", "Egypt", "BarAwlia", "Malaysia", "Bypass", "Imran", "DistrictSpecialBranch",\
    "Mohishavillage", 'Pamerpara', "Nagardiavillage", "Nijkhamar", 'Paotana', 'TanvirHossain', 'Bhorbhoravillage', 'Baimhativillage', 'Molliker', 'Chandrakhanavillage',\
    'GhanekrishtapurVillage', 'Mulaid', "ShimultolyVillage", 'SunoiVillage', 'Fakhrul', 'DinajpurThakurgaon', 'DhakaSylhet', 'DhakaArichaHighway', 'Baikhirvillage', 'DoldolaVillage'\
    'Dhonialapara', 'HasliVillage', 'Goriarpar', 'Abudhabi', 'BazarTeknaf', 'AbuDhabi', 'BILS', "Israfil", "Bangladesh", 'Jaintapur', 'Rangunia', 'Jamtala', 'Kotalipara', 'Jhenidah', 'Palmas',       
    'Jalpaiguri', 'Jhalakati', 'Bhangura', 'Andharijhar', 'Balrampur', 'Rishipara', 'Osmaninagar', 'Sarangpur', 'Jazira', 'Sujatpur', 'Hafez', 'Jammu', 'Ghonapara', 'Abhaynagar',
    'Moragang', 'Paba', 'Kathalbari', 'SriLanka', 'Riyadh', 'Jibonpur', 'Chuniapara', 'Rahimabad', 'Kolabari', 'Pakati', 'Shimulia', 'Bikash', 'Dhonialapara', 'Utsab', 'DoldolaVillage',\
    "Kolkata", 'Chhadaha', "Mexico", 'UpalshohorVillage', 'NitaiMazumdar', 'Munshiganjroad', 'Mohendra', 'Mosharhati', 'Goshercharvillage', 'Bailjuri', 'Mandartola', 'Durgapurvillage', \
     'HogalpashaVillage', 'Tiktikipara', 'Sadikul', 'Swapan', 'TokimunnesaBegum', 'Hamidul', 'accidentShabanaAzmi', 'BelalHossain', 'NurHossain', 'Organising', 'Meduari', 'Baddipur',\
     'Banshgara', 'Bhojergati', 'Shibgati', 'Gualbari', 'Octogenarian', 'Hanjala', 'FoujdarhatBypass', 'Bakcharavillage', 'FulpurUpazillas', 'AramnagarVillage', 'Chhilimpur',\
     'Sutahati', 'DhipikuraVillage', 'Nayadingi', 'Grambandi', 'TF', 'Ruhul', 'Nasrin', 'SB', "Sajib", "Bappi", "Kashem", "Hashem", "Kalu", 'Mabia', "Fahad", "Kamrul", "Uttar", "Dulal", \
    "Elderly", "Mahbub", "LA", "City", "RI", "Hadi", "Taslima", "Parvez", "Roxy"]
     

df1.loc[df1.Location_appox.isin(X), 'Location_appox'] = np.NaN

# %%
df1 = df1.dropna()
df1
# Out:
#                                               links  Year    date  \
# 2     https://www.observerbd.com/news.php?id=319338  2021  28-Jun
# 3     https://www.observerbd.com/news.php?id=319194  2021  27-Jun
# 10    https://www.observerbd.com/news.php?id=318258  2021  21-Jun
# 26    https://www.observerbd.com/news.php?id=317968  2021  19-Jun
# 27    https://www.observerbd.com/news.php?id=317963  2021  19-Jun
# ...                                             ...   ...     ...
# 1381  https://www.observerbd.com/news.php?id=176928  2019  07-Jan
# 1382  https://www.observerbd.com/news.php?id=176806  2019  06-Jan
# 1384  https://www.observerbd.com/news.php?id=176524  2019  04-Jan
# 1385  https://www.observerbd.com/news.php?id=176389  2019  03-Jan
# 1386  https://www.observerbd.com/news.php?id=176070  2019  01-Jan
#
#                                                  titles  \
# 2        2 killed, 5 injured in Cumilla road accident\n
# 3     Four killed in Jashore accident on way to buy ...
# 10       Man, nephew killed in Chattogram bike accident
# 26             NGO worker killed in Bhola road accident
# 27              Three killed in Narsingdi road accident
# ...                                                 ...
# 1381      Mother, son killed in Netrakona road accident
# 1382               Mother-son killed in road accident\n
# 1384                    Teacher killed in road accident
# 1385        3 of a family die in Faridpur road accident
# 1386               \n\n2 bikers killed in road accident
#
#                                                    News Location_appox
# 2     Two were killed and five others were severely ...       Chandina
# 3     Four killed in Jashore accident on way to buy ...        Jashore
# 10    Man, nephew killed in Chattogram bike accident...       Mirsarai
# 26    NGO worker killed in Bhola road accidentA work...          Bhola
# 27    Three killed in Narsingdi road accidentThree p...      Narsingdi
# ...                                                 ...            ...
# 1381  NETRAKONA, Jan 6: A mother and her son were ki...          Dhaka
# 1382  A woman and her son were killed while her daug...      Netrokona
# 1384  Teacher killed in road accident A retired teac...          Kasba
# 1385  3 of a family die in Faridpur road accidentThr...       Boalmari
# 1386  2 bikers killed in road accidentTwo motorcycle...         Lalpur
#
# [469 rows x 6 columns]

# %%
a = list(df1.Location_appox.unique())

coordinates = []

def loc_errors(a):
    list_of_error_loc = []
    for loc in a:
        try:
            location = geolocator.geocode(str(loc + ", Bangladesh"))
            lat_long = (location.latitude, location.longitude)
            coordinates.append(list(lat_long))
        except Exception:
            list_of_error_loc.append(loc)
            continue
    return list_of_error_loc

# %time list_of_error_loc = loc_errors(a)
list_of_error_loc
# Out:
# CPU times: user 472 ms, sys: 36.9 ms, total: 508 ms
# Wall time: 1min 47s
# []

# %%
df1 = df1.reset_index(drop = True)

# %%
df1.Location_appox = df1['Location_appox'] + ', Bangladesh'
df1.head()
# Out:
#                                            links  Year    date  \
# 0  https://www.observerbd.com/news.php?id=319338  2021  28-Jun
# 1  https://www.observerbd.com/news.php?id=319194  2021  27-Jun
# 2  https://www.observerbd.com/news.php?id=318258  2021  21-Jun
# 3  https://www.observerbd.com/news.php?id=317968  2021  19-Jun
# 4  https://www.observerbd.com/news.php?id=317963  2021  19-Jun
#
#                                               titles  \
# 0     2 killed, 5 injured in Cumilla road accident\n
# 1  Four killed in Jashore accident on way to buy ...
# 2     Man, nephew killed in Chattogram bike accident
# 3           NGO worker killed in Bhola road accident
# 4            Three killed in Narsingdi road accident
#
#                                                 News         Location_appox
# 0  Two were killed and five others were severely ...   Chandina, Bangladesh
# 1  Four killed in Jashore accident on way to buy ...    Jashore, Bangladesh
# 2  Man, nephew killed in Chattogram bike accident...   Mirsarai, Bangladesh
# 3  NGO worker killed in Bhola road accidentA work...      Bhola, Bangladesh
# 4  Three killed in Narsingdi road accidentThree p...  Narsingdi, Bangladesh

# %% [markdown]
# ### Using GeoPy to retrive coordinates of the locations

# %%
# %%time

loc_bengali = []
lat = []
lon = []

for i in range(len(df1)):
    location = geolocator.geocode(df1.Location_appox.values[i])
    print(df1.Location_appox.values[i])
    loc_bengali.append(location.address)
    lat.append(location.latitude)
    lon.append(location.longitude)
# Out:
# Chandina, Bangladesh
# Jashore, Bangladesh
# Mirsarai, Bangladesh
# Bhola, Bangladesh
# Narsingdi, Bangladesh
# Bogura, Bangladesh
# Narsingdi, Bangladesh
# Bhandaria, Bangladesh
# Dhaka, Bangladesh
# Bangabandhu, Bangladesh
# Barishal, Bangladesh
# Manikganj, Bangladesh
# Dhamrai, Bangladesh
# Dinajpur, Bangladesh
# Ashulia, Bangladesh
# Bogra, Bangladesh
# Manda, Bangladesh
# Bhurungamari, Bangladesh
# Noakhali, Bangladesh
# Shahjadpur, Bangladesh
# Dhaka, Bangladesh
# Raghunathpur, Bangladesh
# Chattogram, Bangladesh
# Narail, Bangladesh
# Narail, Bangladesh
# Narayanganj, Bangladesh
# Dhamrai, Bangladesh
# Benapole, Bangladesh
# Gazipur, Bangladesh
# Gazipur, Bangladesh
# Chattogram, Bangladesh
# Sirajganj, Bangladesh
# Kalikapur, Bangladesh
# Noakhali, Bangladesh
# Shahzadpur, Bangladesh
# Sylhet, Bangladesh
# Kaliganj, Bangladesh
# Narayanganj, Bangladesh
# Rangpur, Bangladesh
# Thakurgaon, Bangladesh
# Gouripur, Bangladesh
# Nandigram, Bangladesh
# Dighi, Bangladesh
# Nagarkanda, Bangladesh
# Shahjadpur, Bangladesh
# Gaibandha, Bangladesh
# Magura, Bangladesh
# Dhaka, Bangladesh
# Bagerhat, Bangladesh
# Bogura, Bangladesh
# Mohammadpur, Bangladesh
# Dhaka, Bangladesh
# Puthia, Bangladesh
# Dhaka, Bangladesh
# Panchagarh, Bangladesh
# Gulshan, Bangladesh
# Chittagong, Bangladesh
# Chakoria, Bangladesh
# Manikganj, Bangladesh
# Gafargaon, Bangladesh
# Noakhali, Bangladesh
# Gopalganj, Bangladesh
# Satkania, Bangladesh
# Shahjadpur, Bangladesh
# Noakhali, Bangladesh
# Bhandaria, Bangladesh
# Panchagarh, Bangladesh
# Dinajpur, Bangladesh
# Nalitabari, Bangladesh
# Panchagarh, Bangladesh
# Kolatoli, Bangladesh
# Brahmanbaria, Bangladesh
# Bhurungamari, Bangladesh
# Nagarkanda, Bangladesh
# Taltola, Bangladesh
# Natore, Bangladesh
# Bahuli, Bangladesh
# Konabari, Bangladesh
# Khagrachari, Bangladesh
# Manikganj, Bangladesh
# Rangpur, Bangladesh
# Muksudpur, Bangladesh
# Kalkini, Bangladesh
# Kalkini, Bangladesh
# Sylhet, Bangladesh
# DAULATPUR, Bangladesh
# Bogura, Bangladesh
# Runi, Bangladesh
# Nayapara, Bangladesh
# Kalkini, Bangladesh
# Chattogram, Bangladesh
# Shahjahanpur, Bangladesh
# Rajshahi, Bangladesh
# Kalibari, Bangladesh
# Nawabganj, Bangladesh
# Bogura, Bangladesh
# Kendua, Bangladesh
# Nikunja, Bangladesh
# Dinajpur, Bangladesh
# Hakimpur, Bangladesh
# Khagrachhari, Bangladesh
# Dinajpur, Bangladesh
# Chuadanga, Bangladesh
# Rangamati, Bangladesh
# Bogura, Bangladesh
# Manikganj, Bangladesh
# Ukhia, Bangladesh
# Jashore, Bangladesh
# Narail, Bangladesh
# Godagari, Bangladesh
# Gafargaon, Bangladesh
# Dhaka, Bangladesh
# Gafargaon, Bangladesh
# Teknaf, Bangladesh
# Purbadhala, Bangladesh
# Nawabganj, Bangladesh
# Saudia, Bangladesh
# Dhaka, Bangladesh
# Jhenaidah, Bangladesh
# Barabari, Bangladesh
# Purbadhala, Bangladesh
# Gazaria, Bangladesh
# Noakhali, Bangladesh
# Natore, Bangladesh
# Jamalpur, Bangladesh
# Satkhira, Bangladesh
# Narayanganj, Bangladesh
# Bagha, Bangladesh
# Gouripur, Bangladesh
# Patuakhali, Bangladesh
# Kalkini, Bangladesh
# Kishoreganj, Bangladesh
# Naogaon, Bangladesh
# Dhaka, Bangladesh
# Chittagong, Bangladesh
# Khulna, Bangladesh
# Pabna, Bangladesh
# Khulna, Bangladesh
# Ishwardi, Bangladesh
# Dhaka, Bangladesh
# Patuakhali, Bangladesh
# Naogaon, Bangladesh
# Noakhali, Bangladesh
# Bogura, Bangladesh
# Noakhali, Bangladesh
# Lalpur, Bangladesh
# Lama, Bangladesh
# Bhola, Bangladesh
# Kurni, Bangladesh
# Biyala, Bangladesh
# Nageshwari, Bangladesh
# Elenga, Bangladesh
# Tungipara, Bangladesh
# Niamatpur, Bangladesh
# Bijoynagar, Bangladesh
# Naogaon, Bangladesh
# Shibganj, Bangladesh
# Lakshmipur, Bangladesh
# Lakshmipur, Bangladesh
# Khetlal, Bangladesh
# Ulipur, Bangladesh
# Sylhet, Bangladesh
# Bogura, Bangladesh
# Jamalpur, Bangladesh
# Chittagong, Bangladesh
# Magura, Bangladesh
# Chandpur, Bangladesh
# Jhikargacha, Bangladesh
# Rajshahi, Bangladesh
# Rojina, Bangladesh
# Madhukhali, Bangladesh
# China, Bangladesh
# Konabari, Bangladesh
# Manikganj, Bangladesh
# Dhaka, Bangladesh
# Mohanpur, Bangladesh
# Islamabad, Bangladesh
# Ramgati, Bangladesh
# Rajshahi, Bangladesh
# Motijheel, Bangladesh
# Rashidpur, Bangladesh
# Khulna, Bangladesh
# Darussalam, Bangladesh
# Madaripur, Bangladesh
# Kashiani, Bangladesh
# Shahjalal, Bangladesh
# Dhaka, Bangladesh
# Gazipur, Bangladesh
# Pathalia, Bangladesh
# Khulna, Bangladesh
# Dhaka, Bangladesh
# Amanullah, Bangladesh
# Khetlal, Bangladesh
# Bagerhat, Bangladesh
# Jhikorgacha, Bangladesh
# Chattogram, Bangladesh
# Sherpur, Bangladesh
# Golapganj, Bangladesh
# Gazipur, Bangladesh
# Joypurhat, Bangladesh
# Bhola, Bangladesh
# Bhola, Bangladesh
# Dinajpur, Bangladesh
# Dhamrai, Bangladesh
# Noakhali, Bangladesh
# Sonaimuri, Bangladesh
# Patuakhali, Bangladesh
# Dhamrai, Bangladesh
# Kishoreganj, Bangladesh
# Panchagarh, Bangladesh
# Faridpur, Bangladesh
# Nature, Bangladesh
# Feni, Bangladesh
# Munshipara, Bangladesh
# Bhola, Bangladesh
# Belkuchi, Bangladesh
# Sirajganj, Bangladesh
# Dinajpur, Bangladesh
# Nandail, Bangladesh
# Ashulia, Bangladesh
# Munshiganj, Bangladesh
# Gurudaspur, Bangladesh
# Thakurgaon, Bangladesh
# Manda, Bangladesh
# Noapara, Bangladesh
# Dinajpur, Bangladesh
# Natore, Bangladesh
# Natore, Bangladesh
# Chapainawabgonj, Bangladesh
# Taltali, Bangladesh
# Sonargaon, Bangladesh
# Mohadevpur, Bangladesh
# Patnitala, Bangladesh
# Dhaka, Bangladesh
# Narayanganj, Bangladesh
# Pirojpur, Bangladesh
# Gafargaon, Bangladesh
# Dhaka, Bangladesh
# Charfasson, Bangladesh
# Panchagarh, Bangladesh
# NatoreA, Bangladesh
# Wazipur, Bangladesh
# Purbadhala, Bangladesh
# Belal, Bangladesh
# Natore, Bangladesh
# Raiganj, Bangladesh
# Matidali, Bangladesh
# Bhola, Bangladesh
# Dumuria, Bangladesh
# Thakurgaon, Bangladesh
# Noakhali, Bangladesh
# Bogura, Bangladesh
# Panchagarh, Bangladesh
# Daulatpur, Bangladesh
# Bhurungamari, Bangladesh
# Noakhali, Bangladesh
# Dhaka, Bangladesh
# Kashiani, Bangladesh
# Tanore, Bangladesh
# Chattogram, Bangladesh
# Rajapur, Bangladesh
# Konabari, Bangladesh
# Tungipara, Bangladesh
# Sreenagar, Bangladesh
# Durgapur, Bangladesh
# Dhaka, Bangladesh
# Tongi, Bangladesh
# Kashiani, Bangladesh
# Noakhali, Bangladesh
# Teknaf, Bangladesh
# Burichang, Bangladesh
# Dhaka, Bangladesh
# PIROJPUR, Bangladesh
# Chiringa, Bangladesh
# Lakshmipur, Bangladesh
# Bogura, Bangladesh
# Narayanganj, Bangladesh
# Phulbari, Bangladesh
# Chittagong, Bangladesh
# Jhenaidah, Bangladesh
# Gaibandha, Bangladesh
# Bhola, Bangladesh
# Gouripur, Bangladesh
# Sreepur, Bangladesh
# Panchagarh, Bangladesh
# Gazipur, Bangladesh
# Bogdadia, Bangladesh
# Bakerganj, Bangladesh
# Jamalpur, Bangladesh
# Dhaka, Bangladesh
# NILPHAMARI, Bangladesh
# Noakhali, Bangladesh
# Rangpur, Bangladesh
# Bhandaria, Bangladesh
# Dhaka, Bangladesh
# Dhaka, Bangladesh
# Dhaka, Bangladesh
# Meherpur, Bangladesh
# Noakhali, Bangladesh
# Jamalpur, Bangladesh
# Gafargaon, Bangladesh
# PIROJPUR, Bangladesh
# Mathbaria, Bangladesh
# Shibchar, Bangladesh
# Dhaka, Bangladesh
# Satkhira, Bangladesh
# Dhaka, Bangladesh
# Hotapara, Bangladesh
# Dhaka, Bangladesh
# Mirpur, Bangladesh
# Dania, Bangladesh
# Khulna, Bangladesh
# Madhobpur, Bangladesh
# Patuakhali, Bangladesh
# Tiba, Bangladesh
# Kazipara, Bangladesh
# Ashulia, Bangladesh
# Birampur, Bangladesh
# Bogura, Bangladesh
# Raiganj, Bangladesh
# Dhaka, Bangladesh
# Bohra, Bangladesh
# Bhola, Bangladesh
# Kushtia, Bangladesh
# Noakhali, Bangladesh
# Natore, Bangladesh
# Tongibari, Bangladesh
# Kashiani, Bangladesh
# Jashore, Bangladesh
# Sirajganj, Bangladesh
# Kakrail, Bangladesh
# Shibpur, Bangladesh
# Faridpur, Bangladesh
# Jhenaidah, Bangladesh
# Phulbari, Bangladesh
# Joypurhat, Bangladesh
# Barishal, Bangladesh
# Kazipara, Bangladesh
# Fukra, Bangladesh
# Rayhan, Bangladesh
# Sylhet, Bangladesh
# Jhenaidah, Bangladesh
# Gazaria, Bangladesh
# Patuakhali, Bangladesh
# Khajuria, Bangladesh
# PIROJPUR, Bangladesh
# Bhandaria, Bangladesh
# Kaptai, Bangladesh
# Barguna, Bangladesh
# Hazir, Bangladesh
# Bogura, Bangladesh
# Lalmohan, Bangladesh
# Godagari, Bangladesh
# Muksudpur, Bangladesh
# MADARIPUR, Bangladesh
# Khulna, Bangladesh
# Chauddagram, Bangladesh
# Godagari, Bangladesh
# Shyamnagar, Bangladesh
# Dinajpur, Bangladesh
# Manikganj, Bangladesh
# Jatrabari, Bangladesh
# Gazipur, Bangladesh
# Kalkini, Bangladesh
# Gazipur, Bangladesh
# Khulna, Bangladesh
# Dhaka, Bangladesh
# Bogura, Bangladesh
# Godagari, Bangladesh
# Shibpur, Bangladesh
# Meherpur, Bangladesh
# Sonaimuri, Bangladesh
# Gafargaon, Bangladesh
# Dhaka, Bangladesh
# Rajshahi, Bangladesh
# Raiganj, Bangladesh
# Sirajganj, Bangladesh
# Gafargaon, Bangladesh
# Sirajganj, Bangladesh
# Patuakhali, Bangladesh
# Khulshi, Bangladesh
# Milan, Bangladesh
# Dhamrai, Bangladesh
# Godagari, Bangladesh
# Magura, Bangladesh
# Dhaka, Bangladesh
# KURIGRAM, Bangladesh
# Nekmarad, Bangladesh
# KURIGRAM, Bangladesh
# Kanthalbari, Bangladesh
# Sreepur, Bangladesh
# Bogura, Bangladesh
# Tarakanda, Bangladesh
# Faridpur, Bangladesh
# Noapara, Bangladesh
# Sonaimuri, Bangladesh
# Madhabpur, Bangladesh
# Ashulia, Bangladesh
# Hatibandha, Bangladesh
# Natore, Bangladesh
# Chapainawabgonj, Bangladesh
# HABIGANJ, Bangladesh
# Godagari, Bangladesh
# Bheramara, Bangladesh
# Godagari, Bangladesh
# Khulna, Bangladesh
# Sujanagar, Bangladesh
# Meherpur, Bangladesh
# Sirajganj, Bangladesh
# Jatrabari, Bangladesh
# Bogura, Bangladesh
# Rangpur, Bangladesh
# Cumilla, Bangladesh
# Akhaura, Bangladesh
# Noakhali, Bangladesh
# Pirojpur, Bangladesh
# Raiganj, Bangladesh
# Dhamrai, Bangladesh
# Sreepur, Bangladesh
# Bijoynagar, Bangladesh
# KALAPARA, Bangladesh
# Khulna, Bangladesh
# Tongi, Bangladesh
# Kinshasa, Bangladesh
# Gopalganj, Bangladesh
# Harbang, Bangladesh
# Dhaka, Bangladesh
# Teknaf, Bangladesh
# Dinajpur, Bangladesh
# Gopalganj, Bangladesh
# Hasina, Bangladesh
# Faridpur, Bangladesh
# Sirajganj, Bangladesh
# Bogura, Bangladesh
# Barisal, Bangladesh
# Madrasa, Bangladesh
# Gopalganj, Bangladesh
# Jashore, Bangladesh
# Gopalganj, Bangladesh
# Brahmanbaria, Bangladesh
# Rayganj, Bangladesh
# Sirajganj, Bangladesh
# Munshiganj, Bangladesh
# Manikganj, Bangladesh
# Rangpur, Bangladesh
# Jhalokati, Bangladesh
# Dhaka, Bangladesh
# Lohagara, Bangladesh
# Bamrail, Bangladesh
# Badarganj, Bangladesh
# Lalmonirhat, Bangladesh
# Kishoreganj, Bangladesh
# Naogaon, Bangladesh
# Mathbaria, Bangladesh
# Akhaura, Bangladesh
# Baura, Bangladesh
# Kajla, Bangladesh
# Noapara, Bangladesh
# Lohagara, Bangladesh
# Sherpur, Bangladesh
# Chittagong, Bangladesh
# Noakhali, Bangladesh
# Begumganj, Bangladesh
# Gazipur, Bangladesh
# Dhaka, Bangladesh
# Netrokona, Bangladesh
# Kasba, Bangladesh
# Boalmari, Bangladesh
# Lalpur, Bangladesh
# CPU times: user 1.77 s, sys: 220 ms, total: 1.98 s
# Wall time: 3min 54s

# %%
df1['location'] = loc_bengali
df1['Latitude'] = lat
df1['Longitude'] = lon
df1
# Out:
#                                              links  Year    date  \
# 0    https://www.observerbd.com/news.php?id=319338  2021  28-Jun
# 1    https://www.observerbd.com/news.php?id=319194  2021  27-Jun
# 2    https://www.observerbd.com/news.php?id=318258  2021  21-Jun
# 3    https://www.observerbd.com/news.php?id=317968  2021  19-Jun
# 4    https://www.observerbd.com/news.php?id=317963  2021  19-Jun
# ..                                             ...   ...     ...
# 464  https://www.observerbd.com/news.php?id=176928  2019  07-Jan
# 465  https://www.observerbd.com/news.php?id=176806  2019  06-Jan
# 466  https://www.observerbd.com/news.php?id=176524  2019  04-Jan
# 467  https://www.observerbd.com/news.php?id=176389  2019  03-Jan
# 468  https://www.observerbd.com/news.php?id=176070  2019  01-Jan
#
#                                                 titles  \
# 0       2 killed, 5 injured in Cumilla road accident\n
# 1    Four killed in Jashore accident on way to buy ...
# 2       Man, nephew killed in Chattogram bike accident
# 3             NGO worker killed in Bhola road accident
# 4              Three killed in Narsingdi road accident
# ..                                                 ...
# 464      Mother, son killed in Netrakona road accident
# 465               Mother-son killed in road accident\n
# 466                    Teacher killed in road accident
# 467        3 of a family die in Faridpur road accident
# 468               \n\n2 bikers killed in road accident
#
#                                                   News         Location_appox  \
# 0    Two were killed and five others were severely ...   Chandina, Bangladesh
# 1    Four killed in Jashore accident on way to buy ...    Jashore, Bangladesh
# 2    Man, nephew killed in Chattogram bike accident...   Mirsarai, Bangladesh
# 3    NGO worker killed in Bhola road accidentA work...      Bhola, Bangladesh
# 4    Three killed in Narsingdi road accidentThree p...  Narsingdi, Bangladesh
# ..                                                 ...                    ...
# 464  NETRAKONA, Jan 6: A mother and her son were ki...      Dhaka, Bangladesh
# 465  A woman and her son were killed while her daug...  Netrokona, Bangladesh
# 466  Teacher killed in road accident A retired teac...      Kasba, Bangladesh
# 467  3 of a family die in Faridpur road accidentThr...   Boalmari, Bangladesh
# 468  2 bikers killed in road accidentTwo motorcycle...     Lalpur, Bangladesh
#
#                                               location   Latitude  Longitude
# 0    চান্দিনা, কুমিল্লা জেলা, চট্টগ্রাম বিভাগ, 3510...  23.488376  91.007812
# 1         যশোর, যশোর জেলা, খুলনা বিভাগ, 7400, বাংলাদেশ  23.166597  89.209514
# 2    Mirsarai Upazila Code Road, চট্টগ্রাম জেলা, চট...  22.774456  91.563192
# 3                    ভোলা জেলা, বরিশাল বিভাগ, বাংলাদেশ  22.336542  90.843902
# 4    নরসিংদী, নরসিংদী জেলা, ঢাকা বিভাগ, 1602, বাংলাদেশ  23.915645  90.698196
# ..                                                 ...        ...        ...
# 464  ঢাকা, Chanpara Bazar, ঢাকা জেলা, ঢাকা বিভাগ, 1...  23.810651  90.412647
# 465  নেত্রকোনা, নেত্রকোনা জেলা, ময়মনসিংহ বিভাগ, বা...  24.885340  90.732625
# 466  কসবা, ব্রাহ্মণবাড়িয়া জেলা, চট্টগ্রাম বিভাগ, ...  23.746715  91.145893
# 467      বোয়ালমারী, ফরিদপুর জেলা, ঢাকা বিভাগ, বাংলাদেশ  23.385456  89.681615
# 468  লালপুর, নাটোর জেলা, রাজশাহী বিভাগ, 6420, বাংলাদেশ  24.182462  88.956501
#
# [469 rows x 9 columns]

# %%
df1.to_csv('Daily_Observer_hm.csv', index = False)

# %%
df_new = df1.copy()

# %%
import folium
from folium.plugins import *
from folium import plugins

# %%
df_new = df_new.dropna()
#df_new = df_new[(df_new['Latitude'] != 0) & (df_new['Longitude'] != 0)]

def map():


    # Create a map centered on Vancouver
    map_bd = folium.Map(location= [23.6850, 90.3563], tiles="cartodbpositron", zoom_start = 7)

    # Create a list with lat and long values and add the list to a heat map, then show map
    heat_data = [[row['Latitude'],row['Longitude']] for index, row in df_new.iterrows()]
    HeatMap(heat_data).add_to(map_bd)

    # instantiate a feature group for the incidents in the dataframe
    incidents = folium.map.FeatureGroup()

    # loop through the 100 crimes and add each to the incidents feature group
    for lat, lng, in zip(df_new.Latitude, df_new.Longitude):
        incidents.add_child(
            folium.CircleMarker(
                [lat, lng],
                radius=5, # define how big you want the circle markers to be
                color='darkred',
                fill=True,
                fill_color='red',
                fill_opacity=0.6
            )
        )
    
    #map_van.add_child(incidents)
    folium.TileLayer('cartodbdark_matter').add_to(map_bd)

    # instantiate a mark cluster object for the incidents in the dataframe
    incident = plugins.MarkerCluster().add_to(map_bd)

    # loop through the dataframe and add each data point to the mark cluster
    for lat, lng, label, in zip(df_new.Latitude, df_new.Longitude, df_new.Location_appox):
        folium.Marker(
            location=[lat, lng],
            icon=None,
            popup=label,
        ).add_to(incident)

    # add incidents to map
    map_bd.add_child(incident)
    return map_bd

map()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_cb6aa9875b0242a3b60b2dedcb237fdc%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium%40master/folium/templates/leaflet_heat.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css%22/%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20 ...

# %%
from time import strptime

df_new['month'] = df_new.date.str[3:6]
month_num = []
for i in range(len(df1)):
    month_num.append(strptime(df_new['month'][i],'%b').tm_mon)
df_new['month_num'] = month_num
df_new["Weight"] = df_new['month_num'].astype(float)
df_new
# Out:
#                                              links  Year    date  \
# 0    https://www.observerbd.com/news.php?id=319338  2021  28-Jun
# 1    https://www.observerbd.com/news.php?id=319194  2021  27-Jun
# 2    https://www.observerbd.com/news.php?id=318258  2021  21-Jun
# 3    https://www.observerbd.com/news.php?id=317968  2021  19-Jun
# 4    https://www.observerbd.com/news.php?id=317963  2021  19-Jun
# ..                                             ...   ...     ...
# 464  https://www.observerbd.com/news.php?id=176928  2019  07-Jan
# 465  https://www.observerbd.com/news.php?id=176806  2019  06-Jan
# 466  https://www.observerbd.com/news.php?id=176524  2019  04-Jan
# 467  https://www.observerbd.com/news.php?id=176389  2019  03-Jan
# 468  https://www.observerbd.com/news.php?id=176070  2019  01-Jan
#
#                                                 titles  \
# 0       2 killed, 5 injured in Cumilla road accident\n
# 1    Four killed in Jashore accident on way to buy ...
# 2       Man, nephew killed in Chattogram bike accident
# 3             NGO worker killed in Bhola road accident
# 4              Three killed in Narsingdi road accident
# ..                                                 ...
# 464      Mother, son killed in Netrakona road accident
# 465               Mother-son killed in road accident\n
# 466                    Teacher killed in road accident
# 467        3 of a family die in Faridpur road accident
# 468               \n\n2 bikers killed in road accident
#
#                                                   News         Location_appox  \
# 0    Two were killed and five others were severely ...   Chandina, Bangladesh
# 1    Four killed in Jashore accident on way to buy ...    Jashore, Bangladesh
# 2    Man, nephew killed in Chattogram bike accident...   Mirsarai, Bangladesh
# 3    NGO worker killed in Bhola road accidentA work...      Bhola, Bangladesh
# 4    Three killed in Narsingdi road accidentThree p...  Narsingdi, Bangladesh
# ..                                                 ...                    ...
# 464  NETRAKONA, Jan 6: A mother and her son were ki...      Dhaka, Bangladesh
# 465  A woman and her son were killed while her daug...  Netrokona, Bangladesh
# 466  Teacher killed in road accident A retired teac...      Kasba, Bangladesh
# 467  3 of a family die in Faridpur road accidentThr...   Boalmari, Bangladesh
# 468  2 bikers killed in road accidentTwo motorcycle...     Lalpur, Bangladesh
#
#                                               location   Latitude  Longitude  \
# 0    চান্দিনা, কুমিল্লা জেলা, চট্টগ্রাম বিভাগ, 3510...  23.488376  91.007812
# 1         যশোর, যশোর জেলা, খুলনা বিভাগ, 7400, বাংলাদেশ  23.166597  89.209514
# 2    Mirsarai Upazila Code Road, চট্টগ্রাম জেলা, চট...  22.774456  91.563192
# 3                    ভোলা জেলা, বরিশাল বিভাগ, বাংলাদেশ  22.336542  90.843902
# 4    নরসিংদী, নরসিংদী জেলা, ঢাকা বিভাগ, 1602, বাংলাদেশ  23.915645  90.698196
# ..                                                 ...        ...        ...
# 464  ঢাকা, Chanpara Bazar, ঢাকা জেলা, ঢাকা বিভাগ, 1...  23.810651  90.412647
# 465  নেত্রকোনা, নেত্রকোনা জেলা, ময়মনসিংহ বিভাগ, বা...  24.885340  90.732625
# 466  কসবা, ব্রাহ্মণবাড়িয়া জেলা, চট্টগ্রাম বিভাগ, ...  23.746715  91.145893
# 467      বোয়ালমারী, ফরিদপুর জেলা, ঢাকা বিভাগ, বাংলাদেশ  23.385456  89.681615
# 468  লালপুর, নাটোর জেলা, রাজশাহী বিভাগ, 6420, বাংলাদেশ  24.182462  88.956501
#
#     month  month_num  Weight
# 0     Jun          6     6.0
# 1     Jun          6     6.0
# 2     Jun          6     6.0
# 3     Jun          6     6.0
# 4     Jun          6     6.0
# ..    ...        ...     ...
# 464   Jan          1     1.0
# 465   Jan          1     1.0
# 466   Jan          1     1.0
# 467   Jan          1     1.0
# 468   Jan          1     1.0
#
# [469 rows x 12 columns]

# %%
import datetime 
lista_tempo = [] 

for x in df_new['month_num']: 
    monthinteger = x 
    lista_tempo.append(datetime.date(1900, monthinteger, 1).strftime('%B')) 
    
df_new['months_in_full'] = lista_tempo 
df_new['month_year'] = df_new['month'] + ' ' + df_new['Year'].astype(str)

df_new
# Out:
#                                              links  Year    date  \
# 0    https://www.observerbd.com/news.php?id=319338  2021  28-Jun
# 1    https://www.observerbd.com/news.php?id=319194  2021  27-Jun
# 2    https://www.observerbd.com/news.php?id=318258  2021  21-Jun
# 3    https://www.observerbd.com/news.php?id=317968  2021  19-Jun
# 4    https://www.observerbd.com/news.php?id=317963  2021  19-Jun
# ..                                             ...   ...     ...
# 464  https://www.observerbd.com/news.php?id=176928  2019  07-Jan
# 465  https://www.observerbd.com/news.php?id=176806  2019  06-Jan
# 466  https://www.observerbd.com/news.php?id=176524  2019  04-Jan
# 467  https://www.observerbd.com/news.php?id=176389  2019  03-Jan
# 468  https://www.observerbd.com/news.php?id=176070  2019  01-Jan
#
#                                                 titles  \
# 0       2 killed, 5 injured in Cumilla road accident\n
# 1    Four killed in Jashore accident on way to buy ...
# 2       Man, nephew killed in Chattogram bike accident
# 3             NGO worker killed in Bhola road accident
# 4              Three killed in Narsingdi road accident
# ..                                                 ...
# 464      Mother, son killed in Netrakona road accident
# 465               Mother-son killed in road accident\n
# 466                    Teacher killed in road accident
# 467        3 of a family die in Faridpur road accident
# 468               \n\n2 bikers killed in road accident
#
#                                                   News         Location_appox  \
# 0    Two were killed and five others were severely ...   Chandina, Bangladesh
# 1    Four killed in Jashore accident on way to buy ...    Jashore, Bangladesh
# 2    Man, nephew killed in Chattogram bike accident...   Mirsarai, Bangladesh
# 3    NGO worker killed in Bhola road accidentA work...      Bhola, Bangladesh
# 4    Three killed in Narsingdi road accidentThree p...  Narsingdi, Bangladesh
# ..                                                 ...                    ...
# 464  NETRAKONA, Jan 6: A mother and her son were ki...      Dhaka, Bangladesh
# 465  A woman and her son were killed while her daug...  Netrokona, Bangladesh
# 466  Teacher killed in road accident A retired teac...      Kasba, Bangladesh
# 467  3 of a family die in Faridpur road accidentThr...   Boalmari, Bangladesh
# 468  2 bikers killed in road accidentTwo motorcycle...     Lalpur, Bangladesh
#
#                                               location   Latitude  Longitude  \
# 0    চান্দিনা, কুমিল্লা জেলা, চট্টগ্রাম বিভাগ, 3510...  23.488376  91.007812
# 1         যশোর, যশোর জেলা, খুলনা বিভাগ, 7400, বাংলাদেশ  23.166597  89.209514
# 2    Mirsarai Upazila Code Road, চট্টগ্রাম জেলা, চট...  22.774456  91.563192
# 3                    ভোলা জেলা, বরিশাল বিভাগ, বাংলাদেশ  22.336542  90.843902
# 4    নরসিংদী, নরসিংদী জেলা, ঢাকা বিভাগ, 1602, বাংলাদেশ  23.915645  90.698196
# ..                                                 ...        ...        ...
# 464  ঢাকা, Chanpara Bazar, ঢাকা জেলা, ঢাকা বিভাগ, 1...  23.810651  90.412647
# 465  নেত্রকোনা, নেত্রকোনা জেলা, ময়মনসিংহ বিভাগ, বা...  24.885340  90.732625
# 466  কসবা, ব্রাহ্মণবাড়িয়া জেলা, চট্টগ্রাম বিভাগ, ...  23.746715  91.145893
# 467      বোয়ালমারী, ফরিদপুর জেলা, ঢাকা বিভাগ, বাংলাদেশ  23.385456  89.681615
# 468  লালপুর, নাটোর জেলা, রাজশাহী বিভাগ, 6420, বাংলাদেশ  24.182462  88.956501
#
#     month  month_num  Weight months_in_full month_year
# 0     Jun          6     6.0           June   Jun 2021
# 1     Jun          6     6.0           June   Jun 2021
# 2     Jun          6     6.0           June   Jun 2021
# 3     Jun          6     6.0           June   Jun 2021
# 4     Jun          6     6.0           June   Jun 2021
# ..    ...        ...     ...            ...        ...
# 464   Jan          1     1.0        January   Jan 2019
# 465   Jan          1     1.0        January   Jan 2019
# 466   Jan          1     1.0        January   Jan 2019
# 467   Jan          1     1.0        January   Jan 2019
# 468   Jan          1     1.0        January   Jan 2019
#
# [469 rows x 14 columns]

# %%
df_new['indexx'] = df_new['month'] + ' ' + df_new['Year'].astype(str)
lista_index = df_new['indexx'].unique().tolist()

weight_list = []

df_new['conta'] = 1 
for x in df_new['month_year'].sort_values().unique(): 
    weight_list.append(df_new.loc[df_new['month_year'] == x, 
                                        ['Latitude',"Longitude",'conta']].groupby(['Latitude','Longitude']).sum().reset_index().values.tolist()) 
    
base_map = folium.Map(location=[23.6850, 90.3563],tiles="stamen toner",zoom_start = 6) 

#create the heatmap from our List 
HeatMapWithTime(weight_list, radius=20,index= lista_index, gradient={0.1: 'blue',0.5: 'green', 0.5: 'yellow', 0.95: 'orange', 1: 'red'}, \
                                                                     
                        auto_play =True, min_opacity=0.5, max_opacity=1, use_local_extrema=True).add_to(base_map) 
                                                                
                                                                     
base_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_2685d4fcc8e24457a546fbfa80211d75%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/iso8601-js-period%400.2.1/iso8601.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet-timedimension%401.1.1/dist/leaflet.timedimension.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/pa7_hm.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/pa7_leaflet_hm.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet-timedimension%401. ...

# %% [markdown]
# ### References
#
# * https://medium.com/nerd-for-tech/time-lapse-heat-maps-with-folium-1847f53ec956
