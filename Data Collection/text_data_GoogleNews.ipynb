# %%
# !pip install GoogleNews
# Out:
# Collecting GoogleNews
#   Downloading GoogleNews-1.5.8-py3-none-any.whl (7.7 kB)
# Collecting dateparser
#   Downloading dateparser-1.0.0-py2.py3-none-any.whl (279 kB)
#      |████████████████████████████████| 279 kB 1.1 MB/s
# Collecting beautifulsoup4
#   Downloading beautifulsoup4-4.9.3-py3-none-any.whl (115 kB)
#      |████████████████████████████████| 115 kB 2.7 MB/s
# Requirement already satisfied: python-dateutil in /opt/conda/lib/python3.7/site-packages (from GoogleNews) (2.8.1)
# Collecting soupsieve>1.2
#   Downloading soupsieve-2.2.1-py3-none-any.whl (33 kB)
# Requirement already satisfied: regex!=2019.02.19 in /opt/conda/lib/python3.7/site-packages (from dateparser->GoogleNews) (2021.3.17)
# Requirement already satisfied: pytz in /opt/conda/lib/python3.7/site-packages (from dateparser->GoogleNews) (2021.1)
# Requirement already satisfied: tzlocal in /opt/conda/lib/python3.7/site-packages (from dateparser->GoogleNews) (2.1)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.7/site-packages (from python-dateutil->GoogleNews) (1.15.0)
# Installing collected packages: soupsieve, dateparser, beautifulsoup4, GoogleNews
# Successfully installed GoogleNews-1.5.8 beautifulsoup4-4.9.3 dateparser-1.0.0 soupsieve-2.2.1

# %%
from GoogleNews import GoogleNews
googlenews = GoogleNews()

# %%
googlenews.clear()

# %%
googlenews = GoogleNews(lang='en')
googlenews.get_news('bangladesh road accident')
googlenews.search('bangladesh road accident')

# %%
result_0 = googlenews.page_at(1)

desc_1 = googlenews.get_texts()
link_1 = googlenews.get_links()

for i in list(range(2, 70)):

    result = googlenews.page_at(i)
    desc = googlenews.get_texts()
    link = googlenews.get_links()

    desc_1 = desc_1 + desc
    link_1 = link_1 + link
# Out:
# 'NoneType' object is not iterable
# 'NoneType' object is not iterable
# 'NoneType' object is not iterable
# 'NoneType' object is not iterable
# 'NoneType' object is not iterable
# 'NoneType' object is not iterable
# 'NoneType' object is not iterable
# 'NoneType' object is not iterable
# 'NoneType' object is not iterable
# 'NoneType' object is not iterable
# 'NoneType' object is not iterable
# 'NoneType' object is not iterable
# 'NoneType' object is not iterable
# 'NoneType' object is not iterable
# 'NoneType' object is not iterable
# 'NoneType' object is not iterable
# 'NoneType' object is not iterable
# 'NoneType' object is not iterable
# 'NoneType' object is not iterable
# 'NoneType' object is not iterable
# 'NoneType' object is not iterable
# 'NoneType' object is not iterable
# 'NoneType' object is not iterable
# 'NoneType' object is not iterable
# 'NoneType' object is not iterable
# 'NoneType' object is not iterable
# 'NoneType' object is not iterable
# 'NoneType' object is not iterable
# 'NoneType' object is not iterable
# 'NoneType' object is not iterable
# 'NoneType' object is not iterable
# 'NoneType' object is not iterable
# 'NoneType' object is not iterable
# 'NoneType' object is not iterable
# 'NoneType' object is not iterable
# 'NoneType' object is not iterable
# 'NoneType' object is not iterable
# 'NoneType' object is not iterable
# 'NoneType' object is not iterable
# 'NoneType' object is not iterable
# 'NoneType' object is not iterable
# 'NoneType' object is not iterable

# %%
import pandas as pd

column_names = ["newspaper_name", "date_of_incident", "time_of_incident", "incident_type", "location", "death_count", "injury_count", "type_of_vehicle", "driver_age", "description_text", 'link']
df = pd.DataFrame(columns = column_names)

df['description_text'] = desc_1
df['link'] = link_1
display(df)

df.to_csv('google_news.csv', index = False)
# Out:
#       newspaper_name date_of_incident time_of_incident incident_type location  \
# 0                NaN              NaN              NaN           NaN      NaN
# 1                NaN              NaN              NaN           NaN      NaN
# 2                NaN              NaN              NaN           NaN      NaN
# 3                NaN              NaN              NaN           NaN      NaN
# 4                NaN              NaN              NaN           NaN      NaN
# ...              ...              ...              ...           ...      ...
# 22000            NaN              NaN              NaN           NaN      NaN
# 22001            NaN              NaN              NaN           NaN      NaN
# 22002            NaN              NaN              NaN           NaN      NaN
# 22003            NaN              NaN              NaN           NaN      NaN
# 22004            NaN              NaN              NaN           NaN      NaN
#
#       death_count injury_count type_of_vehicle driver_age  \
# 0             NaN          NaN             NaN        NaN
# 1             NaN          NaN             NaN        NaN
# 2             NaN          NaN             NaN        NaN
# 3             NaN          NaN             NaN        NaN
# 4             NaN          NaN             NaN        NaN
# ...           ...          ...             ...        ...
# 22000         NaN          NaN             NaN        NaN
# 22001         NaN          NaN             NaN        NaN
# 22002         NaN          NaN             NaN        NaN
# 22003         NaN          NaN             NaN        NaN
# 22004         NaN          NaN             NaN        NaN
#
#                                         description_text  \
# 0         Road accidents claim 9 lives across Bangladesh
# 1        Bangladeshi expat killed in Saudi road accident
# 2        Govt’s road accident taskforce still ruminating
# 3                        5 killed in Narsingdi collision
# 4      Bangladeshi-American lyft driver killed in New...
# ...                                                  ...
# 22000  Users suffer as Facebook, Instagram and Messen...
# 22001  353 people killed in workplace accidents in 10...
# 22002  Imrul Kayes' father critically injured in road...
# 22003  Road crash in Bangladesh kills at least 13 – B...
# 22004             Bangladesh: Road crash claims 15 lives
#
#                                                     link
# 0      news.google.com/./articles/CBMiX2h0dHBzOi8vd3d...
# 1      news.google.com/./articles/CBMiX2h0dHBzOi8vd3d...
# 2      news.google.com/./articles/CBMiYmh0dHBzOi8vd3d...
# 3      news.google.com/./articles/CBMiYmh0dHBzOi8vd3d...
# 4      news.google.com/./articles/CBMiaGh0dHA6Ly93d3c...
# ...                                                  ...
# 22000  https://www.dhakatribune.com/technology/2020/1...
# 22001  https://www.dhakatribune.com/bangladesh/2020/1...
# 22002  https://www.bdcrictime.com/imrul-kayes-father-...
# 22003  https://borneobulletin.com.bn/road-crash-in-ba...
# 22004  https://www.aa.com.tr/en/asia-pacific/banglade...
#
# [22005 rows x 11 columns]

# %% [markdown]
# ## Reference:
#
# * https://pypi.org/project/GoogleNews/
