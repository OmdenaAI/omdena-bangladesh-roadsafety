# %% [markdown]
# ### Scraping Road Accident News from Dhaka Tribune using BeautifulSoup

# %%
# Import libraries

import requests
import json
import pandas as pd 
import time
from bs4 import BeautifulSoup as bs # 
from bs4 import BeautifulSoup

# %%
# The base URL
url = "https://www.dhakatribune.com/hashtag/road-accident"

# %%
# Creating a BeautifulSoup object
def make_soup(url):
    
    doc = requests.get(url)
    if str(doc) == "<Response [200]>":
        # create a soup object that contains the navigable html presentation of the page
        soup = bs(doc.content, 'html.parser')
        print(f"Retrieved url: {url}")
    else:
        print(f"{url} cannot be reached.")   
        
    return soup

# %%
soup = make_soup(url)
# Out:
# Retrieved url: https://www.dhakatribune.com/hashtag/road-accident

# %%
# What's the URL of the second page?
pagination = soup.find("div", attrs={"class": "page-pagination-area"})
next_page_url = "https://www.dhakatribune.com" + pagination.find_all('a')[1].get('href')
next_page_url
# Out:
# 'https://www.dhakatribune.com/hashtag/road-accident/page/2'

# %%
# And what about the last page?
next_page_url = "https://www.dhakatribune.com" + pagination.find_all('a')[-1].get('href')
next_page_url
# Out:
# 'https://www.dhakatribune.com/hashtag/road-accident/page/48'

# %%
# Let's put together all the URL that we're gonna use
next_urls = [] 

for i in range(2, 48):
    next_urls.append('https://www.dhakatribune.com/hashtag/road-accident/page/{}'.format(i))
    
all_urls = [url] + next_urls
all_urls
# Out:
# ['https://www.dhakatribune.com/hashtag/road-accident',
#  'https://www.dhakatribune.com/hashtag/road-accident/page/2',
#  'https://www.dhakatribune.com/hashtag/road-accident/page/3',
#  'https://www.dhakatribune.com/hashtag/road-accident/page/4',
#  'https://www.dhakatribune.com/hashtag/road-accident/page/5',
#  'https://www.dhakatribune.com/hashtag/road-accident/page/6',
#  'https://www.dhakatribune.com/hashtag/road-accident/page/7',
#  'https://www.dhakatribune.com/hashtag/road-accident/page/8',
#  'https://www.dhakatribune.com/hashtag/road-accident/page/9',
#  'https://www.dhakatribune.com/hashtag/road-accident/page/10',
#  'https://www.dhakatribune.com/hashtag/road-accident/page/11',
#  'https://www.dhakatribune.com/hashtag/road-accident/page/12',
#  'https://www.dhakatribune.com/hashtag/road-accident/page/13',
#  'https://www.dhakatribune.com/hashtag/road-accident/page/14',
#  'https://www.dhakatribune.com/hashtag/road-accident/page/15',
#  'https://www.dhakatribune.com/hashtag/road-accident/page/16',
#  'https://www.dhakatribune.com/hashtag/road-accident/page/17',
#  'https://www.dhakatribune.com/hashtag/road-accident/page/18',
#  'https://www.dhakatribune.com/hashtag/road-accident/page/19',
#  'https://www.dhakatribune.com/hashtag/road-accident/page/20',
#  'https://www.dhakatribune.com/hashtag/road-accident/page/21',
#  'https://www.dhakatribune.com/hashtag/road-accident/page/22',
#  'https://www.dhakatribune.com/hashtag/road-accident/page/23',
#  'https://www.dhakatribune.com/hashtag/road-accident/page/24',
#  'https://www.dhakatribune.com/hashtag/road-accident/page/25',
#  'https://www.dhakatribune.com/hashtag/road-accident/page/26',
#  'https://www.dhakatribune.com/hashtag/road-accident/page/27',
#  'https://www.dhakatribune.com/hashtag/road-accident/page/28',
#  'https://www.dhakatribune.com/hashtag/road-accident/page/29',
#  'https://www.dhakatribune.com/hashtag/road-accident/page/30',
#  'https://www.dhakatribune.com/hashtag/road-accident/page/31',
#  'https://www.dhakatribune.com/hashtag/road-accident/page/32',
#  'https://www.dhakatribune.com/hashtag/road-accident/page/33',
#  'https://www.dhakatribune.com/hashtag/road-accident/page/34',
#  'https://www.dhakatribune.com/hashtag/road-accident/page/35',
#  'https://www.dhakatribune.com/hashtag/road-accident/page/36',
#  'https://www.dhakatribune.com/hashtag/road-accident/page/37',
#  'https://www.dhakatribune.com/hashtag/road-accident/page/38',
#  'https://www.dhakatribune.com/hashtag/road-accident/page/39',
#  'https://www.dhakatribune.com/hashtag/road-accident/page/40',
#  'https://www.dhakatribune.com/hashtag/road-accident/page/41',
#  'https://www.dhakatribune.com/hashtag/road-accident/page/42',
#  'https://www.dhakatribune.com/hashtag/road-accident/page/43',
#  'https://www.dhakatribune.com/hashtag/road-accident/page/44',
#  'https://www.dhakatribune.com/hashtag/road-accident/page/45',
#  'https://www.dhakatribune.com/hashtag/road-accident/page/46',
#  'https://www.dhakatribune.com/hashtag/road-accident/page/47']

# %%
# Let's scrape the links of each news

links = []

for u in all_urls:
    
    soup = make_soup(u)
    container = soup.find("div", attrs={"class": "listing-page-news listing-page-info"})
        
    link = []
    
    for row in container.find_all('a'):
        l = row.attrs['href']
        link.append(l)
        
    links_ = ["https://www.dhakatribune.com" + x for x in link if '/articles/' not in x and '#' not in x]   
    links = links + links_
    
outputs = []
        
for x in links:
    if x not in outputs:
        outputs.append(x)
# Out:
# Retrieved url: https://www.dhakatribune.com/hashtag/road-accident
# Retrieved url: https://www.dhakatribune.com/hashtag/road-accident/page/2
# Retrieved url: https://www.dhakatribune.com/hashtag/road-accident/page/3
# Retrieved url: https://www.dhakatribune.com/hashtag/road-accident/page/4
# Retrieved url: https://www.dhakatribune.com/hashtag/road-accident/page/5
# Retrieved url: https://www.dhakatribune.com/hashtag/road-accident/page/6
# Retrieved url: https://www.dhakatribune.com/hashtag/road-accident/page/7
# Retrieved url: https://www.dhakatribune.com/hashtag/road-accident/page/8
# Retrieved url: https://www.dhakatribune.com/hashtag/road-accident/page/9
# Retrieved url: https://www.dhakatribune.com/hashtag/road-accident/page/10
# Retrieved url: https://www.dhakatribune.com/hashtag/road-accident/page/11
# Retrieved url: https://www.dhakatribune.com/hashtag/road-accident/page/12
# Retrieved url: https://www.dhakatribune.com/hashtag/road-accident/page/13
# Retrieved url: https://www.dhakatribune.com/hashtag/road-accident/page/14
# Retrieved url: https://www.dhakatribune.com/hashtag/road-accident/page/15
# Retrieved url: https://www.dhakatribune.com/hashtag/road-accident/page/16
# Retrieved url: https://www.dhakatribune.com/hashtag/road-accident/page/17
# Retrieved url: https://www.dhakatribune.com/hashtag/road-accident/page/18
# Retrieved url: https://www.dhakatribune.com/hashtag/road-accident/page/19
# Retrieved url: https://www.dhakatribune.com/hashtag/road-accident/page/20
# Retrieved url: https://www.dhakatribune.com/hashtag/road-accident/page/21
# Retrieved url: https://www.dhakatribune.com/hashtag/road-accident/page/22
# Retrieved url: https://www.dhakatribune.com/hashtag/road-accident/page/23
# Retrieved url: https://www.dhakatribune.com/hashtag/road-accident/page/24
# Retrieved url: https://www.dhakatribune.com/hashtag/road-accident/page/25
# Retrieved url: https://www.dhakatribune.com/hashtag/road-accident/page/26
# Retrieved url: https://www.dhakatribune.com/hashtag/road-accident/page/27
# Retrieved url: https://www.dhakatribune.com/hashtag/road-accident/page/28
# Retrieved url: https://www.dhakatribune.com/hashtag/road-accident/page/29
# Retrieved url: https://www.dhakatribune.com/hashtag/road-accident/page/30
# Retrieved url: https://www.dhakatribune.com/hashtag/road-accident/page/31
# Retrieved url: https://www.dhakatribune.com/hashtag/road-accident/page/32
# Retrieved url: https://www.dhakatribune.com/hashtag/road-accident/page/33
# Retrieved url: https://www.dhakatribune.com/hashtag/road-accident/page/34
# Retrieved url: https://www.dhakatribune.com/hashtag/road-accident/page/35
# Retrieved url: https://www.dhakatribune.com/hashtag/road-accident/page/36
# Retrieved url: https://www.dhakatribune.com/hashtag/road-accident/page/37
# Retrieved url: https://www.dhakatribune.com/hashtag/road-accident/page/38
# Retrieved url: https://www.dhakatribune.com/hashtag/road-accident/page/39
# Retrieved url: https://www.dhakatribune.com/hashtag/road-accident/page/40
# Retrieved url: https://www.dhakatribune.com/hashtag/road-accident/page/41
# Retrieved url: https://www.dhakatribune.com/hashtag/road-accident/page/42
# Retrieved url: https://www.dhakatribune.com/hashtag/road-accident/page/43
# Retrieved url: https://www.dhakatribune.com/hashtag/road-accident/page/44
# Retrieved url: https://www.dhakatribune.com/hashtag/road-accident/page/45
# Retrieved url: https://www.dhakatribune.com/hashtag/road-accident/page/46
# Retrieved url: https://www.dhakatribune.com/hashtag/road-accident/page/47

# %%
# Now the headlines of each news

headings = []

for u in all_urls:
    
    soup = make_soup(u)
    container = soup.find("div", attrs={"class": "listing-page-news listing-page-info"})
    
    for row in container.find_all('h4', attrs={"class": "news-title"}):
        # getting the heading
        heading = row.text.strip()
        headings.append(heading)
# Out:
# Retrieved url: https://www.dhakatribune.com/hashtag/road-accident
# Retrieved url: https://www.dhakatribune.com/hashtag/road-accident/page/2
# Retrieved url: https://www.dhakatribune.com/hashtag/road-accident/page/3
# Retrieved url: https://www.dhakatribune.com/hashtag/road-accident/page/4
# Retrieved url: https://www.dhakatribune.com/hashtag/road-accident/page/5
# Retrieved url: https://www.dhakatribune.com/hashtag/road-accident/page/6
# Retrieved url: https://www.dhakatribune.com/hashtag/road-accident/page/7
# Retrieved url: https://www.dhakatribune.com/hashtag/road-accident/page/8
# Retrieved url: https://www.dhakatribune.com/hashtag/road-accident/page/9
# Retrieved url: https://www.dhakatribune.com/hashtag/road-accident/page/10
# Retrieved url: https://www.dhakatribune.com/hashtag/road-accident/page/11
# Retrieved url: https://www.dhakatribune.com/hashtag/road-accident/page/12
# Retrieved url: https://www.dhakatribune.com/hashtag/road-accident/page/13
# Retrieved url: https://www.dhakatribune.com/hashtag/road-accident/page/14
# Retrieved url: https://www.dhakatribune.com/hashtag/road-accident/page/15
# Retrieved url: https://www.dhakatribune.com/hashtag/road-accident/page/16
# Retrieved url: https://www.dhakatribune.com/hashtag/road-accident/page/17
# Retrieved url: https://www.dhakatribune.com/hashtag/road-accident/page/18
# Retrieved url: https://www.dhakatribune.com/hashtag/road-accident/page/19
# Retrieved url: https://www.dhakatribune.com/hashtag/road-accident/page/20
# Retrieved url: https://www.dhakatribune.com/hashtag/road-accident/page/21
# Retrieved url: https://www.dhakatribune.com/hashtag/road-accident/page/22
# Retrieved url: https://www.dhakatribune.com/hashtag/road-accident/page/23
# Retrieved url: https://www.dhakatribune.com/hashtag/road-accident/page/24
# Retrieved url: https://www.dhakatribune.com/hashtag/road-accident/page/25
# Retrieved url: https://www.dhakatribune.com/hashtag/road-accident/page/26
# Retrieved url: https://www.dhakatribune.com/hashtag/road-accident/page/27
# Retrieved url: https://www.dhakatribune.com/hashtag/road-accident/page/28
# Retrieved url: https://www.dhakatribune.com/hashtag/road-accident/page/29
# Retrieved url: https://www.dhakatribune.com/hashtag/road-accident/page/30
# Retrieved url: https://www.dhakatribune.com/hashtag/road-accident/page/31
# Retrieved url: https://www.dhakatribune.com/hashtag/road-accident/page/32
# Retrieved url: https://www.dhakatribune.com/hashtag/road-accident/page/33
# Retrieved url: https://www.dhakatribune.com/hashtag/road-accident/page/34
# Retrieved url: https://www.dhakatribune.com/hashtag/road-accident/page/35
# Retrieved url: https://www.dhakatribune.com/hashtag/road-accident/page/36
# Retrieved url: https://www.dhakatribune.com/hashtag/road-accident/page/37
# Retrieved url: https://www.dhakatribune.com/hashtag/road-accident/page/38
# Retrieved url: https://www.dhakatribune.com/hashtag/road-accident/page/39
# Retrieved url: https://www.dhakatribune.com/hashtag/road-accident/page/40
# Retrieved url: https://www.dhakatribune.com/hashtag/road-accident/page/41
# Retrieved url: https://www.dhakatribune.com/hashtag/road-accident/page/42
# Retrieved url: https://www.dhakatribune.com/hashtag/road-accident/page/43
# Retrieved url: https://www.dhakatribune.com/hashtag/road-accident/page/44
# Retrieved url: https://www.dhakatribune.com/hashtag/road-accident/page/45
# Retrieved url: https://www.dhakatribune.com/hashtag/road-accident/page/46
# Retrieved url: https://www.dhakatribune.com/hashtag/road-accident/page/47

# %%
# Let's also look at the date when the news got published

times = []

for u in all_urls:
    
    soup = make_soup(u)
    container = soup.find("div", attrs={"class": "listing-page-news listing-page-info"})
    
    for row in container.find_all('h4'):
        # getting the publish time
        time = row.text
        times.append(time)
    
    times = [x.strip() for x in times if '\n' not in x]
# Out:
# Retrieved url: https://www.dhakatribune.com/hashtag/road-accident
# Retrieved url: https://www.dhakatribune.com/hashtag/road-accident/page/2
# Retrieved url: https://www.dhakatribune.com/hashtag/road-accident/page/3
# Retrieved url: https://www.dhakatribune.com/hashtag/road-accident/page/4
# Retrieved url: https://www.dhakatribune.com/hashtag/road-accident/page/5
# Retrieved url: https://www.dhakatribune.com/hashtag/road-accident/page/6
# Retrieved url: https://www.dhakatribune.com/hashtag/road-accident/page/7
# Retrieved url: https://www.dhakatribune.com/hashtag/road-accident/page/8
# Retrieved url: https://www.dhakatribune.com/hashtag/road-accident/page/9
# Retrieved url: https://www.dhakatribune.com/hashtag/road-accident/page/10
# Retrieved url: https://www.dhakatribune.com/hashtag/road-accident/page/11
# Retrieved url: https://www.dhakatribune.com/hashtag/road-accident/page/12
# Retrieved url: https://www.dhakatribune.com/hashtag/road-accident/page/13
# Retrieved url: https://www.dhakatribune.com/hashtag/road-accident/page/14
# Retrieved url: https://www.dhakatribune.com/hashtag/road-accident/page/15
# Retrieved url: https://www.dhakatribune.com/hashtag/road-accident/page/16
# Retrieved url: https://www.dhakatribune.com/hashtag/road-accident/page/17
# Retrieved url: https://www.dhakatribune.com/hashtag/road-accident/page/18
# Retrieved url: https://www.dhakatribune.com/hashtag/road-accident/page/19
# Retrieved url: https://www.dhakatribune.com/hashtag/road-accident/page/20
# Retrieved url: https://www.dhakatribune.com/hashtag/road-accident/page/21
# Retrieved url: https://www.dhakatribune.com/hashtag/road-accident/page/22
# Retrieved url: https://www.dhakatribune.com/hashtag/road-accident/page/23
# Retrieved url: https://www.dhakatribune.com/hashtag/road-accident/page/24
# Retrieved url: https://www.dhakatribune.com/hashtag/road-accident/page/25
# Retrieved url: https://www.dhakatribune.com/hashtag/road-accident/page/26
# Retrieved url: https://www.dhakatribune.com/hashtag/road-accident/page/27
# Retrieved url: https://www.dhakatribune.com/hashtag/road-accident/page/28
# Retrieved url: https://www.dhakatribune.com/hashtag/road-accident/page/29
# Retrieved url: https://www.dhakatribune.com/hashtag/road-accident/page/30
# Retrieved url: https://www.dhakatribune.com/hashtag/road-accident/page/31
# Retrieved url: https://www.dhakatribune.com/hashtag/road-accident/page/32
# Retrieved url: https://www.dhakatribune.com/hashtag/road-accident/page/33
# Retrieved url: https://www.dhakatribune.com/hashtag/road-accident/page/34
# Retrieved url: https://www.dhakatribune.com/hashtag/road-accident/page/35
# Retrieved url: https://www.dhakatribune.com/hashtag/road-accident/page/36
# Retrieved url: https://www.dhakatribune.com/hashtag/road-accident/page/37
# Retrieved url: https://www.dhakatribune.com/hashtag/road-accident/page/38
# Retrieved url: https://www.dhakatribune.com/hashtag/road-accident/page/39
# Retrieved url: https://www.dhakatribune.com/hashtag/road-accident/page/40
# Retrieved url: https://www.dhakatribune.com/hashtag/road-accident/page/41
# Retrieved url: https://www.dhakatribune.com/hashtag/road-accident/page/42
# Retrieved url: https://www.dhakatribune.com/hashtag/road-accident/page/43
# Retrieved url: https://www.dhakatribune.com/hashtag/road-accident/page/44
# Retrieved url: https://www.dhakatribune.com/hashtag/road-accident/page/45
# Retrieved url: https://www.dhakatribune.com/hashtag/road-accident/page/46
# Retrieved url: https://www.dhakatribune.com/hashtag/road-accident/page/47

# %%
# let's create a dataframe with all the info in hand

column_names = ['date_of_incident', 'time_of_incident', 'incident_type', 'location',
       'death_count', 'injury_count', 'type_of_vehicle1', 'type_of_vehicle2',
       'driver_age', 'description_text', 'published-time', 'link', 'full_text']

df = pd.DataFrame(columns = column_names)
df['description_text'] = headings
df['published-time'] = times
df['link'] = outputs
df.head()
# Out:
#   date_of_incident time_of_incident incident_type location death_count  \
# 0              NaN              NaN           NaN      NaN         NaN
# 1              NaN              NaN           NaN      NaN         NaN
# 2              NaN              NaN           NaN      NaN         NaN
# 3              NaN              NaN           NaN      NaN         NaN
# 4              NaN              NaN           NaN      NaN         NaN
#
#   injury_count type_of_vehicle1 type_of_vehicle2 driver_age  \
# 0          NaN              NaN              NaN        NaN
# 1          NaN              NaN              NaN        NaN
# 2          NaN              NaN              NaN        NaN
# 3          NaN              NaN              NaN        NaN
# 4          NaN              NaN              NaN        NaN
#
#                          description_text    published-time  \
# 0            2 killed in Dhaka road crash  Sat, Jun 26 2021
# 1      Three killed in Muktagacha road...  Wed, Jun 23 2021
# 2  Truck-pickup van collision leaves 3...  Sat, Jun 19 2021
# 3                Bogra road crash kills 3  Sat, Jun 19 2021
# 4          Cop killed in Dhaka road crash  Sat, Jun 19 2021
#
#                                                 link full_text
# 0  https://www.dhakatribune.com/accident/2021/06/...       NaN
# 1  https://www.dhakatribune.com/accident/2021/06/...       NaN
# 2  https://www.dhakatribune.com/bangladesh/nation...       NaN
# 3  https://www.dhakatribune.com/bangladesh/nation...       NaN
# 4  https://www.dhakatribune.com/bangladesh/dhaka/...       NaN

# %%
# Let's populate the full_text column as well

# %%
# %%time

links = df.link
full_text = []

for link in links:

        URL = link
        page = requests.get(URL)
        soup = BeautifulSoup(page.content, 'html.parser')

        cont = container = soup.find("div", attrs={"class": "report-content fr-view"})

        parahraphs = cont.find_all('p')
        para = []
        
        for i in list(range(len(parahraphs))):
            para.append(cont.find_all('p')[i].get_text())
            s = ' '.join(para)
        full_text.append(s)
        
df['full_text'] = full_text
        
display(df.tail())
df.to_csv('dhakatribune_1jan2016-29jun2021_v2.csv', index = False)
# Out:
#     date_of_incident time_of_incident incident_type location death_count  \
# 982              NaN              NaN           NaN      NaN         NaN
# 983              NaN              NaN           NaN      NaN         NaN
# 984              NaN              NaN           NaN      NaN         NaN
# 985              NaN              NaN           NaN      NaN         NaN
# 986              NaN              NaN           NaN      NaN         NaN
#
#     injury_count type_of_vehicle1 type_of_vehicle2 driver_age  \
# 982          NaN              NaN              NaN        NaN
# 983          NaN              NaN              NaN        NaN
# 984          NaN              NaN              NaN        NaN
# 985          NaN              NaN              NaN        NaN
# 986          NaN              NaN              NaN        NaN
#
#                                description_text    published-time  \
# 982             6 killed in Pabna road accident  Mon, Aug 15 2016
# 983             Road accident kills 1 in Natore  Fri, Aug 12 2016
# 984  Traffic constable dies after truck runs...   Thu, Aug 4 2016
# 985    Traffic constable crushed under truck...   Thu, Aug 4 2016
# 986    Two motorcyclists killed in Manikganj...  Sat, Jul 16 2016
#
#                                                   link  \
# 982  https://www.dhakatribune.com/bangladesh/2016/0...
# 983  https://www.dhakatribune.com/bangladesh/2016/0...
# 984  https://www.dhakatribune.com/bangladesh/2016/0...
# 985  https://www.dhakatribune.com/bangladesh/2016/0...
# 986  https://www.dhakatribune.com/bangladesh/2016/0...
#
#                                              full_text
# 982  The vice-president of Jatiyatabadi Chhatra Dal...
# 983  The vice-president of Jatiyatabadi Chhatra Dal...
# 984  The vice-president of Jatiyatabadi Chhatra Dal...
# 985  The vice-president of Jatiyatabadi Chhatra Dal...
# 986  The vice-president of Jatiyatabadi Chhatra Dal...
# Wall time: 2min 37s

# %% [markdown]
# Well, there are some errors and we gotta fix this! The texts extracted from links starting from index 736 are repetitive. There is a slight change in the HTML which causes this. The texts are in text format instead of being in paragraphs for these indices.

# %%
# %%time 

links_left = list(df.link[736:])
full_text_left = []

for link in links_left:

        URL = link
        page = requests.get(URL)
        soup = BeautifulSoup(page.content, 'html.parser')

        cont = container = soup.find("div", attrs={"class": "report-content fr-view"})
        parahraphs = cont.text.strip().replace('\n', ' ')
        
        full_text_left.append(parahraphs)
        
df.full_text[736:] = full_text_left

display(df.tail())
df.to_csv('dhakatribune_1jan2016-29jun2021_v2.csv', index = False)
# Out:
#     date_of_incident time_of_incident incident_type location death_count  \
# 982              NaN              NaN           NaN      NaN         NaN
# 983              NaN              NaN           NaN      NaN         NaN
# 984              NaN              NaN           NaN      NaN         NaN
# 985              NaN              NaN           NaN      NaN         NaN
# 986              NaN              NaN           NaN      NaN         NaN
#
#     injury_count type_of_vehicle1 type_of_vehicle2 driver_age  \
# 982          NaN              NaN              NaN        NaN
# 983          NaN              NaN              NaN        NaN
# 984          NaN              NaN              NaN        NaN
# 985          NaN              NaN              NaN        NaN
# 986          NaN              NaN              NaN        NaN
#
#                                description_text    published-time  \
# 982             6 killed in Pabna road accident  Mon, Aug 15 2016
# 983             Road accident kills 1 in Natore  Fri, Aug 12 2016
# 984  Traffic constable dies after truck runs...   Thu, Aug 4 2016
# 985    Traffic constable crushed under truck...   Thu, Aug 4 2016
# 986    Two motorcyclists killed in Manikganj...  Sat, Jul 16 2016
#
#                                                   link  \
# 982  https://www.dhakatribune.com/bangladesh/2016/0...
# 983  https://www.dhakatribune.com/bangladesh/2016/0...
# 984  https://www.dhakatribune.com/bangladesh/2016/0...
# 985  https://www.dhakatribune.com/bangladesh/2016/0...
# 986  https://www.dhakatribune.com/bangladesh/2016/0...
#
#                                              full_text
# 982  Of the deceased, five were identified as Abul ...
# 983  The deceased was identified as Ali Hossain, 50...
# 984  The constable was identified as RG Jojon Akhan...
# 985  An on-duty traffic constable has been crushed ...
# 986  At least two motorcyclists have been killed as...
# Wall time: 40.2 s

# %% [markdown]
# ### Reference
#
# * https://github.com/subrockmann/news_scraping/blob/main/Scraping_road_accidents.ipynb
